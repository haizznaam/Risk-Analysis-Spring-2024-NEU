# %% [markdown]
# <a href="https://colab.research.google.com/github/haizznaam/Risk-Analysis-NEU/blob/main/LendingClub_WoE_PD_Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Set up Colab Env
import os
os.chdir('/content/drive/MyDrive/Risk Analysis - Spring 2024_NEU')
print("We are currently in the folder of ", os.getcwd())
# Out:
# We are currently in the folder of  /content/drive/MyDrive/Risk Analysis - Spring 2024_NEU

# %% [markdown]
# # Context & Objective:
#
# The dataset being used here has 7 years' historical loan data taken from [LendingClub](https://www.lendingclub.com/). By looking at the loan status, we can check if the loan was sanctioned to the customers or not. If the loan status is "charged off" or "default" or the issuance of loan got delayed by 31-120 days, it is a bad loan. We will analyze the characteristics of the customers whose loans belong to **"bad loan"** category and will build a **Probability of Default (PD) Model**, so that is can be used in future to predict the customer will default or not.
#
# We have used some useful concepts:
# - Binning,
# - Weight of Evidence (WoE),
# - Information Value (IV)
#
# **Acknowledgements:**
# - Some insightful kernels which discussed the above three topics earlier for other applications are: [Pranav Pandya's work](https://www.kaggle.com/code/pranav84/talkingdata-with-breaking-bad-feature-engg/report), [Bryan Arnold's work](https://www.kaggle.com/code/puremath86/iv-woe-starter-for-python/notebook)
# - [This youtube webinar](https://www.youtube.com/watch?v=fiQhxn9RjEQ&t=2873s) on credit risk analysis is also informative

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(context='notebook')
sns.set_style("whitegrid", {'axes.grid' : False})
plt.tight_layout()

import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
data = pd.read_csv("LendingClub Dataset/loan_data_2007_2014.csv", low_memory=False)
data.drop(columns= ["Unnamed: 0"], inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 466285 entries, 0 to 466284
# Data columns (total 74 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   id                           466285 non-null  int64
#  1   member_id                    466285 non-null  int64
#  2   loan_amnt                    466285 non-null  int64
#  3   funded_amnt                  466285 non-null  int64
#  4   funded_amnt_inv              466285 non-null  float64
#  5   term                         466285 non-null  object
#  6   int_rate                     466285 non-null  float64
#  7   installment                  466285 non-null  float64
#  8   grade                        466285 non-null  object
#  9   sub_grade                    466285 non-null  object
#  10  emp_title                    438697 non-null  object
#  11  emp_length                   445277 non-null  object
#  12  home_ownership               466285 non-null  object
#  13  annual_inc                   466281 non-null  float64
#  14  verification_status          466285 non-null  object
#  15  issue_d                      466285 non-null  object
#  16  loan_status                  466285 non-null  object
#  17  pymnt_plan                   466285 non-null  object
#  18  url                          466285 non-null  object
#  19  desc                         125983 non-null  object
#  20  purpose                      466285 non-null  object
#  21  title                        466265 non-null  object
#  22  zip_code                     466285 non-null  object
#  23  addr_state                   466285 non-null  object
#  24  dti                          466285 non-null  float64
#  25  delinq_2yrs                  466256 non-null  float64
#  26  earliest_cr_line             466256 non-null  object
#  27  inq_last_6mths               466256 non-null  float64
#  28  mths_since_last_delinq       215934 non-null  float64
#  29  mths_since_last_record       62638 non-null   float64
#  30  open_acc                     466256 non-null  float64
#  31  pub_rec                      466256 non-null  float64
#  32  revol_bal                    466285 non-null  int64
#  33  revol_util                   465945 non-null  float64
#  34  total_acc                    466256 non-null  float64
#  35  initial_list_status          466285 non-null  object
#  36  out_prncp                    466285 non-null  float64
#  37  out_prncp_inv                466285 non-null  float64
#  38  total_pymnt                  466285 non-null  float64
#  39  total_pymnt_inv              466285 non-null  float64
#  40  total_rec_prncp              466285 non-null  float64
#  41  total_rec_int                466285 non-null  float64
#  42  total_rec_late_fee           466285 non-null  float64
#  43  recoveries                   466285 non-null  float64
#  44  collection_recovery_fee      466285 non-null  float64
#  45  last_pymnt_d                 465909 non-null  object
#  46  last_pymnt_amnt              466285 non-null  float64
#  47  next_pymnt_d                 239071 non-null  object
#  48  last_credit_pull_d           466243 non-null  object
#  49  collections_12_mths_ex_med   466140 non-null  float64
#  50  mths_since_last_major_derog  98974 non-null   float64
#  51  policy_code                  466285 non-null  int64
#  52  application_type             466285 non-null  object
#  53  annual_inc_joint             0 non-null       float64
#  54  dti_joint                    0 non-null       float64
#  55  verification_status_joint    0 non-null       float64
#  56  acc_now_delinq               466256 non-null  float64
#  57  tot_coll_amt                 396009 non-null  float64
#  58  tot_cur_bal                  396009 non-null  float64
#  59  open_acc_6m                  0 non-null       float64
#  60  open_il_6m                   0 non-null       float64
#  61  open_il_12m                  0 non-null       float64
#  62  open_il_24m                  0 non-null       float64
#  63  mths_since_rcnt_il           0 non-null       float64
#  64  total_bal_il                 0 non-null       float64
#  65  il_util                      0 non-null       float64
#  66  open_rv_12m                  0 non-null       float64
#  67  open_rv_24m                  0 non-null       float64
#  68  max_bal_bc                   0 non-null       float64
#  69  all_util                     0 non-null       float64
#  70  total_rev_hi_lim             396009 non-null  float64
#  71  inq_fi                       0 non-null       float64
#  72  total_cu_tl                  0 non-null       float64
#  73  inq_last_12m                 0 non-null       float64
# dtypes: float64(46), int64(6), object(22)
# memory usage: 263.3+ MB

# %% [markdown]
# Check the "instance attribute summary" section in this [webpage](https://www.rubydoc.info/gems/lending_club/0.0.2/LendingClub/Loan)

# %% [markdown]
# # Assigning the Target Column to Identify Bad Loans

# %%
# create a new column based on the loan_status column that will be our target variable
data['bad_loan'] = np.where(data.loc[:, 'loan_status'].isin(['Charged Off', 'Default', 'Late (31-120 days)',
                                        'Does not meet the credit policy. Status:Charged Off']), 0, 1)
# Drop the original 'loan_status' column
data.drop(columns = ['loan_status'], inplace = True)

# %%
data['bad_loan']
# Out:
# 0         1
# 1         0
# 2         1
# 3         1
# 4         1
#          ..
# 466280    1
# 466281    0
# 466282    1
# 466283    1
# 466284    1
# Name: bad_loan, Length: 466285, dtype: int64

# %%
X = data.drop('bad_loan', axis = 1)
y = data['bad_loan']

# %%
# display some
data.head(10)
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
# 5  1075269    1311441       5000         5000           5000.0   36 months
# 6  1069639    1304742       7000         7000           7000.0   60 months
# 7  1072053    1288686       3000         3000           3000.0   36 months
# 8  1071795    1306957       5600         5600           5600.0   60 months
# 9  1071570    1306721       5375         5375           5350.0   60 months
#
#    int_rate  installment grade sub_grade  ... il_util open_rv_12m open_rv_24m  \
# 0     10.65       162.87     B        B2  ...     NaN         NaN         NaN
# 1     15.27        59.83     C        C4  ...     NaN         NaN         NaN
# 2     15.96        84.33     C        C5  ...     NaN         NaN         NaN
# 3     13.49       339.31     C        C1  ...     NaN         NaN         NaN
# 4     12.69        67.79     B        B5  ...     NaN         NaN         NaN
# 5      7.90       156.46     A        A4  ...     NaN         NaN         NaN
# 6     15.96       170.08     C        C5  ...     NaN         NaN         NaN
# 7     18.64       109.43     E        E1  ...     NaN         NaN         NaN
# 8     21.28       152.39     F        F2  ...     NaN         NaN         NaN
# 9     12.69       121.45     B        B5  ...     NaN         NaN         NaN
#
#    max_bal_bc all_util total_rev_hi_lim inq_fi total_cu_tl inq_last_12m  \
# 0         NaN      NaN              NaN    NaN         NaN          NaN
# 1         NaN      NaN              NaN    NaN         NaN          NaN
# 2         NaN      NaN              NaN    NaN         NaN          NaN
# 3         NaN      NaN              NaN    NaN         NaN          NaN
# 4         NaN      NaN              NaN    NaN         NaN          NaN
# 5         NaN      NaN              NaN    NaN         NaN          NaN
# 6         NaN      NaN              NaN    NaN         NaN          NaN
# 7         NaN      NaN              NaN    NaN         NaN          NaN
# 8         NaN      NaN              NaN    NaN         NaN          NaN
# 9         NaN      NaN              NaN    NaN         NaN          NaN
#
#   bad_loan
# 0        1
# 1        0
# 2        1
# 3        1
# 4        1
# 5        1
# 6        1
# 7        1
# 8        0
# 9        0
#
# [10 rows x 74 columns]

# %%
#cols that contain missing values
missing_values = data.isnull().mean()
missing_values[missing_values>0].sort_values(ascending=False)
# Out:
# dti_joint                      1.000000
# annual_inc_joint               1.000000
# total_cu_tl                    1.000000
# inq_fi                         1.000000
# all_util                       1.000000
# max_bal_bc                     1.000000
# open_rv_24m                    1.000000
# open_rv_12m                    1.000000
# il_util                        1.000000
# total_bal_il                   1.000000
# mths_since_rcnt_il             1.000000
# open_il_24m                    1.000000
# open_il_12m                    1.000000
# open_il_6m                     1.000000
# open_acc_6m                    1.000000
# verification_status_joint      1.000000
# inq_last_12m                   1.000000
# mths_since_last_record         0.865666
# mths_since_last_major_derog    0.787739
# desc                           0.729815
# mths_since_last_delinq         0.536906
# next_pymnt_d                   0.487286
# total_rev_hi_lim               0.150715
# tot_coll_amt                   0.150715
# tot_cur_bal                    0.150715
# emp_title                      0.059166
# emp_length                     0.045054
# last_pymnt_d                   0.000806
# revol_util                     0.000729
# collections_12_mths_ex_med     0.000311
# last_credit_pull_d             0.000090
# open_acc                       0.000062
# total_acc                      0.000062
# inq_last_6mths                 0.000062
# earliest_cr_line               0.000062
# delinq_2yrs                    0.000062
# acc_now_delinq                 0.000062
# pub_rec                        0.000062
# title                          0.000043
# annual_inc                     0.000009
# dtype: float64

# %% [markdown]
# # Data Preprocessing:
#
# * We need to drop the columns having > 70% missing values.
#
# * The follwing features are identifiers and can not be used in building model. id, member id, url, title, desc, zipcode and emp_title
#
# * The sub_grade column wll also be droped as it contains the same information as the grade columns.
#
# * Features that contain information about the future will not be included in building the model since those events are yet to occur. The features include next_pymnt_d, recoveries, collection_recovery_fee, total_rec_prncp and total_rec_late_fee

# %%
#dropping irrelevant cols & cols with missing values

columns_to_drop = ['id', 'member_id', 'sub_grade', 'emp_title', 'url', 'desc', 'title', 'zip_code', 'next_pymnt_d',
                  'recoveries', 'collection_recovery_fee', 'total_rec_prncp', 'total_rec_late_fee', 'desc', 'mths_since_last_record',
                  'mths_since_last_major_derog', 'annual_inc_joint', 'dti_joint', 'verification_status_joint', 'open_acc_6m', 'open_il_6m',
                  'open_il_12m', 'open_il_24m', 'mths_since_rcnt_il', 'total_bal_il', 'il_util', 'open_rv_12m', 'open_rv_24m',
                  'max_bal_bc', 'all_util', 'inq_fi', 'total_cu_tl', 'inq_last_12m','policy_code',]
data.drop(columns=columns_to_drop, inplace=True, axis=1)

data.dropna(inplace=True)

# %%
data.head()
# Out:
#        loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# 42537      12000        12000          12000.0   36 months      6.62
# 42538      12000        12000          12000.0   36 months     13.53
# 42539      15000        15000          15000.0   36 months      8.90
# 42541      14000        14000          14000.0   36 months     12.85
# 42543      10000        10000          10000.0   36 months      9.67
#
#        installment grade emp_length home_ownership  annual_inc  ...  \
# 42537       368.45     A  10+ years       MORTGAGE    105000.0  ...
# 42538       407.40     B  10+ years           RENT     40000.0  ...
# 42539       476.30     A    2 years       MORTGAGE     63000.0  ...
# 42541       470.71     B    4 years           RENT     88000.0  ...
# 42543       321.13     B    7 years       MORTGAGE    102000.0  ...
#
#       last_pymnt_d last_pymnt_amnt last_credit_pull_d  \
# 42537       Jan-16          368.45             Jan-16
# 42538       Sep-15          119.17             Jan-16
# 42539       Jan-16          476.30             Jan-16
# 42541       Jan-16          470.71             Jan-16
# 42543       Jan-16          321.13             Jan-16
#
#       collections_12_mths_ex_med application_type  acc_now_delinq  \
# 42537                        0.0       INDIVIDUAL             0.0
# 42538                        0.0       INDIVIDUAL             0.0
# 42539                        0.0       INDIVIDUAL             0.0
# 42541                        0.0       INDIVIDUAL             0.0
# 42543                        0.0       INDIVIDUAL             0.0
#
#        tot_coll_amt tot_cur_bal  total_rev_hi_lim  bad_loan
# 42537           0.0    267646.0           61100.0         1
# 42538       15386.0     13605.0            8100.0         1
# 42539        1514.0    272492.0           15400.0         1
# 42541           0.0     17672.0            4500.0         1
# 42543           0.0     39143.0           22300.0         1
#
# [5 rows x 41 columns]

# %%
data.columns
# Out:
# Index(['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate',
#        'installment', 'grade', 'emp_length', 'home_ownership', 'annual_inc',
#        'verification_status', 'issue_d', 'pymnt_plan', 'purpose', 'addr_state',
#        'dti', 'delinq_2yrs', 'earliest_cr_line', 'inq_last_6mths',
#        'mths_since_last_delinq', 'open_acc', 'pub_rec', 'revol_bal',
#        'revol_util', 'total_acc', 'initial_list_status', 'out_prncp',
#        'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv', 'total_rec_int',
#        'last_pymnt_d', 'last_pymnt_amnt', 'last_credit_pull_d',
#        'collections_12_mths_ex_med', 'application_type', 'acc_now_delinq',
#        'tot_coll_amt', 'tot_cur_bal', 'total_rev_hi_lim', 'bad_loan'],
#       dtype='object')

# %% [markdown]
# # Data Type Transformation

# %%
#check datatypes of data again

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 181686 entries, 42537 to 466284
# Data columns (total 41 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   loan_amnt                   181686 non-null  int64
#  1   funded_amnt                 181686 non-null  int64
#  2   funded_amnt_inv             181686 non-null  float64
#  3   term                        181686 non-null  object
#  4   int_rate                    181686 non-null  float64
#  5   installment                 181686 non-null  float64
#  6   grade                       181686 non-null  object
#  7   emp_length                  181686 non-null  object
#  8   home_ownership              181686 non-null  object
#  9   annual_inc                  181686 non-null  float64
#  10  verification_status         181686 non-null  object
#  11  issue_d                     181686 non-null  object
#  12  pymnt_plan                  181686 non-null  object
#  13  purpose                     181686 non-null  object
#  14  addr_state                  181686 non-null  object
#  15  dti                         181686 non-null  float64
#  16  delinq_2yrs                 181686 non-null  float64
#  17  earliest_cr_line            181686 non-null  object
#  18  inq_last_6mths              181686 non-null  float64
#  19  mths_since_last_delinq      181686 non-null  float64
#  20  open_acc                    181686 non-null  float64
#  21  pub_rec                     181686 non-null  float64
#  22  revol_bal                   181686 non-null  int64
#  23  revol_util                  181686 non-null  float64
#  24  total_acc                   181686 non-null  float64
#  25  initial_list_status         181686 non-null  object
#  26  out_prncp                   181686 non-null  float64
#  27  out_prncp_inv               181686 non-null  float64
#  28  total_pymnt                 181686 non-null  float64
#  29  total_pymnt_inv             181686 non-null  float64
#  30  total_rec_int               181686 non-null  float64
#  31  last_pymnt_d                181686 non-null  object
#  32  last_pymnt_amnt             181686 non-null  float64
#  33  last_credit_pull_d          181686 non-null  object
#  34  collections_12_mths_ex_med  181686 non-null  float64
#  35  application_type            181686 non-null  object
#  36  acc_now_delinq              181686 non-null  float64
#  37  tot_coll_amt                181686 non-null  float64
#  38  tot_cur_bal                 181686 non-null  float64
#  39  total_rev_hi_lim            181686 non-null  float64
#  40  bad_loan                    181686 non-null  int64
# dtypes: float64(23), int64(4), object(14)
# memory usage: 58.2+ MB

# %% [markdown]
# The following variables are not possessing appropriate data types and should be modified. Also the NaN values should be replaced with zeroes wherever applicable.
#
# - emp_length,
# - term,
# - issue_d,
# - last_pymnt_d,
# - last_credit_pull_d
# - earliest_cr_line
#
# We will define functions to transform their data types.

# %%
data['emp_length'].value_counts()
# Out:
# 10+ years    69102
# 2 years      15615
# 3 years      14172
# < 1 year     12812
# 5 years      11434
# 1 year       10905
# 7 years      10601
# 4 years      10380
# 6 years      10121
# 8 years       9191
# 9 years       7353
# Name: emp_length, dtype: int64

# %%
# converting emp_length to numeric and assign NaN to zero

def emp_length_convert(df, column):
    # df[column] = df[column].str.replace('\+ years', '')
    df[column] = df[column].str.replace('+', '')
    df[column] = df[column].str.replace('< 1 year', str(0))
    df[column] = df[column].str.replace(' years', '')
    df[column] = df[column].str.replace(' year', '')
    df[column] = pd.to_numeric(df[column])
    df[column].fillna(value = 0, inplace = True)


emp_length_convert(data, 'emp_length')

data['emp_length'].unique()
# Out:
# array([10,  2,  4,  7,  6,  5,  8,  3,  1,  0,  9])

# %%
data['emp_length'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# **Term**

# %%
data['term'].value_counts()
# Out:
#  36 months    129478
#  60 months     52208
# Name: term, dtype: int64

# %%
# converting term to numeric

def term_numeric(df, column):
    df[column] = pd.to_numeric(df[column].str.replace(' months', ''))

term_numeric(data, 'term')

# %%
data['term'].dtype
# Out:
# dtype('int64')

# %%
# preprocessing date cols

def date_columns(df, column):
    # store current month
    today_date = pd.to_datetime('2020-08-01')
    # convert to datetime format
    df[column] = pd.to_datetime(df[column], format = "%b-%y")
    # calculate the difference in months and add to a new column
    df['mths_since_' + column] = round(pd.to_numeric((today_date - df[column]) / np.timedelta64(1, 'M')))
    # make any resulting -ve values to be equal to the max date
    df['mths_since_' + column] = df['mths_since_' + column].apply(lambda x: df['mths_since_' + column].max() if x < 0 else x)
    # drop the original date column
    df.drop(columns = [column], inplace = True)


date_columns(data, 'issue_d')
date_columns(data, 'last_pymnt_d')
date_columns(data, 'last_credit_pull_d')
date_columns(data, 'earliest_cr_line')

# %%
# checking for missing values again

missing_values = data.isnull().sum()
missing_values[missing_values>0]/len(data)
# Out:
# Series([], dtype: float64)

# %% [markdown]
# # Checking Correlation among Features

# %%
numeric_df = data.select_dtypes(include=[np.int64, np.float64])

# %%
# correlation matrix with correlation co-effiecients
import numpy as np
mask = np.zeros_like(numeric_df.corr().fillna(0))
mask[np.triu_indices_from(mask)] = True
plt.figure(figsize=(24,24))
sns.heatmap(numeric_df.corr(), mask=mask, annot=True,  cmap="inferno", vmin = -1, fmt='.1g', edgecolor='w', linewidth=0.6)
# Out:
# <Axes: >

# %% [markdown]
# # Removing Multicollinear Features

# %%
 data.drop(columns=['loan_amnt', 'revol_bal', 'funded_amnt', 'funded_amnt_inv', 'installment',
                   'total_pymnt_inv',  'out_prncp_inv',  'total_acc'], inplace=True)

# %%
numeric_df = data.select_dtypes(include=[np.int64, np.float64])
mask = np.zeros_like(numeric_df.corr().fillna(0))
mask[np.triu_indices_from(mask)] = True
plt.figure(figsize=(24,24))
sns.heatmap(numeric_df.corr(), mask=mask, annot=True,  cmap="inferno", vmin = -1, fmt='.1g', edgecolor='w', linewidth=0.6)
# Out:
# <Axes: >

# %%
##descriptive statistics
data.describe()
# Out:
#                 term       int_rate     emp_length    annual_inc  \
# count  181686.000000  181686.000000  181686.000000  1.816860e+05
# mean       42.896470      14.449868       6.324092  7.886698e+04
# std        10.860692       4.252272       3.607371  6.078531e+04
# min        36.000000       6.000000       0.000000  4.000000e+03
# 25%        36.000000      11.670000       3.000000  5.000000e+04
# 50%        36.000000      14.160000       7.000000  6.800000e+04
# 75%        60.000000      17.140000      10.000000  9.402825e+04
# max        60.000000      26.060000      10.000000  7.500000e+06
#
#                  dti    delinq_2yrs  inq_last_6mths  mths_since_last_delinq  \
# count  181686.000000  181686.000000   181686.000000           181686.000000
# mean       17.389873       0.638040        0.822942               33.724167
# std         7.787230       1.104461        1.059299               21.716923
# min         0.000000       0.000000        0.000000                0.000000
# 25%        11.530000       0.000000        0.000000               15.000000
# 50%        16.910000       0.000000        0.000000               30.000000
# 75%        22.900000       1.000000        1.000000               49.000000
# max        39.990000      29.000000        7.000000              188.000000
#
#             open_acc        pub_rec  ...  collections_12_mths_ex_med  \
# count  181686.000000  181686.000000  ...               181686.000000
# mean       11.756382       0.189244  ...                    0.016418
# std         4.997763       0.557625  ...                    0.149082
# min         1.000000       0.000000  ...                    0.000000
# 25%         8.000000       0.000000  ...                    0.000000
# 50%        11.000000       0.000000  ...                    0.000000
# 75%        14.000000       0.000000  ...                    0.000000
# max        84.000000      21.000000  ...                   20.000000
#
#        acc_now_delinq  tot_coll_amt   tot_cur_bal  total_rev_hi_lim  \
# count   181686.000000  1.816860e+05  1.816860e+05      1.816860e+05
# mean         0.009808  3.263843e+02  1.505644e+05      2.735155e+04
# std          0.107319  2.157745e+04  1.595617e+05      4.243696e+04
# min          0.000000  0.000000e+00  0.000000e+00      1.000000e+02
# 25%          0.000000  0.000000e+00  3.245125e+04      1.230000e+04
# 50%          0.000000  0.000000e+00  9.847150e+04      2.060000e+04
# 75%          0.000000  0.000000e+00  2.255148e+05      3.400000e+04
# max          5.000000  9.152545e+06  8.000078e+06      9.999999e+06
#
#             bad_loan  mths_since_issue_d  mths_since_last_pymnt_d  \
# count  181686.000000       181686.000000            181686.000000
# mean        0.901897           77.987522                59.690532
# std         0.297455            7.312420                 7.251103
# min         0.000000           68.000000                55.000000
# 25%         1.000000           72.000000                55.000000
# 50%         1.000000           77.000000                56.000000
# 75%         1.000000           83.000000                62.000000
# max         1.000000           96.000000                95.000000
#
#        mths_since_last_credit_pull_d  mths_since_earliest_cr_line
# count                  181686.000000                181686.000000
# mean                       56.907192                   284.550026
# std                         4.930061                    82.832749
# min                        55.000000                   107.000000
# 25%                        55.000000                   227.000000
# 50%                        55.000000                   267.000000
# 75%                        55.000000                   326.000000
# max                        95.000000                   619.000000
#
# [8 rows x 25 columns]

# %%
# Final 25 columns
data.columns
# Out:
# Index(['term', 'int_rate', 'grade', 'emp_length', 'home_ownership',
#        'annual_inc', 'verification_status', 'pymnt_plan', 'purpose',
#        'addr_state', 'dti', 'delinq_2yrs', 'inq_last_6mths',
#        'mths_since_last_delinq', 'open_acc', 'pub_rec', 'revol_util',
#        'initial_list_status', 'out_prncp', 'total_pymnt', 'total_rec_int',
#        'last_pymnt_amnt', 'collections_12_mths_ex_med', 'application_type',
#        'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal', 'total_rev_hi_lim',
#        'bad_loan', 'mths_since_issue_d', 'mths_since_last_pymnt_d',
#        'mths_since_last_credit_pull_d', 'mths_since_earliest_cr_line'],
#       dtype='object')

# %%
# data.to_csv('loan-data-25-feats.csv', index=False)

# %% [markdown]
# # Seprating categorical features from numerical

# %%
# seperating categorical features from numerical
categorical_features = data.select_dtypes(exclude='number')
numerical_features = data.select_dtypes(exclude='object')

# %%
# converting to dataframe
filled_data = data

# %%
preprocess_data = data

#checking for any missing values
missing = preprocess_data.isnull().sum()
missing[missing>0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# Finally no missing values

# %% [markdown]
# # Binning, Weight of Evidence (WoE), Information Value (IV)
#
# - **Binning** create buckets of independent variables based on ranking  methods. Binning helps us converting continuous variables into categorical ones. This process allows us to understand feature performance better. The  insights from this part of the analysis can be useful in devising portfolio risk strategies. One simple binning example using "age" is given below for illustration.
#
# ![image.png](data:image/png;base64,...)
#
# - **Weight of Evidence (WoE)** will help us to determine which categories should be binned together. WOE measures the strength of a bin in differentiating the Good and Bad accounts. WOE < 0 indicates that the variable bin is captures higher proportion of bad accounts.
#
#
# - **Information Value (IV)** will help in determining which variables are useful for prediction in the logistic regression model. IV is the measure of overall predictive power of the variables and is very useful for feature selection.
#
#
# **The formular of WoE and IV are as follows:**
#
# $$\text{WoE} = [ln (\frac{\text{Relative frequency of Goods}}{\text{Relative frequency of Bads}})] \times 100$$
#
# $$IV = \sum (\text{Distribution Good}_i - \text{Distribution Bad}_i) \times \text{WoE}_i$$

# %%
#function to calculate Weight of Evidence (WoE) and Information Value (IV)

def iv_woe(data, target, bins=10, show_woe=False):

    new_df,woe_df = pd.DataFrame(), pd.DataFrame()
    cols = data.columns

    #Run WoE and IV on all the independent variables
    for ivars in cols[~cols.isin([target])]:
        if (data[ivars].dtype.kind in 'bifc') and (len(np.unique(data[ivars]))>10):
            binned_x = pd.qcut(data[ivars], bins,  duplicates='drop')
            d0 = pd.DataFrame({'x': binned_x, 'y': data[target]})
        else:
            d0 = pd.DataFrame({'x': data[ivars], 'y': data[target]})
        d = d0.groupby("x", as_index=False).agg({"y": ["count", "sum"]})
        d.columns = ['Cutoff', 'N', 'Events']
        d['% of Events'] = np.maximum(d['Events'], 0.5) / d['Events'].sum()
        d['Non-Events'] = d['N'] - d['Events']
        d['% of Non-Events'] = np.maximum(d['Non-Events'], 0.5) / d['Non-Events'].sum()
        d['WoE'] = np.log(d['% of Events']/d['% of Non-Events'])
        d['IV'] = d['WoE'] * (d['% of Events'] - d['% of Non-Events'])
        d.insert(loc=0, column='Variable', value=ivars)
        print("Information value of " + ivars + " is " + str(round(d['IV'].sum(),6)))
        temp =pd.DataFrame({"Variable" : [ivars], "IV" : [d['IV'].sum()]}, columns = ["Variable", "IV"])
        new_df=pd.concat([new_df,temp], axis=0)
        woe_df=pd.concat([woe_df,d], axis=0)

        if show_woe == True:
            print(d)

    return new_df, woe_df

iv, woe = iv_woe(preprocess_data, target='bad_loan', bins=20)
# Out:
# Information value of term is 0.035478
# Information value of int_rate is 0.347724
# Information value of grade is 0.281145
# Information value of emp_length is 0.007174
# Information value of home_ownership is 0.017952
# Information value of annual_inc is 0.037998
# Information value of verification_status is 0.033377
# Information value of pymnt_plan is 0.000309
# Information value of purpose is 0.028333
# Information value of addr_state is 0.010291
# Information value of dti is 0.041026
# Information value of delinq_2yrs is 0.001039
# Information value of inq_last_6mths is 0.040454
# Information value of mths_since_last_delinq is 0.002487
# Information value of open_acc is 0.004499
# Information value of pub_rec is 0.000504
# Information value of revol_util is 0.008858
# Information value of initial_list_status is 0.011513
# Information value of out_prncp is 0.703375
# Information value of total_pymnt is 0.515794
# Information value of total_rec_int is 0.011108
# Information value of last_pymnt_amnt is 1.491828
# Information value of collections_12_mths_ex_med is 0.000733
# Information value of application_type is 0.0
# Information value of acc_now_delinq is 0.0002
# Information value of tot_coll_amt is 0.000738
# Information value of tot_cur_bal is 0.026379
# Information value of total_rev_hi_lim is 0.018835
# Information value of mths_since_issue_d is 0.09055
# Information value of mths_since_last_pymnt_d is 2.331187
# Information value of mths_since_last_credit_pull_d is 0.313059
# Information value of mths_since_earliest_cr_line is 0.02135

# %%
woe
# Out:
#                        Variable          Cutoff       N  Events  % of Events  \
# 0                          term              36  129478  118188     0.721265
# 1                          term              60   52208   45674     0.278735
# 0                      int_rate   (5.999, 7.69]   10195    9973     0.060862
# 1                      int_rate     (7.69, 8.9]   10280    9878     0.060282
# 2                      int_rate     (8.9, 9.99]    7066    6767     0.041297
# ..                          ...             ...     ...     ...          ...
# 15  mths_since_earliest_cr_line  (326.0, 348.0]    9323    8524     0.052019
# 16  mths_since_earliest_cr_line  (348.0, 371.0]    8945    8178     0.049908
# 17  mths_since_earliest_cr_line  (371.0, 399.0]    8889    8188     0.049969
# 18  mths_since_earliest_cr_line  (399.0, 444.0]    9192    8472     0.051702
# 19  mths_since_earliest_cr_line  (444.0, 619.0]    8962    8290     0.050591
#
#     Non-Events  % of Non-Events       WoE        IV
# 0        11290         0.633416  0.129880  0.011410
# 1         6534         0.366584 -0.273969  0.024068
# 0          222         0.012455  1.586481  0.076797
# 1          402         0.022554  0.983135  0.037092
# 2          299         0.016775  0.900891  0.022091
# ..         ...              ...       ...       ...
# 15         799         0.044827  0.148801  0.001070
# 16         767         0.043032  0.148237  0.001019
# 17         701         0.039329  0.239438  0.002548
# 18         720         0.040395  0.246792  0.002790
# 19         672         0.037702  0.294068  0.003790
#
# [403 rows x 9 columns]

# %%
iv
# Out:
#                         Variable        IV
# 0                           term  0.035478
# 0                       int_rate  0.347724
# 0                          grade  0.281145
# 0                     emp_length  0.007174
# 0                 home_ownership  0.017952
# 0                     annual_inc  0.037998
# 0            verification_status  0.033377
# 0                     pymnt_plan  0.000309
# 0                        purpose  0.028333
# 0                     addr_state  0.010291
# 0                            dti  0.041026
# 0                    delinq_2yrs  0.001039
# 0                 inq_last_6mths  0.040454
# 0         mths_since_last_delinq  0.002487
# 0                       open_acc  0.004499
# 0                        pub_rec  0.000504
# 0                     revol_util  0.008858
# 0            initial_list_status  0.011513
# 0                      out_prncp  0.703375
# 0                    total_pymnt  0.515794
# 0                  total_rec_int  0.011108
# 0                last_pymnt_amnt  1.491828
# 0     collections_12_mths_ex_med  0.000733
# 0               application_type  0.000000
# 0                 acc_now_delinq  0.000200
# 0                   tot_coll_amt  0.000738
# 0                    tot_cur_bal  0.026379
# 0               total_rev_hi_lim  0.018835
# 0             mths_since_issue_d  0.090550
# 0        mths_since_last_pymnt_d  2.331187
# 0  mths_since_last_credit_pull_d  0.313059
# 0    mths_since_earliest_cr_line  0.021350

# %% [markdown]
# The rule of thumb says that all variables with IV < 0.02 are not useful for prediction and IV > 0.5 have a suspicious predictive power. Therefore, the follwing variables will not be included out_prncp, last_pymnt_amnt, delinq_2yrs, mths_since_last_delinq, open_acc, pub_rec, total_acc, collections_12_mths_ex_med, acc_now_delinq, tot_coll_amt and mths_since_last_pymnt_d

# %%
#drop columns with low IV
preprocess_data.drop(columns=[ 'pymnt_plan', 'last_pymnt_amnt', 'revol_util', 'delinq_2yrs', 'mths_since_last_delinq',
                              'open_acc', 'pub_rec',  'collections_12_mths_ex_med', 'acc_now_delinq',
                              'tot_coll_amt', 'mths_since_last_pymnt_d', 'emp_length', 'application_type'], axis=1, inplace=True)

# %%
print(f'Remainning columns : {len(preprocess_data.columns)}')
preprocess_data.columns
# Out:
# Remainning columns : 20
# Index(['term', 'int_rate', 'grade', 'home_ownership', 'annual_inc',
#        'verification_status', 'purpose', 'addr_state', 'dti', 'inq_last_6mths',
#        'initial_list_status', 'out_prncp', 'total_pymnt', 'total_rec_int',
#        'tot_cur_bal', 'total_rev_hi_lim', 'bad_loan', 'mths_since_issue_d',
#        'mths_since_last_credit_pull_d', 'mths_since_earliest_cr_line'],
#       dtype='object')

# %% [markdown]
# # Dummy Variables for Categorical Columns

# %%
# dummy variables for cat cols
data_dummies1 = [pd.get_dummies(preprocess_data['grade'], prefix='grade', prefix_sep=':'),
                 pd.get_dummies(preprocess_data['home_ownership'], prefix='home_ownership', prefix_sep=':'),
                 pd.get_dummies(preprocess_data['verification_status'], prefix='verification_status', prefix_sep=':'),
                 pd.get_dummies(preprocess_data['purpose'], prefix='purpose', prefix_sep=':'),
                 pd.get_dummies(preprocess_data['addr_state'], prefix='addr_state', prefix_sep=':'),
                 pd.get_dummies(preprocess_data['initial_list_status'], prefix='initial_list_status', prefix_sep=':')
                ]

# %%
# turn  data_dummies into dataframe

categorical_dummies = pd.concat(data_dummies1, axis=1)
categorical_dummies.head()
# Out:
#        grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  grade:G  \
# 42537        1        0        0        0        0        0        0
# 42538        0        1        0        0        0        0        0
# 42539        1        0        0        0        0        0        0
# 42541        0        1        0        0        0        0        0
# 42543        0        1        0        0        0        0        0
#
#        home_ownership:ANY  home_ownership:MORTGAGE  home_ownership:NONE  ...  \
# 42537                   0                        1                    0  ...
# 42538                   0                        0                    0  ...
# 42539                   0                        1                    0  ...
# 42541                   0                        0                    0  ...
# 42543                   0                        1                    0  ...
#
#        addr_state:TX  addr_state:UT  addr_state:VA  addr_state:VT  \
# 42537              0              0              0              0
# 42538              0              0              0              0
# 42539              0              0              0              0
# 42541              0              0              0              0
# 42543              0              0              0              0
#
#        addr_state:WA  addr_state:WI  addr_state:WV  addr_state:WY  \
# 42537              0              0              0              0
# 42538              0              0              0              0
# 42539              0              0              0              0
# 42541              0              0              0              0
# 42543              0              0              0              0
#
#        initial_list_status:f  initial_list_status:w
# 42537                      0                      1
# 42538                      0                      1
# 42539                      0                      1
# 42541                      1                      0
# 42543                      1                      0
#
# [5 rows x 78 columns]

# %%
# concatinating preprocess_data with categorical_dummies

preprocess_data = pd.concat([preprocess_data, categorical_dummies], axis=1)

# %%
# function to calculate WoE of cat features

def woe_categorical(df, cat_feature, good_bad_df):
    df = pd.concat([df[cat_feature], good_bad_df], axis=1)
    df = pd.concat([df.groupby(df.columns.values[0], as_index = False)[df.columns.values[1]].count(),
                    df.groupby(df.columns.values[0], as_index = False)[df.columns.values[1]].mean()], axis = 1)

    df = df.iloc[:, [0, 1, 3]]
    df.columns = [df.columns.values[0], 'n_obs', 'prop_good']
    df['prop_n_obs'] = df['n_obs'] / df['n_obs'].sum()
    df['n_good'] = df['prop_good'] * df['n_obs']
    df['n_bad'] = (1 - df['prop_good']) * df['n_obs']
    df['prop_n_good'] = df['n_good'] / df['n_good'].sum()
    df['prop_n_bad'] = df['n_bad'] / df['n_bad'].sum()

    df['WoE'] = np.log(df['prop_n_good'] / df['prop_n_bad'])
    df = df.sort_values(['WoE'])
    df = df.reset_index(drop = True)
    df['diff_prop_good'] = df['prop_good'].diff().abs()
    df['diff_WoE'] = df['WoE'].diff().abs()

    df['IV'] = (df['prop_n_good'] - df['prop_n_bad']) * df['WoE']
    df['IV'] = df['IV'].sum()
    return df

# %%
# function to plot WoE
import numpy as np

def plot_by_woe(df_WoE, rotation_of_x_axis_labels = 0):
    x = np.array(df_WoE.iloc[:, 0].apply(str))
    y = df_WoE['WoE']
    plt.figure(figsize=(18, 12))
    plt.plot(x, y, marker = 'o', color = 'hotpink', linestyle = 'dashed', linewidth = 3, markersize = 18, markeredgecolor = 'cyan', markerfacecolor = 'black')
    plt.xlabel(df_WoE.columns[0])
    plt.ylabel('Weight of Evidence')
    plt.title(str('Weight of Evidence by ' + df_WoE.columns[0]), size = 20)
    plt.xticks(rotation = rotation_of_x_axis_labels)
    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.show()

# %%
#seperating data into target and features
X= preprocess_data.drop(columns='bad_loan', axis=1)
y=preprocess_data['bad_loan']

# %% [markdown]
# # Analyzing Categorical Variables by Plotting WoE

# %% [markdown]
# **1. Analyzing Grade variable**

# %%
df_grade = woe_categorical(X, 'grade', y)
plot_by_woe(df_grade)

# %% [markdown]
# We can see from the above graph that the grades have significantly different woe as we grade changes. We will therefore keep each grade as a feature.

# %% [markdown]
# **2. Analyzing Home Ownership variable**

# %%
df_home = woe_categorical(X, 'home_ownership', y)
plot_by_woe(df_home)

# %% [markdown]
# OTHER, NONE and ANY have very few observations and should be combined with the category with high risk of default that is RENT

# %% [markdown]
# **3. Analyzing Verification status variable**

# %%
veri_df = woe_categorical(X, 'verification_status', y)
plot_by_woe(veri_df)

# %% [markdown]
# This variable has different WoE values and can be used as seperate variables

# %% [markdown]
# **4. Analyzing Purpose variable**

# %%
pur_df = woe_categorical(X, 'purpose', y)
plot_by_woe(pur_df, 90)

# %% [markdown]
# The following categories wil be combined together:
#
# educational, renewable_energy, moving
# other,house, medical
# weeding, vacation
# debt_consolidation
# home_improvement, major purchase
# car, credit_card

# %% [markdown]
# **5. Analyzing address-state variable**

# %%
addr_df = woe_categorical(X, 'addr_state', y)
plot_by_woe(addr_df)

# %% [markdown]
# The states NE, IA, ME and ID have low observations and this may be the reason for their extreme woe. We will plot the graph again excluding these categories and see if there is any change.

# %%
data1 =addr_df.iloc[2:44, :]
data2 =addr_df.iloc[45:49, :]
low_data_woe = pd.concat([data1, data2], axis=0)
plot_by_woe(low_data_woe)

# %% [markdown]
# In deciding which categories to combine we use both WOE and the number of observations in our analysis. Categories with similar WoE but significantly different observations will not be combined together, because the number of observations can influence the WoE values. Also, categories with both similar WoE and observations greater than 5% can be combined together to form a new category. This process will be used for the rest of analysis.The categories to be combined as follows:
#
# - NE, IA, NV, HI, FL, AL
# - NY
# - LA, NM, OK, NC, MO, MD, NJ, VA
# - CA
# - AZ, MI, UT, TN, AR, PA
# - RI, OH, KY, DE, MN, SD, MA, IN
# - GA, WA
# - WI, OR
# - TX
# - IL, CT,MT
# - CO, SC
# - KS, VT, AK, MS
# - NH, WV, WY, DC
#
# In total we will have to create 13 categories for the addr_variable. We will create these variables later. Let us move on to analyze the rest of the features.

# %% [markdown]
# **6. Analyzing initial list status variable**

# %%
init_list_df = woe_categorical( X, 'initial_list_status', y)
plot_by_woe(init_list_df)

# %% [markdown]
# This variable has significantly different WoE values and categories should be kept as seperate variables

# %% [markdown]
# # Analyzing Continous Variables by Plotting WoE

# %%
# function to calculate WoE for continous variables
def woe_continous(df, cat_feature, good_bad_df):
    df = pd.concat([df[cat_feature], good_bad_df], axis=1)
    df = pd.concat([df.groupby(df.columns.values[0], as_index = False)[df.columns.values[1]].count(),
                    df.groupby(df.columns.values[0], as_index = False)[df.columns.values[1]].mean()], axis = 1)
    df = df.iloc[:, [0, 1, 3]]
    df.columns = [df.columns.values[0], 'n_obs', 'prop_good']
    df['prop_n_obs'] = df['n_obs'] / df['n_obs'].sum()
    df['n_good'] = df['prop_good'] * df['n_obs']
    df['n_bad'] = (1 - df['prop_good']) * df['n_obs']
    df['prop_n_good'] = df['n_good'] / df['n_good'].sum()
    df['prop_n_bad'] = df['n_bad'] / df['n_bad'].sum()
    df['WoE'] = np.log(df['prop_n_good'] / df['prop_n_bad'])
    df['diff_prop_good'] = df['prop_good'].diff().abs()
    df['diff_WoE'] = df['WoE'].diff().abs()
    df['IV'] = (df['prop_n_good'] - df['prop_n_bad']) * df['WoE']
    df['IV'] = df['IV'].sum()
    return df

# %% [markdown]
# **1. Analyzing term variable**

# %%
plot_by_woe(woe_continous(X,'term', y ))

# %% [markdown]
# **2. Analyzing months since issued variable**

# %%
X['mths_since_issue_d'].unique()
# Out:
# array([80., 81., 82., 83., 84., 85., 86., 87., 88., 89., 90., 91., 92.,
#        93., 94., 95., 96., 68., 69., 70., 71., 72., 73., 74., 75., 76.,
#        77., 78., 79.])

# %%
# fine class by creating  a new var

X['mths_since_issue_d_factor'] = pd.cut(X['mths_since_issue_d'], 10)
mths_since_iss_df = woe_continous(X, 'mths_since_issue_d_factor', y)
plot_by_woe(mths_since_iss_df)

# %% [markdown]
# The follwing categories will be created based on their WoE and number of observations
#
# - (67.97, 70.8)
# - (70.8, 73.6)
# - (73.6- 76.4)
# - (76.4.- 79.2)
# - (79.2-82)
# - (82-84)
# - (84-90.4)
# - (90.4-96)

# %% [markdown]
# **3. Analyzing interest rate variable**

# %%
X['int_rate_factor'] = pd.cut(X['int_rate'], 10)
int_rate_df = woe_continous(X, 'int_rate_factor',y)
plot_by_woe(int_rate_df,90)

# %% [markdown]
# From the graph above only the last two categories will be combined.
#
# (22.048, 26)

# %% [markdown]
# **4. Analyzing total_rec_int variable**

# %%
X['total_rec_int_factor'] = pd.cut(X['total_rec_int'], 20)
rec_int_df = woe_continous(X, 'total_rec_int_factor', y)
plot_by_woe(rec_int_df, 90)

# %% [markdown]
# **5. Analyzing toal revolving_high_limit variable**

# %%
X['total_rev_hi_lim_factor'] = pd.cut(X['total_rev_hi_lim'], 100)
revol_hi_df = woe_continous(X, 'total_rev_hi_lim_factor', y)
# plot_by_woe(revol_hi_df, 90)

# %%
#analyzing below 100000
X_train_prepr_temp = X[X['total_rev_hi_lim'] <= 100000].copy()
# fine-classing
X_train_prepr_temp['total_rev_hi_lim_factor'] = pd.cut(X_train_prepr_temp['total_rev_hi_lim'],10)
# select only the relevant index in the target col
df_temp = woe_continous(X_train_prepr_temp, 'total_rev_hi_lim_factor', y[X_train_prepr_temp.index])
plot_by_woe(df_temp, 90)

# %% [markdown]
# **6. Analyzing total_payment variable**

# %%
X['total_pymnt_factor'] = pd.cut(X['total_pymnt'], 10)
total_pym_df = woe_continous(X, 'total_pymnt_factor', y)
plot_by_woe(total_pym_df,90)

# %% [markdown]
# **7. Analyzing dti variable**
#
# "dti" is a ratio calculated using the borrower’s total monthly debt payments on the total debt obligations, excluding mortgage and the requested LC loan, divided by the borrower’s self-reported monthly income.

# %%
X['dti_factor'] = pd.cut(X['dti'], 10)
dti_df = woe_continous(X, 'dti_factor', y)
plot_by_woe(dti_df)

# %% [markdown]
# The following categories will be combined:
#
# (27.993, 31.992), (31.992, 35.991), (35.991, 39.99)

# %% [markdown]
# **8. Analyzing annual_income variable**

# %%
X['annual_inc_factor'] = pd.cut(X['annual_inc'], 50)
ann_inc_df = woe_continous(X, 'annual_inc_factor', y)
plot_by_woe(ann_inc_df, 90)

# %% [markdown]
# We will seperate this variable into people with higher and lower incomes. From the WoE table, we observe, when annual income increases, the the number of observations decreases. This is because only a few people earn high income. We will use a new variable for people with income above 150000 dollars. And also, analyze individuals with income below 150000 dollars.

# %%
#Analyzing income  below 150000
X_train_prepr_temp = X[X['annual_inc'] <= 150000].copy()
# fine-classing
X_train_prepr_temp['annual_inc_factor'] = pd.cut(X_train_prepr_temp['annual_inc'], 10)
# select only the relevant index in the target col
df_temp = woe_continous(X_train_prepr_temp, 'annual_inc_factor', y[X_train_prepr_temp.index])
plot_by_woe(df_temp, 90)

# %% [markdown]
# From the graph, we will combine the follwing categories based on WoE and number of observations as follows:
# - (<=32000),
# - (>32000 <= 50000),
# - (>50000 <= 60000),
# - (>60000 <=75000),
# - (>75000 <=90000),
# - (>90000 <=120000),
# - (>120000 <=135000),
# - (>135000 <=150000),
# - (>150000)

# %% [markdown]
# **9. Analyzing inq_last_6mths variable**
#
# inq_last_6mths denote the number of inquiries in last 6 months

# %%
X['inq_last_6mths_factor'] = pd.cut(X['inq_last_6mths'], 7)
inq_fact_df = woe_continous(X, 'inq_last_6mths_factor', y)
plot_by_woe(inq_fact_df)

# %% [markdown]
# The follwing categories will be created
#
# - <1 months,
# - 1-2,
# - 2-4,
# - 4-7

# %% [markdown]
# **10. Analyzing total current balance variable**

# %%
X['tot_cur_bal_factor'] = pd.cut(X['tot_cur_bal'], 20)
curr_bal_df = woe_continous(X, 'tot_cur_bal_factor', y)
plot_by_woe(curr_bal_df, 90)

# %%
#Analyzing current balance  below 400000
X_train_prepr_temp = X[X['tot_cur_bal'] <= 400000].copy()
# fine-classing
X_train_prepr_temp['tot_cur_bal_factor'] = pd.cut(X_train_prepr_temp['tot_cur_bal'], 10)
# select only the relevant index in the target column
df_temp = woe_continous(X_train_prepr_temp, 'tot_cur_bal_factor', y[X_train_prepr_temp.index])
plot_by_woe(df_temp, 90)

# %% [markdown]
# the following variables will be created:
# - <40000,
# - 40000-80000,
# - 80000-120000,
# - 120000-160000,
# - 160000-200000,
# - 200000-240000,
# - 240000-320000,
# - 320000-400000

# %% [markdown]
# **11. Analyzing months since credit pulled variable**

# %%
X['mths_since_last_credit_pull_d_factor'] = pd.cut(X['mths_since_last_credit_pull_d'], 10)
mths_cr_pull_df = woe_continous(X, 'mths_since_last_credit_pull_d_factor', y)
plot_by_woe(mths_cr_pull_df)

# %%
#Analyzing mths_since_credit_pull  below 60
X_train_prepr_temp = X[X['mths_since_last_credit_pull_d'] <= 60].copy()
# fine-classing
X_train_prepr_temp['mths_since_last_credit_pull_d'] = pd.cut(X_train_prepr_temp['mths_since_last_credit_pull_d'], 5)
# select only the relevant index in the target column
df_temp = woe_continous(X_train_prepr_temp, 'mths_since_last_credit_pull_d', y[X_train_prepr_temp.index])
plot_by_woe(df_temp)

# %% [markdown]
# The following categories will be grouped together:
# - 54-65,
# - 65-76,
# - greater than 76

# %% [markdown]
# **12. Analyzing out_prncp_factor variable**
#
# "out_prncp_factor" denotes remaining outstanding principal for total amount funded

# %%
X['out_prncp_factor'] = pd.cut(X['out_prncp'], 10)
out_df = woe_continous(X, 'out_prncp_factor', y)
plot_by_woe(out_df, 90)

# %% [markdown]
# **13. Analyzing months_since_issue_date variable**

# %%
X['mths_since_issue_d'] = pd.cut(X['mths_since_issue_d'], 10)
iss_df = woe_continous(X, 'mths_since_issue_d', y)
plot_by_woe(iss_df)

# %% [markdown]
# # Creating New Features Based on WoE

# %%
# grade

new_df = preprocess_data.loc[:, 'grade:A':'grade:G']

# home_ownership

new_df['home_ownership:OWN'] = preprocess_data.loc[:, 'home_ownership:OWN']
new_df['home_ownership:OTHER_NONE_RENT_ANY'] = sum([preprocess_data['home_ownership:OTHER'],
                                                    preprocess_data['home_ownership:NONE'],
                                                    preprocess_data['home_ownership:RENT'],
                                                    preprocess_data['home_ownership:ANY']])
new_df['home_ownership:MORTGAGE'] = preprocess_data.loc[:, 'home_ownership:MORTGAGE']

#verification status
new_df['verification_status:NOT_VERIFIED'] = preprocess_data.loc[:, 'verification_status:Not Verified']
new_df['verification_status:SOURCE_VERIFIED'] = preprocess_data.loc[:, 'verification_status:Source Verified']
new_df['verification_status:VERIFIED'] = preprocess_data.loc[:, 'verification_status:Verified']

# purpose of loan
new_df['purpose:SMALL_BUSINESS_EDUCATIONAL_RENEWABLE_ENERGY_MOVING'] = sum([preprocess_data['purpose:small_business'],  preprocess_data['purpose:renewable_energy'], preprocess_data['purpose:moving']])
new_df['purpose:OTHER_HOUSE_MEDICAL'] =sum([preprocess_data['purpose:other'], preprocess_data['purpose:house'], preprocess_data['purpose:medical']])
new_df ['purpose:WEDDING_VACATION'] = sum([preprocess_data['purpose:wedding'], preprocess_data['purpose:vacation']])
new_df ['purpose:HOME_IMPROVEMENT_MAJOR_PURCHASE'] = sum([preprocess_data['purpose:home_improvement'], preprocess_data['purpose:major_purchase']])
new_df ['purpose:CAR_CREDIT_CARD'] = sum([preprocess_data['purpose:car'], preprocess_data['purpose:credit_card']])


# addr state
new_df['addr_state:NE_IA_NV_HI_FL_AL'] =sum([preprocess_data['addr_state:IA'],preprocess_data['addr_state:NV'],
                                             preprocess_data['addr_state:HI'],preprocess_data['addr_state:FL'],
                                             preprocess_data['addr_state:AL']])
new_df['addr_state:NY'] = preprocess_data.loc[:, 'addr_state:NY']
new_df['addr_state:LA_NM_OK_NC_MO_MD_NJ_VA'] = sum([preprocess_data['addr_state:LA'],preprocess_data['addr_state:NM'],preprocess_data['addr_state:OK'],
                                                    preprocess_data['addr_state:NC'],preprocess_data['addr_state:MO'],preprocess_data['addr_state:MD'], preprocess_data['addr_state:NJ'],
                                                    preprocess_data['addr_state:VA']])
new_df['addr_state:CA'] = preprocess_data.loc[:,'addr_state:CA']
new_df['addr_state:AZ_MI_UT_TN_AR_PA'] =sum([preprocess_data['addr_state:AZ'],preprocess_data['addr_state:MI'],preprocess_data['addr_state:UT'],
preprocess_data['addr_state:TN'],preprocess_data['addr_state:AR'],preprocess_data['addr_state:PA']])

new_df['addr_state:RI_OH_KY_DE_MN_SD_MA_IN'] =sum([preprocess_data['addr_state:RI'],preprocess_data['addr_state:OH'],preprocess_data['addr_state:KY'],
                                                   preprocess_data['addr_state:DE'],preprocess_data['addr_state:MN'],preprocess_data['addr_state:SD'],preprocess_data['addr_state:MA'],
                                                   preprocess_data['addr_state:IN']])

new_df['addr_state:GA_WA'] = sum([preprocess_data['addr_state:GA'], preprocess_data['addr_state:WA']])
new_df['addr_state:WI_OR'] = sum([preprocess_data['addr_state:WI'], preprocess_data['addr_state:OR']])
new_df['addr_state:TX'] = preprocess_data.loc[:,'addr_state:TX']
new_df['addr_state:IL_CT_MT'] =sum([preprocess_data['addr_state:IL'],preprocess_data['addr_state:CT'],preprocess_data['addr_state:MT']])
new_df['addr_state:CO_SC'] = sum([preprocess_data['addr_state:CO'], preprocess_data['addr_state:SC']])
new_df['addr_state:KS_VT_AK_NS'] =sum([preprocess_data['addr_state:KS'],preprocess_data['addr_state:VT'],preprocess_data['addr_state:AK'],
                                           preprocess_data['addr_state:MS']])
new_df['addr_state:NH_WV_WY_DC'] =sum([preprocess_data['addr_state:NH'],preprocess_data['addr_state:WV'],preprocess_data['addr_state:WY'],
                                           preprocess_data['addr_state:DC']])
#initial_list_status
new_df['initial_list_status:F'] = preprocess_data.loc[:, 'initial_list_status:f']
new_df['initial_list_status:W'] = preprocess_data.loc[:, 'initial_list_status:w']

# term
new_df['term:36'] = np.where((preprocess_data['term'] == 36), 1, 0)
new_df['term:60'] = np.where((preprocess_data['term']==60), 1,0)

#total_rec_int
new_df['total_rec_int:<1000'] = np.where((preprocess_data['total_rec_int']<=1000), 1,0)
new_df['total_rec_int:1000-2000'] = np.where((preprocess_data['total_rec_int']>1000) &(preprocess_data['total_rec_int']<=2000), 1,0)
new_df['total_rec_int:2000-9000'] = np.where((preprocess_data['total_rec_int']>2000) &(preprocess_data['total_rec_int']<=9000), 1,0)
new_df['total_rec_int:>9000'] = np.where((preprocess_data['total_rec_int']>9000), 1,0)


#total_revol_hi_lim
new_df['total_rev_hi_lim:<10000'] =np.where((preprocess_data['total_rev_hi_lim']<=10000),1,0)
new_df['total_rev_hi_lim:10000-20000'] =np.where((preprocess_data['total_rev_hi_lim']>10000)&(preprocess_data['total_rev_hi_lim']<=20000),1,0)
new_df['total_rev_hi_lim:20000-40000'] =np.where((preprocess_data['total_rev_hi_lim']>20000)&(preprocess_data['total_rev_hi_lim']<=40000),1,0)
new_df['total_rev_hi_lim:40000-60000'] =np.where((preprocess_data['total_rev_hi_lim']>40000)&(preprocess_data['total_rev_hi_lim']<=60000),1,0)
new_df['total_rev_hi_lim:60000-80000'] =np.where((preprocess_data['total_rev_hi_lim']>60000)&(preprocess_data['total_rev_hi_lim']<=80000),1,0)
new_df['total_rev_hi_lim:80000-100000'] =np.where((preprocess_data['total_rev_hi_lim']>80000)&(preprocess_data['total_rev_hi_lim']<=100000),1,0)
new_df['total_rev_hi_lim:<100000'] =np.where((preprocess_data['total_rev_hi_lim']>100000),1,0)


#total_pymnt
new_df['total_pymnt:<5000'] = np.where((preprocess_data['total_pymnt']<=5000), 1,0)
new_df['total_pymnt:5000-11000'] = np.where((preprocess_data['total_pymnt']>5000)&(preprocess_data['total_pymnt']<=11000),1,0)
new_df['total_pymnt:11000-16000'] = np.where((preprocess_data['total_pymnt']>11000)&(preprocess_data['total_pymnt']<=16000),1,0)
new_df['total_pymnt:16000-22000'] = np.where((preprocess_data['total_pymnt']>16000)&(preprocess_data['total_pymnt']<=22000),1,0)
new_df['total_pymnt:>22000'] = np.where((preprocess_data['total_pymnt']<=5000), 1,0)
#int_Rate

new_df['int_rate:<7.484'] = np.where((preprocess_data['int_rate'] <= 7.484), 1, 0)
new_df['int_rate:7.484-9.548'] = np.where((preprocess_data['int_rate'] > 7.484) & (preprocess_data['int_rate'] <= 9.548), 1, 0)
new_df['int_rate:9.548-11.612'] = np.where((preprocess_data['int_rate'] > 9.548) & (preprocess_data['int_rate'] <= 11.612), 1, 0)
new_df['int_rate:11.612-13.676'] = np.where((preprocess_data['int_rate'] > 11.612) & (preprocess_data['int_rate'] <= 13.676), 1, 0)
new_df['int_rate:13.676-15.74'] = np.where((preprocess_data['int_rate'] > 13.676) & (preprocess_data['int_rate'] <= 15.74), 1, 0)
new_df['int_rate:15.74-17.804'] = np.where((preprocess_data['int_rate'] > 15.74) & (preprocess_data['int_rate'] <= 17.804), 1, 0)
new_df['int_rate:17.804-19.868'] = np.where((preprocess_data['int_rate'] > 17.804) & (preprocess_data['int_rate'] <= 19.868), 1, 0)
new_df['int_rate:7.19.868-21.932'] = np.where((preprocess_data['int_rate'] > 19.868) & (preprocess_data['int_rate'] <= 21.932), 1, 0)
new_df['int_rate:21.932-26.06'] = np.where((preprocess_data['int_rate'] > 21.932) & (preprocess_data['int_rate'] <= 26.06), 1, 0)


#dti
new_df['dti:<4'] = np.where((preprocess_data['dti'] <=4), 1, 0)
new_df['dti:4-8'] = np.where((preprocess_data['dti'] > 4) & (preprocess_data['dti'] <= 8), 1, 0)
new_df['dti:8-12'] = np.where((preprocess_data['dti'] > 8) & (preprocess_data['dti'] <= 12), 1, 0)
new_df['dti:12-16'] = np.where((preprocess_data['dti'] > 12) & (preprocess_data['dti'] <= 16), 1, 0)
new_df['dti:16-20'] = np.where((preprocess_data['dti'] > 16) & (preprocess_data['dti'] <= 20), 1, 0)
new_df['dti:20-23'] = np.where((preprocess_data['dti'] > 20) & (preprocess_data['dti'] <= 23), 1, 0)
new_df['dti:23-27'] = np.where((preprocess_data['dti'] > 23) & (preprocess_data['dti'] <= 27), 1, 0)
new_df['dti:27-40'] = np.where((preprocess_data['dti'] > 27) & (preprocess_data['dti'] <= 40), 1, 0)

#annual income
new_df['annual_inc:<32000'] = np.where((preprocess_data['annual_inc'] <= 32000), 1, 0)
new_df['annual_inc:32000-50000'] = np.where((preprocess_data['annual_inc'] > 32000) & (preprocess_data['annual_inc'] <= 50000),1, 0)
new_df['annual_inc:32000-50000'] = np.where((preprocess_data['annual_inc'] > 32000) & (preprocess_data['annual_inc'] <= 50000), 1, 0)
new_df['annual_inc:50000-60000'] = np.where((preprocess_data['annual_inc'] > 50000) & (preprocess_data['annual_inc'] <= 60000), 1, 0)
new_df['annual_inc:60000-75000'] = np.where((preprocess_data['annual_inc'] > 60000) & (preprocess_data['annual_inc'] <= 75000), 1, 0)
new_df['annual_inc:75000-90000'] = np.where((preprocess_data['annual_inc'] > 75000) & (preprocess_data['annual_inc'] <= 90000), 1, 0)
new_df['annual_inc:90000-120000'] = np.where((preprocess_data['annual_inc'] > 90000) & (preprocess_data['annual_inc'] <= 120000), 1, 0)
new_df['annual_inc:120000-135000'] = np.where((preprocess_data['annual_inc'] > 120000) & (preprocess_data['annual_inc'] <= 135000), 1, 0)
new_df['annual_inc:135000-150000'] = np.where((preprocess_data['annual_inc'] > 135000) & (preprocess_data['annual_inc'] <= 150000), 1, 0)
new_df['annual_inc:>150000'] = np.where((preprocess_data['annual_inc'] > 150000), 1, 0)

#inq_last_6mths
new_df['inq_last_6mths:<1'] = np.where((preprocess_data['inq_last_6mths'] <=1), 1, 0)
new_df['inq_last_6mths:1-2'] = np.where((preprocess_data['inq_last_6mths'] >1)& (preprocess_data['inq_last_6mths']<=2),  1, 0)
new_df['inq_last_6mths:2-4'] = np.where((preprocess_data['inq_last_6mths'] >2)& (preprocess_data['inq_last_6mths']<=4),  1, 0)
new_df['inq_last_6mths:4-7'] = np.where((preprocess_data['inq_last_6mths'] >4)& (preprocess_data['inq_last_6mths']<=7),  1, 0)

#tot_cur_balance
new_df['tot_cur_bal:<40000'] = np.where((preprocess_data['tot_cur_bal'] <= 40000), 1, 0)
new_df['tot_cur_bal:40000-80000'] = np.where((preprocess_data['tot_cur_bal'] > 40000) & (preprocess_data['tot_cur_bal'] <= 80000), 1, 0)
new_df['tot_cur_bal:80000-120000'] = np.where((preprocess_data['tot_cur_bal'] > 120000) & (preprocess_data['tot_cur_bal'] <= 160000), 1, 0)
new_df['tot_cur_bal:120000-160000'] = np.where((preprocess_data['tot_cur_bal'] > 120000) & (preprocess_data['tot_cur_bal'] <= 160000), 1, 0)
new_df['tot_cur_bal:160000-200000'] = np.where((preprocess_data['tot_cur_bal'] > 160000) & (preprocess_data['tot_cur_bal'] <= 200000), 1, 0)
new_df['tot_cur_bal:200000-240000'] = np.where((preprocess_data['tot_cur_bal'] > 200000) & (preprocess_data['tot_cur_bal'] <= 240000), 1, 0)
new_df['tot_cur_bal:240000-320000'] = np.where((preprocess_data['tot_cur_bal'] > 240000) & (preprocess_data['tot_cur_bal'] <= 320000), 1, 0)
new_df['tot_cur_bal:320000-400000'] = np.where((preprocess_data['tot_cur_bal'] > 320000) & (preprocess_data['tot_cur_bal'] <= 400000), 1, 0)
new_df['tot_cur_bal:>400000'] = np.where((preprocess_data['tot_cur_bal'] > 400000), 1, 0)

#mths_since_last_credit_pull_d
new_df['mths_since_last_credit_pull_d:<65'] = np.where((preprocess_data['mths_since_last_credit_pull_d']<=65), 1,0)
new_df['mths_since_last_credit_pull_d:65-76'] = np.where((preprocess_data['mths_since_last_credit_pull_d']>65)&(preprocess_data['mths_since_last_credit_pull_d']<=76),1,0)
new_df['mths_since_last_credit_pull_d:>76'] = np.where((preprocess_data['mths_since_last_credit_pull_d']>76), 1,0)

#mths_since_issue_d_factor
new_df['mths_since_issue_d_:<70.8'] = np.where((preprocess_data['mths_since_issue_d']<=70.8), 1,0)
new_df['mths_since_issue_d_:>70.8-73.6'] = np.where((preprocess_data['mths_since_issue_d'] >70.8) & (preprocess_data['mths_since_issue_d']<=73.6), 1,0)
new_df['mths_since_issue_d_:73.6-76.4'] = np.where((preprocess_data['mths_since_issue_d']>70.8) & (preprocess_data['mths_since_issue_d']<=76.4), 1,0)
new_df['mths_since_issue_d_:>76.4-79.2'] = np.where((preprocess_data['mths_since_issue_d'] >76.4) & (preprocess_data['mths_since_issue_d']<=79.2), 1,0)
new_df['mths_since_issue_d_:>79.2-82'] = np.where((preprocess_data['mths_since_issue_d'] >79.2) & (preprocess_data['mths_since_issue_d']<=82), 1,0)
new_df['mths_since_issue_d_>82-84'] = np.where((preprocess_data['mths_since_issue_d'] >82) & (preprocess_data['mths_since_issue_d']<=84), 1,0)
new_df['mths_since_issue_d_:>84-90.4'] = np.where((preprocess_data['mths_since_issue_d'] >84) & (preprocess_data['mths_since_issue_d']<=90.4), 1,0)
new_df['mths_since_issue_d_:>90.4-96'] = np.where((preprocess_data['mths_since_issue_d'] >90.4) & (preprocess_data['mths_since_issue_d']<=96), 1,0)

new_df['out_prncp:<3000'] = np.where((preprocess_data['out_prncp']<=3000), 1,0)
new_df['out_prncp:3000-6000'] = np.where((preprocess_data['out_prncp']>3000)&(preprocess_data['out_prncp']<=6000), 1,0)
new_df['out_prncp:6000-10000'] = np.where((preprocess_data['out_prncp']>6000)&(preprocess_data['out_prncp']<=10000), 1,0)
new_df['out_prncp:10000-12000'] = np.where((preprocess_data['out_prncp']>10000)&(preprocess_data['out_prncp']<=12000), 1,0)
new_df['out_prncp:>12000'] = np.where((preprocess_data['out_prncp']>12000), 1,0)

new_df['bad_loan'] = preprocess_data.loc[:, 'bad_loan']

# %%
#Displaying first 10 rows of new_df
pd.options.display.max_columns = None
new_df.head(10)
# Out:
#        grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  grade:G  \
# 42537        1        0        0        0        0        0        0
# 42538        0        1        0        0        0        0        0
# 42539        1        0        0        0        0        0        0
# 42541        0        1        0        0        0        0        0
# 42543        0        1        0        0        0        0        0
# 42544        0        1        0        0        0        0        0
# 42547        0        0        0        1        0        0        0
# 42548        0        0        1        0        0        0        0
# 42555        0        1        0        0        0        0        0
# 42558        0        0        0        1        0        0        0
#
#        home_ownership:OWN  home_ownership:OTHER_NONE_RENT_ANY  \
# 42537                   0                                   0
# 42538                   0                                   1
# 42539                   0                                   0
# 42541                   0                                   1
# 42543                   0                                   0
# 42544                   0                                   1
# 42547                   0                                   0
# 42548                   0                                   0
# 42555                   0                                   1
# 42558                   0                                   1
#
#        home_ownership:MORTGAGE  verification_status:NOT_VERIFIED  \
# 42537                        1                                 1
# 42538                        0                                 0
# 42539                        1                                 1
# 42541                        0                                 1
# 42543                        1                                 1
# 42544                        0                                 0
# 42547                        1                                 0
# 42548                        1                                 1
# 42555                        0                                 0
# 42558                        0                                 1
#
#        verification_status:SOURCE_VERIFIED  verification_status:VERIFIED  \
# 42537                                    0                             0
# 42538                                    1                             0
# 42539                                    0                             0
# 42541                                    0                             0
# 42543                                    0                             0
# 42544                                    0                             1
# 42547                                    1                             0
# 42548                                    0                             0
# 42555                                    0                             1
# 42558                                    0                             0
#
#        purpose:SMALL_BUSINESS_EDUCATIONAL_RENEWABLE_ENERGY_MOVING  \
# 42537                                                  0
# 42538                                                  0
# 42539                                                  0
# 42541                                                  0
# 42543                                                  0
# 42544                                                  0
# 42547                                                  0
# 42548                                                  0
# 42555                                                  0
# 42558                                                  0
#
#        purpose:OTHER_HOUSE_MEDICAL  purpose:WEDDING_VACATION  \
# 42537                            0                         0
# 42538                            0                         0
# 42539                            0                         0
# 42541                            0                         0
# 42543                            0                         0
# 42544                            0                         0
# 42547                            0                         0
# 42548                            1                         0
# 42555                            0                         0
# 42558                            1                         0
#
#        purpose:HOME_IMPROVEMENT_MAJOR_PURCHASE  purpose:CAR_CREDIT_CARD  \
# 42537                                        0                        0
# 42538                                        0                        0
# 42539                                        0                        0
# 42541                                        0                        0
# 42543                                        0                        0
# 42544                                        0                        0
# 42547                                        0                        0
# 42548                                        0                        0
# 42555                                        0                        0
# 42558                                        0                        0
#
#        addr_state:NE_IA_NV_HI_FL_AL  addr_state:NY  \
# 42537                             0              0
# 42538                             0              0
# 42539                             1              0
# 42541                             0              0
# 42543                             0              0
# 42544                             1              0
# 42547                             0              0
# 42548                             0              1
# 42555                             0              1
# 42558                             0              0
#
#        addr_state:LA_NM_OK_NC_MO_MD_NJ_VA  addr_state:CA  \
# 42537                                   0              0
# 42538                                   1              0
# 42539                                   0              0
# 42541                                   1              0
# 42543                                   0              0
# 42544                                   0              0
# 42547                                   0              0
# 42548                                   0              0
# 42555                                   0              0
# 42558                                   0              0
#
#        addr_state:AZ_MI_UT_TN_AR_PA  addr_state:RI_OH_KY_DE_MN_SD_MA_IN  \
# 42537                             0                                   0
# 42538                             0                                   0
# 42539                             0                                   0
# 42541                             0                                   0
# 42543                             0                                   1
# 42544                             0                                   0
# 42547                             0                                   0
# 42548                             0                                   0
# 42555                             0                                   0
# 42558                             0                                   0
#
#        addr_state:GA_WA  addr_state:WI_OR  addr_state:TX  addr_state:IL_CT_MT  \
# 42537                 0                 0              0                    1
# 42538                 0                 0              0                    0
# 42539                 0                 0              0                    0
# 42541                 0                 0              0                    0
# 42543                 0                 0              0                    0
# 42544                 0                 0              0                    0
# 42547                 0                 0              0                    0
# 42548                 0                 0              0                    0
# 42555                 0                 0              0                    0
# 42558                 0                 0              1                    0
#
#        addr_state:CO_SC  addr_state:KS_VT_AK_NS  addr_state:NH_WV_WY_DC  \
# 42537                 0                       0                       0
# 42538                 0                       0                       0
# 42539                 0                       0                       0
# 42541                 0                       0                       0
# 42543                 0                       0                       0
# 42544                 0                       0                       0
# 42547                 1                       0                       0
# 42548                 0                       0                       0
# 42555                 0                       0                       0
# 42558                 0                       0                       0
#
#        initial_list_status:F  initial_list_status:W  term:36  term:60  \
# 42537                      0                      1        1        0
# 42538                      0                      1        1        0
# 42539                      0                      1        1        0
# 42541                      1                      0        1        0
# 42543                      1                      0        1        0
# 42544                      1                      0        1        0
# 42547                      1                      0        0        1
# 42548                      1                      0        1        0
# 42555                      1                      0        1        0
# 42558                      1                      0        1        0
#
#        total_rec_int:<1000  total_rec_int:1000-2000  total_rec_int:2000-9000  \
# 42537                    0                        1                        0
# 42538                    0                        1                        0
# 42539                    0                        1                        0
# 42541                    0                        0                        1
# 42543                    0                        1                        0
# 42544                    1                        0                        0
# 42547                    0                        0                        0
# 42548                    0                        0                        1
# 42555                    0                        0                        1
# 42558                    0                        1                        0
#
#        total_rec_int:>9000  total_rev_hi_lim:<10000  \
# 42537                    0                        0
# 42538                    0                        1
# 42539                    0                        0
# 42541                    0                        1
# 42543                    0                        0
# 42544                    0                        1
# 42547                    1                        0
# 42548                    0                        1
# 42555                    0                        0
# 42558                    0                        0
#
#        total_rev_hi_lim:10000-20000  total_rev_hi_lim:20000-40000  \
# 42537                             0                             0
# 42538                             0                             0
# 42539                             1                             0
# 42541                             0                             0
# 42543                             0                             1
# 42544                             0                             0
# 42547                             0                             1
# 42548                             0                             0
# 42555                             0                             0
# 42558                             0                             1
#
#        total_rev_hi_lim:40000-60000  total_rev_hi_lim:60000-80000  \
# 42537                             0                             1
# 42538                             0                             0
# 42539                             0                             0
# 42541                             0                             0
# 42543                             0                             0
# 42544                             0                             0
# 42547                             0                             0
# 42548                             0                             0
# 42555                             1                             0
# 42558                             0                             0
#
#        total_rev_hi_lim:80000-100000  total_rev_hi_lim:<100000  \
# 42537                              0                         0
# 42538                              0                         0
# 42539                              0                         0
# 42541                              0                         0
# 42543                              0                         0
# 42544                              0                         0
# 42547                              0                         0
# 42548                              0                         0
# 42555                              0                         0
# 42558                              0                         0
#
#        total_pymnt:<5000  total_pymnt:5000-11000  total_pymnt:11000-16000  \
# 42537                  0                       1                        0
# 42538                  0                       0                        1
# 42539                  0                       0                        1
# 42541                  0                       0                        1
# 42543                  0                       1                        0
# 42544                  1                       0                        0
# 42547                  0                       0                        0
# 42548                  0                       1                        0
# 42555                  0                       0                        0
# 42558                  1                       0                        0
#
#        total_pymnt:16000-22000  total_pymnt:>22000  int_rate:<7.484  \
# 42537                        0                   0                1
# 42538                        0                   0                0
# 42539                        0                   0                0
# 42541                        0                   0                0
# 42543                        0                   0                0
# 42544                        0                   1                0
# 42547                        1                   0                0
# 42548                        0                   0                0
# 42555                        0                   0                0
# 42558                        0                   1                0
#
#        int_rate:7.484-9.548  int_rate:9.548-11.612  int_rate:11.612-13.676  \
# 42537                     0                      0                       0
# 42538                     0                      0                       1
# 42539                     1                      0                       0
# 42541                     0                      0                       1
# 42543                     0                      1                       0
# 42544                     0                      0                       1
# 42547                     0                      0                       0
# 42548                     0                      0                       0
# 42555                     0                      0                       1
# 42558                     0                      0                       0
#
#        int_rate:13.676-15.74  int_rate:15.74-17.804  int_rate:17.804-19.868  \
# 42537                      0                      0                       0
# 42538                      0                      0                       0
# 42539                      0                      0                       0
# 42541                      0                      0                       0
# 42543                      0                      0                       0
# 42544                      0                      0                       0
# 42547                      0                      0                       0
# 42548                      1                      0                       0
# 42555                      0                      0                       0
# 42558                      0                      0                       1
#
#        int_rate:7.19.868-21.932  int_rate:21.932-26.06  dti:<4  dti:4-8  \
# 42537                         0                      0       0        0
# 42538                         0                      0       0        0
# 42539                         0                      0       0        0
# 42541                         0                      0       0        0
# 42543                         0                      0       0        0
# 42544                         0                      0       0        0
# 42547                         1                      0       0        0
# 42548                         0                      0       1        0
# 42555                         0                      0       0        0
# 42558                         0                      0       0        0
#
#        dti:8-12  dti:12-16  dti:16-20  dti:20-23  dti:23-27  dti:27-40  \
# 42537         0          1          0          0          0          0
# 42538         0          0          1          0          0          0
# 42539         0          0          1          0          0          0
# 42541         1          0          0          0          0          0
# 42543         0          1          0          0          0          0
# 42544         0          0          0          0          1          0
# 42547         0          0          0          0          1          0
# 42548         0          0          0          0          0          0
# 42555         0          0          1          0          0          0
# 42558         0          0          1          0          0          0
#
#        annual_inc:<32000  annual_inc:32000-50000  annual_inc:50000-60000  \
# 42537                  0                       0                       0
# 42538                  0                       1                       0
# 42539                  0                       0                       0
# 42541                  0                       0                       0
# 42543                  0                       0                       0
# 42544                  1                       0                       0
# 42547                  0                       0                       0
# 42548                  0                       0                       0
# 42555                  0                       0                       0
# 42558                  0                       0                       0
#
#        annual_inc:60000-75000  annual_inc:75000-90000  \
# 42537                       0                       0
# 42538                       0                       0
# 42539                       1                       0
# 42541                       0                       1
# 42543                       0                       0
# 42544                       0                       0
# 42547                       1                       0
# 42548                       0                       1
# 42555                       0                       1
# 42558                       0                       0
#
#        annual_inc:90000-120000  annual_inc:120000-135000  \
# 42537                        1                         0
# 42538                        0                         0
# 42539                        0                         0
# 42541                        0                         0
# 42543                        1                         0
# 42544                        0                         0
# 42547                        0                         0
# 42548                        0                         0
# 42555                        0                         0
# 42558                        1                         0
#
#        annual_inc:135000-150000  annual_inc:>150000  inq_last_6mths:<1  \
# 42537                         0                   0                  1
# 42538                         0                   0                  1
# 42539                         0                   0                  1
# 42541                         0                   0                  1
# 42543                         0                   0                  1
# 42544                         0                   0                  1
# 42547                         0                   0                  1
# 42548                         0                   0                  1
# 42555                         0                   0                  0
# 42558                         0                   0                  1
#
#        inq_last_6mths:1-2  inq_last_6mths:2-4  inq_last_6mths:4-7  \
# 42537                   0                   0                   0
# 42538                   0                   0                   0
# 42539                   0                   0                   0
# 42541                   0                   0                   0
# 42543                   0                   0                   0
# 42544                   0                   0                   0
# 42547                   0                   0                   0
# 42548                   0                   0                   0
# 42555                   1                   0                   0
# 42558                   0                   0                   0
#
#        tot_cur_bal:<40000  tot_cur_bal:40000-80000  tot_cur_bal:80000-120000  \
# 42537                   0                        0                         0
# 42538                   1                        0                         0
# 42539                   0                        0                         0
# 42541                   1                        0                         0
# 42543                   1                        0                         0
# 42544                   1                        0                         0
# 42547                   0                        0                         0
# 42548                   0                        0                         0
# 42555                   1                        0                         0
# 42558                   0                        1                         0
#
#        tot_cur_bal:120000-160000  tot_cur_bal:160000-200000  \
# 42537                          0                          0
# 42538                          0                          0
# 42539                          0                          0
# 42541                          0                          0
# 42543                          0                          0
# 42544                          0                          0
# 42547                          0                          0
# 42548                          0                          0
# 42555                          0                          0
# 42558                          0                          0
#
#        tot_cur_bal:200000-240000  tot_cur_bal:240000-320000  \
# 42537                          0                          1
# 42538                          0                          0
# 42539                          0                          1
# 42541                          0                          0
# 42543                          0                          0
# 42544                          0                          0
# 42547                          0                          1
# 42548                          0                          0
# 42555                          0                          0
# 42558                          0                          0
#
#        tot_cur_bal:320000-400000  tot_cur_bal:>400000  \
# 42537                          0                    0
# 42538                          0                    0
# 42539                          0                    0
# 42541                          0                    0
# 42543                          0                    0
# 42544                          0                    0
# 42547                          0                    0
# 42548                          1                    0
# 42555                          0                    0
# 42558                          0                    0
#
#        mths_since_last_credit_pull_d:<65  mths_since_last_credit_pull_d:65-76  \
# 42537                                  1                                    0
# 42538                                  1                                    0
# 42539                                  1                                    0
# 42541                                  1                                    0
# 42543                                  1                                    0
# 42544                                  1                                    0
# 42547                                  1                                    0
# 42548                                  1                                    0
# 42555                                  1                                    0
# 42558                                  1                                    0
#
#        mths_since_last_credit_pull_d:>76  mths_since_issue_d_:<70.8  \
# 42537                                  0                          0
# 42538                                  0                          0
# 42539                                  0                          0
# 42541                                  0                          0
# 42543                                  0                          0
# 42544                                  0                          0
# 42547                                  0                          0
# 42548                                  0                          0
# 42555                                  0                          0
# 42558                                  0                          0
#
#        mths_since_issue_d_:>70.8-73.6  mths_since_issue_d_:73.6-76.4  \
# 42537                               0                              0
# 42538                               0                              0
# 42539                               0                              0
# 42541                               0                              0
# 42543                               0                              0
# 42544                               0                              0
# 42547                               0                              0
# 42548                               0                              0
# 42555                               0                              0
# 42558                               0                              0
#
#        mths_since_issue_d_:>76.4-79.2  mths_since_issue_d_:>79.2-82  \
# 42537                               0                             1
# 42538                               0                             1
# 42539                               0                             1
# 42541                               0                             1
# 42543                               0                             1
# 42544                               0                             1
# 42547                               0                             1
# 42548                               0                             1
# 42555                               0                             1
# 42558                               0                             1
#
#        mths_since_issue_d_>82-84  mths_since_issue_d_:>84-90.4  \
# 42537                          0                             0
# 42538                          0                             0
# 42539                          0                             0
# 42541                          0                             0
# 42543                          0                             0
# 42544                          0                             0
# 42547                          0                             0
# 42548                          0                             0
# 42555                          0                             0
# 42558                          0                             0
#
#        mths_since_issue_d_:>90.4-96  out_prncp:<3000  out_prncp:3000-6000  \
# 42537                             0                0                    1
# 42538                             0                1                    0
# 42539                             0                0                    1
# 42541                             0                0                    1
# 42543                             0                0                    1
# 42544                             0                1                    0
# 42547                             0                0                    0
# 42548                             0                0                    1
# 42555                             0                1                    0
# 42558                             0                1                    0
#
#        out_prncp:6000-10000  out_prncp:10000-12000  out_prncp:>12000  bad_loan
# 42537                     0                      0                 0         1
# 42538                     0                      0                 0         1
# 42539                     0                      0                 0         1
# 42541                     0                      0                 0         1
# 42543                     0                      0                 0         1
# 42544                     0                      0                 0         1
# 42547                     0                      0                 1         1
# 42548                     0                      0                 0         1
# 42555                     0                      0                 0         1
# 42558                     0                      0                 0         1

# %%
new_df1 = new_df

# %% [markdown]
# Now we must remove 1 dummy variable for each original variable, otherwise we will get into the [dummy variable trap](https://www.geeksforgeeks.org/ml-dummy-variable-trap-in-regression-models/). The dummy variables to be removed are those with the lowest WoE.

# %%
#dummy categories to drop
ref_categories = ['home_ownership:OTHER_NONE_RENT_ANY', 'total_rec_int:<1000', 'total_pymnt:<5000','total_rev_hi_lim:<10000', 'grade:G', 'verification_status:VERIFIED', 'purpose:SMALL_BUSINESS_EDUCATIONAL_RENEWABLE_ENERGY_MOVING',
                 'addr_state:NE_IA_NV_HI_FL_AL', 'initial_list_status:F', 'term:60', 'mths_since_issue_d_:>90.4-96','int_rate:21.932-26.06', 'dti:27-40',
                 'annual_inc:<32000', 'inq_last_6mths:4-7', 'tot_cur_bal:<40000', 'mths_since_last_credit_pull_d:>76', 'out_prncp:>12000']
#col dropped
new_df.drop(columns=ref_categories, inplace=True, axis=1)

# %% [markdown]
# # Checking for Class Imbalance in the Fully Preprocessed Dataset

# %%
#check if class labels are balanced

from yellowbrick.target import ClassBalance
X= new_df.drop(columns='bad_loan', axis=1)
y = new_df['bad_loan']
visualizer = ClassBalance()
visualizer.fit(y)
visualizer.show()
# Out:
# <Axes: title={'center': 'Class Balance for 181,686 Instances'}, ylabel='support'>

# %% [markdown]
# From the chart above, we see the individuals classified as bad borrowers have very few observations. This class imbalance can affect our model while training. To solve this problem, we will oversample the minority class.

# %% [markdown]
# # Splitting into Train and Test

# %%
#spliting data into train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
#checking  imbalance for training dataset
y_train.value_counts()
# Out:
# 1    131094
# 0     14254
# Name: bad_loan, dtype: int64

# %%
#checking  imbalance for training dataset
y_train.value_counts() / len(y_train) * 100
# Out:
# 1    90.193192
# 0     9.806808
# Name: bad_loan, dtype: float64

# %%
# # Save data for train test split
# import pickle
# file = open('feature storage/X_train', 'wb')
# pickle.dump(X_train, file)
# file.close()

# file = open('feature storage/y_train', 'wb')
# pickle.dump(y_train, file)
# file.close()

# file = open('feature storage/X_test', 'wb')
# pickle.dump(X_test, file)
# file.close()

# file = open('feature storage/y_test', 'wb')
# pickle.dump(y_test, file)
# file.close()

# print("Saving done !!!")

# %%
X_train.head(10)
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 331449        0        0        1        0        0        0
# 288712        0        0        0        1        0        0
# 70746         0        0        0        0        1        0
# 464189        0        0        0        0        1        0
# 339285        0        0        1        0        0        0
# 388830        0        0        1        0        0        0
# 61713         0        0        1        0        0        0
# 72275         1        0        0        0        0        0
# 366565        0        0        1        0        0        0
# 253866        0        0        0        0        1        0
#
#         home_ownership:OWN  home_ownership:MORTGAGE  \
# 331449                   0                        0
# 288712                   0                        1
# 70746                    0                        0
# 464189                   0                        1
# 339285                   1                        0
# 388830                   0                        1
# 61713                    0                        0
# 72275                    0                        1
# 366565                   0                        1
# 253866                   1                        0
#
#         verification_status:NOT_VERIFIED  verification_status:SOURCE_VERIFIED  \
# 331449                                 1                                    0
# 288712                                 0                                    0
# 70746                                  0                                    1
# 464189                                 0                                    0
# 339285                                 0                                    1
# 388830                                 0                                    1
# 61713                                  0                                    1
# 72275                                  0                                    1
# 366565                                 0                                    0
# 253866                                 0                                    1
#
#         purpose:OTHER_HOUSE_MEDICAL  purpose:WEDDING_VACATION  \
# 331449                            0                         1
# 288712                            0                         0
# 70746                             0                         0
# 464189                            0                         0
# 339285                            0                         0
# 388830                            0                         0
# 61713                             0                         0
# 72275                             0                         0
# 366565                            0                         0
# 253866                            0                         0
#
#         purpose:HOME_IMPROVEMENT_MAJOR_PURCHASE  purpose:CAR_CREDIT_CARD  \
# 331449                                        0                        0
# 288712                                        0                        0
# 70746                                         1                        0
# 464189                                        0                        0
# 339285                                        0                        0
# 388830                                        0                        1
# 61713                                         0                        0
# 72275                                         0                        0
# 366565                                        0                        0
# 253866                                        0                        0
#
#         addr_state:NY  addr_state:LA_NM_OK_NC_MO_MD_NJ_VA  addr_state:CA  \
# 331449              0                                   0              0
# 288712              0                                   0              0
# 70746               0                                   0              1
# 464189              0                                   0              0
# 339285              0                                   0              0
# 388830              0                                   0              0
# 61713               0                                   0              0
# 72275               0                                   0              0
# 366565              0                                   0              1
# 253866              0                                   0              0
#
#         addr_state:AZ_MI_UT_TN_AR_PA  addr_state:RI_OH_KY_DE_MN_SD_MA_IN  \
# 331449                             0                                   0
# 288712                             1                                   0
# 70746                              0                                   0
# 464189                             0                                   0
# 339285                             0                                   1
# 388830                             0                                   0
# 61713                              0                                   0
# 72275                              0                                   0
# 366565                             0                                   0
# 253866                             0                                   0
#
#         addr_state:GA_WA  addr_state:WI_OR  addr_state:TX  \
# 331449                 0                 0              1
# 288712                 0                 0              0
# 70746                  0                 0              0
# 464189                 0                 0              1
# 339285                 0                 0              0
# 388830                 0                 0              0
# 61713                  0                 0              1
# 72275                  0                 0              0
# 366565                 0                 0              0
# 253866                 0                 0              1
#
#         addr_state:IL_CT_MT  addr_state:CO_SC  addr_state:KS_VT_AK_NS  \
# 331449                    0                 0                       0
# 288712                    0                 0                       0
# 70746                     0                 0                       0
# 464189                    0                 0                       0
# 339285                    0                 0                       0
# 388830                    1                 0                       0
# 61713                     0                 0                       0
# 72275                     0                 0                       1
# 366565                    0                 0                       0
# 253866                    0                 0                       0
#
#         addr_state:NH_WV_WY_DC  initial_list_status:W  term:36  \
# 331449                       0                      1        1
# 288712                       0                      1        1
# 70746                        0                      0        0
# 464189                       0                      0        0
# 339285                       0                      1        0
# 388830                       0                      1        0
# 61713                        0                      1        1
# 72275                        0                      0        1
# 366565                       0                      1        1
# 253866                       0                      0        0
#
#         total_rec_int:1000-2000  total_rec_int:2000-9000  total_rec_int:>9000  \
# 331449                        0                        0                    0
# 288712                        0                        1                    0
# 70746                         0                        1                    0
# 464189                        0                        1                    0
# 339285                        0                        1                    0
# 388830                        1                        0                    0
# 61713                         1                        0                    0
# 72275                         0                        1                    0
# 366565                        0                        0                    0
# 253866                        0                        1                    0
#
#         total_rev_hi_lim:10000-20000  total_rev_hi_lim:20000-40000  \
# 331449                             1                             0
# 288712                             0                             0
# 70746                              0                             1
# 464189                             0                             1
# 339285                             1                             0
# 388830                             1                             0
# 61713                              0                             0
# 72275                              0                             0
# 366565                             0                             1
# 253866                             0                             1
#
#         total_rev_hi_lim:40000-60000  total_rev_hi_lim:60000-80000  \
# 331449                             0                             0
# 288712                             1                             0
# 70746                              0                             0
# 464189                             0                             0
# 339285                             0                             0
# 388830                             0                             0
# 61713                              0                             0
# 72275                              1                             0
# 366565                             0                             0
# 253866                             0                             0
#
#         total_rev_hi_lim:80000-100000  total_rev_hi_lim:<100000  \
# 331449                              0                         0
# 288712                              0                         0
# 70746                               0                         0
# 464189                              0                         0
# 339285                              0                         0
# 388830                              0                         0
# 61713                               0                         0
# 72275                               0                         0
# 366565                              0                         0
# 253866                              0                         0
#
#         total_pymnt:5000-11000  total_pymnt:11000-16000  \
# 331449                       0                        0
# 288712                       0                        1
# 70746                        1                        0
# 464189                       0                        0
# 339285                       1                        0
# 388830                       0                        0
# 61713                        0                        1
# 72275                        0                        0
# 366565                       0                        1
# 253866                       1                        0
#
#         total_pymnt:16000-22000  total_pymnt:>22000  int_rate:<7.484  \
# 331449                        0                   1                0
# 288712                        0                   0                0
# 70746                         0                   0                0
# 464189                        1                   0                0
# 339285                        0                   0                0
# 388830                        0                   1                0
# 61713                         0                   0                0
# 72275                         0                   0                0
# 366565                        0                   0                0
# 253866                        0                   0                0
#
#         int_rate:7.484-9.548  int_rate:9.548-11.612  int_rate:11.612-13.676  \
# 331449                     0                      0                       1
# 288712                     0                      0                       0
# 70746                      0                      0                       0
# 464189                     0                      0                       0
# 339285                     0                      0                       0
# 388830                     0                      0                       1
# 61713                      0                      0                       0
# 72275                      1                      0                       0
# 366565                     0                      0                       1
# 253866                     0                      0                       0
#
#         int_rate:13.676-15.74  int_rate:15.74-17.804  int_rate:17.804-19.868  \
# 331449                      0                      0                       0
# 288712                      1                      0                       0
# 70746                       0                      0                       0
# 464189                      0                      0                       0
# 339285                      1                      0                       0
# 388830                      0                      0                       0
# 61713                       0                      1                       0
# 72275                       0                      0                       0
# 366565                      0                      0                       0
# 253866                      0                      0                       1
#
#         int_rate:7.19.868-21.932  dti:<4  dti:4-8  dti:8-12  dti:12-16  \
# 331449                         0       0        0         1          0
# 288712                         0       0        0         0          0
# 70746                          0       0        0         1          0
# 464189                         0       0        0         0          0
# 339285                         0       0        0         1          0
# 388830                         0       0        0         1          0
# 61713                          0       0        0         0          0
# 72275                          0       0        1         0          0
# 366565                         0       0        1         0          0
# 253866                         0       0        0         0          0
#
#         dti:16-20  dti:20-23  dti:23-27  annual_inc:32000-50000  \
# 331449          0          0          0                       1
# 288712          0          0          0                       0
# 70746           0          0          0                       0
# 464189          0          1          0                       0
# 339285          0          0          0                       0
# 388830          0          0          0                       0
# 61713           0          0          1                       0
# 72275           0          0          0                       0
# 366565          0          0          0                       1
# 253866          0          1          0                       0
#
#         annual_inc:50000-60000  annual_inc:60000-75000  \
# 331449                       0                       0
# 288712                       0                       0
# 70746                        0                       0
# 464189                       0                       0
# 339285                       1                       0
# 388830                       0                       0
# 61713                        1                       0
# 72275                        0                       0
# 366565                       0                       0
# 253866                       0                       1
#
#         annual_inc:75000-90000  annual_inc:90000-120000  \
# 331449                       0                        0
# 288712                       1                        0
# 70746                        0                        1
# 464189                       0                        1
# 339285                       0                        0
# 388830                       0                        1
# 61713                        0                        0
# 72275                        0                        1
# 366565                       0                        0
# 253866                       0                        0
#
#         annual_inc:120000-135000  annual_inc:135000-150000  \
# 331449                         0                         0
# 288712                         0                         0
# 70746                          0                         0
# 464189                         0                         0
# 339285                         0                         0
# 388830                         0                         0
# 61713                          0                         0
# 72275                          0                         0
# 366565                         0                         0
# 253866                         0                         0
#
#         annual_inc:>150000  inq_last_6mths:<1  inq_last_6mths:1-2  \
# 331449                   0                  0                   1
# 288712                   0                  1                   0
# 70746                    0                  1                   0
# 464189                   0                  1                   0
# 339285                   0                  1                   0
# 388830                   0                  1                   0
# 61713                    0                  1                   0
# 72275                    0                  1                   0
# 366565                   0                  1                   0
# 253866                   0                  0                   1
#
#         inq_last_6mths:2-4  tot_cur_bal:40000-80000  tot_cur_bal:80000-120000  \
# 331449                   0                        0                         0
# 288712                   0                        0                         0
# 70746                    0                        0                         0
# 464189                   0                        1                         0
# 339285                   0                        0                         0
# 388830                   0                        0                         0
# 61713                    0                        0                         0
# 72275                    0                        0                         0
# 366565                   0                        0                         0
# 253866                   0                        1                         0
#
#         tot_cur_bal:120000-160000  tot_cur_bal:160000-200000  \
# 331449                          0                          0
# 288712                          0                          0
# 70746                           0                          0
# 464189                          0                          0
# 339285                          0                          0
# 388830                          0                          0
# 61713                           0                          0
# 72275                           0                          0
# 366565                          0                          0
# 253866                          0                          0
#
#         tot_cur_bal:200000-240000  tot_cur_bal:240000-320000  \
# 331449                          0                          0
# 288712                          1                          0
# 70746                           0                          0
# 464189                          0                          0
# 339285                          0                          0
# 388830                          1                          0
# 61713                           0                          0
# 72275                           1                          0
# 366565                          1                          0
# 253866                          0                          0
#
#         tot_cur_bal:320000-400000  tot_cur_bal:>400000  \
# 331449                          0                    0
# 288712                          0                    0
# 70746                           0                    0
# 464189                          0                    0
# 339285                          0                    0
# 388830                          0                    0
# 61713                           0                    0
# 72275                           0                    0
# 366565                          0                    0
# 253866                          0                    0
#
#         mths_since_last_credit_pull_d:<65  \
# 331449                                  0
# 288712                                  1
# 70746                                   1
# 464189                                  1
# 339285                                  1
# 388830                                  1
# 61713                                   1
# 72275                                   1
# 366565                                  1
# 253866                                  1
#
#         mths_since_last_credit_pull_d:65-76  mths_since_issue_d_:<70.8  \
# 331449                                    1                          0
# 288712                                    0                          1
# 70746                                     0                          0
# 464189                                    0                          0
# 339285                                    0                          0
# 388830                                    0                          0
# 61713                                     0                          0
# 72275                                     0                          0
# 366565                                    0                          0
# 253866                                    0                          1
#
#         mths_since_issue_d_:>70.8-73.6  mths_since_issue_d_:73.6-76.4  \
# 331449                               1                              1
# 288712                               0                              0
# 70746                                0                              0
# 464189                               0                              0
# 339285                               1                              1
# 388830                               0                              1
# 61713                                0                              0
# 72275                                0                              0
# 366565                               0                              1
# 253866                               0                              0
#
#         mths_since_issue_d_:>76.4-79.2  mths_since_issue_d_:>79.2-82  \
# 331449                               0                             0
# 288712                               0                             0
# 70746                                0                             1
# 464189                               1                             0
# 339285                               0                             0
# 388830                               0                             0
# 61713                                0                             1
# 72275                                0                             1
# 366565                               0                             0
# 253866                               0                             0
#
#         mths_since_issue_d_>82-84  mths_since_issue_d_:>84-90.4  \
# 331449                          0                             0
# 288712                          0                             0
# 70746                           0                             0
# 464189                          0                             0
# 339285                          0                             0
# 388830                          0                             0
# 61713                           0                             0
# 72275                           0                             0
# 366565                          0                             0
# 253866                          0                             0
#
#         out_prncp:<3000  out_prncp:3000-6000  out_prncp:6000-10000  \
# 331449                1                    0                     0
# 288712                0                    0                     0
# 70746                 0                    0                     1
# 464189                0                    0                     0
# 339285                0                    0                     0
# 388830                0                    0                     1
# 61713                 1                    0                     0
# 72275                 1                    0                     0
# 366565                1                    0                     0
# 253866                0                    0                     0
#
#         out_prncp:10000-12000
# 331449                      0
# 288712                      0
# 70746                       0
# 464189                      0
# 339285                      0
# 388830                      0
# 61713                       0
# 72275                       0
# 366565                      0
# 253866                      0

# %% [markdown]
# # Oversampling Minority Class to Resolve Class Imbalance

# %%
#import libraries for model training
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from imblearn.under_sampling import RandomUnderSampler
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, precision_recall_curve
from imblearn.over_sampling import RandomOverSampler
from imblearn.combine import SMOTETomek

# %%
#dealing with imbalanced data
os = RandomOverSampler()
X_train_o, y_train_o = os.fit_resample(X_train, y_train)
y_train_series = pd.Series(y_train_o)
#check value counts after oversampling
y_train_series.value_counts()
# Out:
# 1    131094
# 0    131094
# Name: bad_loan, dtype: int64

# %%
# # Save data for oversampling
# import pickle
# file = open('feature storage/X_train_o', 'wb')
# pickle.dump(X_train_o, file)
# file.close()

# file = open('feature storage/y_train_o', 'wb')
# pickle.dump(y_train_o, file)
# file.close()

# %% [markdown]
# # Building PD Model (White-Box)

# %%
#building logistic regression model
model = LogisticRegression()
model.fit(X_train_o, y_train_o)
# Out:
# LogisticRegression()

# %%
#predicting
y_preds = model.predict(X_test)
#classification report
print(classification_report(y_test, y_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.28      0.79      0.42      3570
#            1       0.97      0.78      0.87     32768
#
#     accuracy                           0.78     36338
#    macro avg       0.63      0.79      0.64     36338
# weighted avg       0.90      0.78      0.82     36338

# %%
y_hat_test_proba = model.predict_proba(X_test)
y_hat_test_proba = y_hat_test_proba[:][: , 1]
y_test_temp = y_test.copy()
y_test_temp.reset_index(drop = True, inplace = True)
y_test_proba = pd.concat([y_test_temp, pd.DataFrame(y_hat_test_proba), pd.DataFrame(y_preds)], axis = 1)
y_test_proba.columns = ['y_test_class_actual', 'y_hat_test_proba', 'y_hat_test']
y_test_proba.index = X_test.index
y_test_proba.head(-10)
# Out:
#         y_test_class_actual  y_hat_test_proba  y_hat_test
# 63645                     1          0.865680           1
# 393671                    1          0.869561           1
# 136741                    0          0.105385           0
# 459873                    1          0.608379           1
# 321075                    1          0.901739           1
# ...                     ...               ...         ...
# 60541                     1          0.477015           0
# 66798                     1          0.624969           1
# 156013                    1          0.439475           0
# 444099                    1          0.780939           1
# 365558                    1          0.490323           0
#
# [36328 rows x 3 columns]

# %% [markdown]
# # Assessing Discriminatory Power of the PD Model
#
# **1 A. ROC Curve**

# %%
# get the values required to plot a ROC curve
fpr, tpr, thresholds = roc_curve(y_test_proba['y_test_class_actual'], y_test_proba['y_hat_test_proba'])
# plot the ROC curve
plt.plot(fpr, tpr)
# plot a secondary diagonal line, to plot randomness of model
plt.plot(fpr, fpr, linestyle = '--', color = 'k')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve');

# %% [markdown]
# **1 B. Area under ROC Curve**

# %%
#Area under receiver operating charateristic cure
AUROC = roc_auc_score(y_test_proba['y_test_class_actual'], y_test_proba['y_hat_test_proba'])
AUROC
# Out:
# 0.853875993146282

# %% [markdown]
# **2. Gini Index**

# %%
Gini = AUROC * 2 - 1
Gini
# Out:
# 0.7077519862925641

# %%
y_train_pred = model.predict(X_train_o)
print(classification_report(y_train_o, y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.78      0.78    131094
#            1       0.78      0.78      0.78    131094
#
#     accuracy                           0.78    262188
#    macro avg       0.78      0.78      0.78    262188
# weighted avg       0.78      0.78      0.78    262188

# %%
y_train_pred = model.predict(X_train)
print(classification_report(y_train, y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.28      0.78      0.42     14254
#            1       0.97      0.78      0.87    131094
#
#     accuracy                           0.78    145348
#    macro avg       0.63      0.78      0.64    145348
# weighted avg       0.90      0.78      0.82    145348

# %% [markdown]
# # Logistic Regression - Report

# %%
train_model_scores = {}
train_o_model_scores = {}
test_model_scores = {}

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# %%
model = LogisticRegression()
model.fit(X_train_o, y_train_o)

y_test_pred = model.predict(X_test)
y_train_pred = model.predict(X_train)
y_train_o_pred = model.predict(X_train_o)

model_name = 'Logistic Regression'
# result on test
accuracy = accuracy_score(y_test, y_test_pred)
precision = precision_score(y_test, y_test_pred, average='macro')
recall = recall_score(y_test, y_test_pred, average='macro')
f1 = f1_score(y_test, y_test_pred, average='macro')
AUROC = roc_auc_score(y_test, y_test_pred)

test_model_scores[model_name] = [accuracy,precision, recall, f1,AUROC]

# result on train
accuracy = accuracy_score(y_train, y_train_pred)
precision = precision_score(y_train, y_train_pred, average='macro')
recall = recall_score(y_train, y_train_pred, average='macro')
f1 = f1_score(y_train, y_train_pred, average='macro')
AUROC = roc_auc_score(y_train, y_train_pred)

train_model_scores[model_name] = [accuracy, precision, recall, f1, AUROC]

# result on train_o
accuracy = accuracy_score(y_train_o, y_train_o_pred)
precision = precision_score(y_train_o, y_train_o_pred, average='macro')
recall = recall_score(y_train_o, y_train_o_pred, average='macro')
f1 = f1_score(y_train_o, y_train_o_pred, average='macro')
AUROC = roc_auc_score(y_train_o, y_train_o_pred)

train_o_model_scores[model_name] = [accuracy, precision, recall, f1, AUROC]

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(random_state=42)
model.fit(X_train_o, y_train_o)

y_test_pred = model.predict(X_test)
y_train_pred = model.predict(X_train)
y_train_o_pred = model.predict(X_train_o)

model_name = 'Decision Tree'
# result on test
accuracy = accuracy_score(y_test, y_test_pred)
precision = precision_score(y_test, y_test_pred, average='macro')
recall = recall_score(y_test, y_test_pred, average='macro')
f1 = f1_score(y_test, y_test_pred, average='macro')
AUROC = roc_auc_score(y_test, y_test_pred)

test_model_scores[model_name] = [accuracy,precision, recall, f1,AUROC]

# result on train
accuracy = accuracy_score(y_train, y_train_pred)
precision = precision_score(y_train, y_train_pred, average='macro')
recall = recall_score(y_train, y_train_pred, average='macro')
f1 = f1_score(y_train, y_train_pred, average='macro')
AUROC = roc_auc_score(y_train, y_train_pred)

train_model_scores[model_name] = [accuracy, precision, recall, f1, AUROC]

# result on train_o
accuracy = accuracy_score(y_train_o, y_train_o_pred)
precision = precision_score(y_train_o, y_train_o_pred, average='macro')
recall = recall_score(y_train_o, y_train_o_pred, average='macro')
f1 = f1_score(y_train_o, y_train_o_pred, average='macro')
AUROC = roc_auc_score(y_train_o, y_train_o_pred)

train_o_model_scores[model_name] = [accuracy, precision, recall, f1, AUROC]

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(X_train_o, y_train_o)

y_test_pred = model.predict(X_test)
y_train_pred = model.predict(X_train)
y_train_o_pred = model.predict(X_train_o)

model_name = 'Random Forest'
# result on test
accuracy = accuracy_score(y_test, y_test_pred)
precision = precision_score(y_test, y_test_pred, average='macro')
recall = recall_score(y_test, y_test_pred, average='macro')
f1 = f1_score(y_test, y_test_pred, average='macro')
AUROC = roc_auc_score(y_test, y_test_pred)

test_model_scores[model_name] = [accuracy,precision, recall, f1,AUROC]

# result on train
accuracy = accuracy_score(y_train, y_train_pred)
precision = precision_score(y_train, y_train_pred, average='macro')
recall = recall_score(y_train, y_train_pred, average='macro')
f1 = f1_score(y_train, y_train_pred, average='macro')
AUROC = roc_auc_score(y_train, y_train_pred)

train_model_scores[model_name] = [accuracy, precision, recall, f1, AUROC]

# result on train_o
accuracy = accuracy_score(y_train_o, y_train_o_pred)
precision = precision_score(y_train_o, y_train_o_pred, average='macro')
recall = recall_score(y_train_o, y_train_o_pred, average='macro')
f1 = f1_score(y_train_o, y_train_o_pred, average='macro')
AUROC = roc_auc_score(y_train_o, y_train_o_pred)

train_o_model_scores[model_name] = [accuracy, precision, recall, f1, AUROC]

# %% [markdown]
# # K-Nearest Neighbors

# %%
# from sklearn.neighbors import KNeighborsClassifier
# model = KNeighborsClassifier()
# model.fit(X_train_o, y_train_o)

# y_test_pred = model.predict(X_test)
# y_train_pred = model.predict(X_train)
# y_train_o_pred = model.predict(X_train_o)

# model_name = 'KNN'
# # result on test
# accuracy = accuracy_score(y_test, y_test_pred)
# precision = precision_score(y_test, y_test_pred, average='macro')
# recall = recall_score(y_test, y_test_pred, average='macro')
# f1 = f1_score(y_test, y_test_pred, average='macro')
# AUROC = roc_auc_score(y_test, y_test_pred)

# test_model_scores[model_name] = [accuracy,precision, recall, f1,AUROC]

# # result on train
# accuracy = accuracy_score(y_train, y_train_pred)
# precision = precision_score(y_train, y_train_pred, average='macro')
# recall = recall_score(y_train, y_train_pred, average='macro')
# f1 = f1_score(y_train, y_train_pred, average='macro')
# AUROC = roc_auc_score(y_train, y_train_pred)

# train_model_scores[model_name] = [accuracy, precision, recall, f1, AUROC]

# # result on train_o
# accuracy = accuracy_score(y_train_o, y_train_o_pred)
# precision = precision_score(y_train_o, y_train_o_pred, average='macro')
# recall = recall_score(y_train_o, y_train_o_pred, average='macro')
# f1 = f1_score(y_train_o, y_train_o_pred, average='macro')
# AUROC = roc_auc_score(y_train_o, y_train_o_pred)

# train_o_model_scores[model_name] = [accuracy, precision, recall, f1, AUROC]

# %% [markdown]
# # Support Vector Machine

# %%
# from sklearn.svm import SVC

# model = SVC(kernel='linear')
# model.fit(X_train_o, y_train_o)

# y_test_pred = model.predict(X_test)
# y_train_pred = model.predict(X_train)
# y_train_o_pred = model.predict(X_train_o)

# model_name = 'Support Vector Machine'
# # result on test
# accuracy = accuracy_score(y_test, y_test_pred)
# precision = precision_score(y_test, y_test_pred, average='macro')
# recall = recall_score(y_test, y_test_pred, average='macro')
# f1 = f1_score(y_test, y_test_pred, average='macro')
# AUROC = roc_auc_score(y_test, y_test_pred)

# test_model_scores[model_name] = [accuracy,precision, recall, f1,AUROC]

# # result on train
# accuracy = accuracy_score(y_train, y_train_pred)
# precision = precision_score(y_train, y_train_pred, average='macro')
# recall = recall_score(y_train, y_train_pred, average='macro')
# f1 = f1_score(y_train, y_train_pred, average='macro')
# AUROC = roc_auc_score(y_train, y_train_pred)

# train_model_scores[model_name] = [accuracy, precision, recall, f1, AUROC]

# # result on train_o
# accuracy = accuracy_score(y_train_o, y_train_o_pred)
# precision = precision_score(y_train_o, y_train_o_pred, average='macro')
# recall = recall_score(y_train_o, y_train_o_pred, average='macro')
# f1 = f1_score(y_train_o, y_train_o_pred, average='macro')
# AUROC = roc_auc_score(y_train_o, y_train_o_pred)

# train_o_model_scores[model_name] = [accuracy, precision, recall, f1, AUROC]

# %% [markdown]
# # XGBoost

# %%
pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from xgboost) (1.11.4)

# %%
X_train_o.columns = ['grade_A', 'grade_B', 'grade_C', 'grade_D', 'grade_E', 'grade_F',
 'home_ownership_OWN', 'home_ownership_MORTGAGE',
 'verification_status_NOT_VERIFIED', 'verification_status_SOURCE_VERIFIED',
 'purpose_OTHER_HOUSE_MEDICAL', 'purpose_WEDDING_VACATION',
 'purpose_HOME_IMPROVEMENT_MAJOR_PURCHASE', 'purpose_CAR_CREDIT_CARD',
 'addr_state_NY', 'addr_state_LA_NM_OK_NC_MO_MD_NJ_VA', 'addr_state_CA',
 'addr_state_AZ_MI_UT_TN_AR_PA', 'addr_state_RI_OH_KY_DE_MN_SD_MA_IN',
 'addr_state_GA_WA', 'addr_state_WI_OR', 'addr_state_TX',
 'addr_state_IL_CT_MT', 'addr_state_CO_SC', 'addr_state_KS_VT_AK_NS',
 'addr_state_NH_WV_WY_DC', 'initial_list_status_W', 'term_36',
 'total_rec_int_1000_2000', 'total_rec_int_2000_9000', 'total_rec_int_gt_9000',
 'total_rev_hi_lim_10000_20000', 'total_rev_hi_lim_20000_40000',
 'total_rev_hi_lim_40000_60000', 'total_rev_hi_lim_60000_80000',
 'total_rev_hi_lim_80000_100000', 'total_rev_hi_lim_lt_100000',
 'total_pymnt_5000_11000', 'total_pymnt_11000_16000', 'total_pymnt_16000_22000',
 'total_pymnt_gt_22000', 'int_rate_lt_7.484', 'int_rate_7.484_9.548',
 'int_rate_9.548_11.612', 'int_rate_11.612_13.676', 'int_rate_13.676_15.74',
 'int_rate_15.74_17.804', 'int_rate_17.804_19.868', 'int_rate_gt_19.868',
 'dti_lt_4', 'dti_4_8', 'dti_8_12', 'dti_12_16', 'dti_16_20', 'dti_20_23',
 'dti_23_27', 'annual_inc_32000_50000', 'annual_inc_50000_60000',
 'annual_inc_60000_75000', 'annual_inc_75000_90000', 'annual_inc_90000_120000',
 'annual_inc_120000_135000', 'annual_inc_135000_150000', 'annual_inc_gt_150000',
 'inq_last_6mths_lt_1', 'inq_last_6mths_1_2', 'inq_last_6mths_2_4',
 'tot_cur_bal_40000_80000','tot_cur_bal_80000_120000', 'tot_cur_bal_120000_160000', 'tot_cur_bal_160000_200000',
 'tot_cur_bal_200000_240000', 'tot_cur_bal_240000_320000', 'tot_cur_bal_320000_400000',
 'tot_cur_bal_gt_400000', 'mths_since_last_credit_pull_d_lt_65',
 'mths_since_last_credit_pull_d_65_76', 'mths_since_issue_d_lt_70.8',
 'mths_since_issue_d_gt_70.8_73.6', 'mths_since_issue_d_73.6_76.4',
 'mths_since_issue_d_gt_76.4_79.2', 'mths_since_issue_d_gt_79.2_82',
 'mths_since_issue_d_gt_82_84', 'mths_since_issue_d_gt_84_90.4',
 'out_prncp_lt_3000', 'out_prncp_3000_6000', 'out_prncp_6000_10000',
 'out_prncp_10000_12000']

# %%
X_test.columns = ['grade_A', 'grade_B', 'grade_C', 'grade_D', 'grade_E', 'grade_F',
 'home_ownership_OWN', 'home_ownership_MORTGAGE',
 'verification_status_NOT_VERIFIED', 'verification_status_SOURCE_VERIFIED',
 'purpose_OTHER_HOUSE_MEDICAL', 'purpose_WEDDING_VACATION',
 'purpose_HOME_IMPROVEMENT_MAJOR_PURCHASE', 'purpose_CAR_CREDIT_CARD',
 'addr_state_NY', 'addr_state_LA_NM_OK_NC_MO_MD_NJ_VA', 'addr_state_CA',
 'addr_state_AZ_MI_UT_TN_AR_PA', 'addr_state_RI_OH_KY_DE_MN_SD_MA_IN',
 'addr_state_GA_WA', 'addr_state_WI_OR', 'addr_state_TX',
 'addr_state_IL_CT_MT', 'addr_state_CO_SC', 'addr_state_KS_VT_AK_NS',
 'addr_state_NH_WV_WY_DC', 'initial_list_status_W', 'term_36',
 'total_rec_int_1000_2000', 'total_rec_int_2000_9000', 'total_rec_int_gt_9000',
 'total_rev_hi_lim_10000_20000', 'total_rev_hi_lim_20000_40000',
 'total_rev_hi_lim_40000_60000', 'total_rev_hi_lim_60000_80000',
 'total_rev_hi_lim_80000_100000', 'total_rev_hi_lim_lt_100000',
 'total_pymnt_5000_11000', 'total_pymnt_11000_16000', 'total_pymnt_16000_22000',
 'total_pymnt_gt_22000', 'int_rate_lt_7.484', 'int_rate_7.484_9.548',
 'int_rate_9.548_11.612', 'int_rate_11.612_13.676', 'int_rate_13.676_15.74',
 'int_rate_15.74_17.804', 'int_rate_17.804_19.868', 'int_rate_gt_19.868',
 'dti_lt_4', 'dti_4_8', 'dti_8_12', 'dti_12_16', 'dti_16_20', 'dti_20_23',
 'dti_23_27', 'annual_inc_32000_50000', 'annual_inc_50000_60000',
 'annual_inc_60000_75000', 'annual_inc_75000_90000', 'annual_inc_90000_120000',
 'annual_inc_120000_135000', 'annual_inc_135000_150000', 'annual_inc_gt_150000',
 'inq_last_6mths_lt_1', 'inq_last_6mths_1_2', 'inq_last_6mths_2_4',
 'tot_cur_bal_40000_80000','tot_cur_bal_80000_120000', 'tot_cur_bal_120000_160000', 'tot_cur_bal_160000_200000',
 'tot_cur_bal_200000_240000', 'tot_cur_bal_240000_320000', 'tot_cur_bal_320000_400000',
 'tot_cur_bal_gt_400000', 'mths_since_last_credit_pull_d_lt_65',
 'mths_since_last_credit_pull_d_65_76', 'mths_since_issue_d_lt_70.8',
 'mths_since_issue_d_gt_70.8_73.6', 'mths_since_issue_d_73.6_76.4',
 'mths_since_issue_d_gt_76.4_79.2', 'mths_since_issue_d_gt_79.2_82',
 'mths_since_issue_d_gt_82_84', 'mths_since_issue_d_gt_84_90.4',
 'out_prncp_lt_3000', 'out_prncp_3000_6000', 'out_prncp_6000_10000',
 'out_prncp_10000_12000']

# %%
X_train.columns = ['grade_A', 'grade_B', 'grade_C', 'grade_D', 'grade_E', 'grade_F',
 'home_ownership_OWN', 'home_ownership_MORTGAGE',
 'verification_status_NOT_VERIFIED', 'verification_status_SOURCE_VERIFIED',
 'purpose_OTHER_HOUSE_MEDICAL', 'purpose_WEDDING_VACATION',
 'purpose_HOME_IMPROVEMENT_MAJOR_PURCHASE', 'purpose_CAR_CREDIT_CARD',
 'addr_state_NY', 'addr_state_LA_NM_OK_NC_MO_MD_NJ_VA', 'addr_state_CA',
 'addr_state_AZ_MI_UT_TN_AR_PA', 'addr_state_RI_OH_KY_DE_MN_SD_MA_IN',
 'addr_state_GA_WA', 'addr_state_WI_OR', 'addr_state_TX',
 'addr_state_IL_CT_MT', 'addr_state_CO_SC', 'addr_state_KS_VT_AK_NS',
 'addr_state_NH_WV_WY_DC', 'initial_list_status_W', 'term_36',
 'total_rec_int_1000_2000', 'total_rec_int_2000_9000', 'total_rec_int_gt_9000',
 'total_rev_hi_lim_10000_20000', 'total_rev_hi_lim_20000_40000',
 'total_rev_hi_lim_40000_60000', 'total_rev_hi_lim_60000_80000',
 'total_rev_hi_lim_80000_100000', 'total_rev_hi_lim_lt_100000',
 'total_pymnt_5000_11000', 'total_pymnt_11000_16000', 'total_pymnt_16000_22000',
 'total_pymnt_gt_22000', 'int_rate_lt_7.484', 'int_rate_7.484_9.548',
 'int_rate_9.548_11.612', 'int_rate_11.612_13.676', 'int_rate_13.676_15.74',
 'int_rate_15.74_17.804', 'int_rate_17.804_19.868', 'int_rate_gt_19.868',
 'dti_lt_4', 'dti_4_8', 'dti_8_12', 'dti_12_16', 'dti_16_20', 'dti_20_23',
 'dti_23_27', 'annual_inc_32000_50000', 'annual_inc_50000_60000',
 'annual_inc_60000_75000', 'annual_inc_75000_90000', 'annual_inc_90000_120000',
 'annual_inc_120000_135000', 'annual_inc_135000_150000', 'annual_inc_gt_150000',
 'inq_last_6mths_lt_1', 'inq_last_6mths_1_2', 'inq_last_6mths_2_4',
 'tot_cur_bal_40000_80000','tot_cur_bal_80000_120000', 'tot_cur_bal_120000_160000', 'tot_cur_bal_160000_200000',
 'tot_cur_bal_200000_240000', 'tot_cur_bal_240000_320000', 'tot_cur_bal_320000_400000',
 'tot_cur_bal_gt_400000', 'mths_since_last_credit_pull_d_lt_65',
 'mths_since_last_credit_pull_d_65_76', 'mths_since_issue_d_lt_70.8',
 'mths_since_issue_d_gt_70.8_73.6', 'mths_since_issue_d_73.6_76.4',
 'mths_since_issue_d_gt_76.4_79.2', 'mths_since_issue_d_gt_79.2_82',
 'mths_since_issue_d_gt_82_84', 'mths_since_issue_d_gt_84_90.4',
 'out_prncp_lt_3000', 'out_prncp_3000_6000', 'out_prncp_6000_10000',
 'out_prncp_10000_12000']

# %%
from xgboost import XGBClassifier

model = XGBClassifier()
model.fit(X_train_o, y_train_o)

y_test_pred = model.predict(X_test)
y_train_pred = model.predict(X_train)
y_train_o_pred = model.predict(X_train_o)

model_name = 'XGBoost'
# result on test
accuracy = accuracy_score(y_test, y_test_pred)
precision = precision_score(y_test, y_test_pred, average='macro')
recall = recall_score(y_test, y_test_pred, average='macro')
f1 = f1_score(y_test, y_test_pred, average='macro')
AUROC = roc_auc_score(y_test, y_test_pred)

test_model_scores[model_name] = [accuracy,precision, recall, f1,AUROC]

# result on train
accuracy = accuracy_score(y_train, y_train_pred)
precision = precision_score(y_train, y_train_pred, average='macro')
recall = recall_score(y_train, y_train_pred, average='macro')
f1 = f1_score(y_train, y_train_pred, average='macro')
AUROC = roc_auc_score(y_train, y_train_pred)

train_model_scores[model_name] = [accuracy, precision, recall, f1, AUROC]

# result on train_o
accuracy = accuracy_score(y_train_o, y_train_o_pred)
precision = precision_score(y_train_o, y_train_o_pred, average='macro')
recall = recall_score(y_train_o, y_train_o_pred, average='macro')
f1 = f1_score(y_train_o, y_train_o_pred, average='macro')
AUROC = roc_auc_score(y_train_o, y_train_o_pred)

train_o_model_scores[model_name] = [accuracy, precision, recall, f1, AUROC]

# %% [markdown]
# # CatBoost

# %%
pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.3-cp310-cp310-manylinux2014_x86_64.whl (98.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.5/98.5 MB 14.8 MB/s eta 0:00:00
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.23.5)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.3)
# Installing collected packages: catboost
# Successfully installed catboost-1.2.3

# %%
from catboost import CatBoostClassifier
model = CatBoostClassifier()
model.fit(X_train_o, y_train_o)

y_test_pred = model.predict(X_test)
y_train_pred = model.predict(X_train)
y_train_o_pred = model.predict(X_train_o)

model_name = 'CatBoost'
# result on test
accuracy = accuracy_score(y_test, y_test_pred)
precision = precision_score(y_test, y_test_pred, average='macro')
recall = recall_score(y_test, y_test_pred, average='macro')
f1 = f1_score(y_test, y_test_pred, average='macro')
AUROC = roc_auc_score(y_test, y_test_pred)

test_model_scores[model_name] = [accuracy,precision, recall, f1,AUROC]

# result on train
accuracy = accuracy_score(y_train, y_train_pred)
precision = precision_score(y_train, y_train_pred, average='macro')
recall = recall_score(y_train, y_train_pred, average='macro')
f1 = f1_score(y_train, y_train_pred, average='macro')
AUROC = roc_auc_score(y_train, y_train_pred)

train_model_scores[model_name] = [accuracy, precision, recall, f1, AUROC]

# result on train_o
accuracy = accuracy_score(y_train_o, y_train_o_pred)
precision = precision_score(y_train_o, y_train_o_pred, average='macro')
recall = recall_score(y_train_o, y_train_o_pred, average='macro')
f1 = f1_score(y_train_o, y_train_o_pred, average='macro')
AUROC = roc_auc_score(y_train_o, y_train_o_pred)

train_o_model_scores[model_name] = [accuracy, precision, recall, f1, AUROC]
# Out:
# Learning rate set to 0.111092
# 0:	learn: 0.6431127	total: 63.5ms	remaining: 1m 3s
# 1:	learn: 0.5986985	total: 77ms	remaining: 38.4s
# 2:	learn: 0.5722552	total: 89.6ms	remaining: 29.8s
# 3:	learn: 0.5514639	total: 102ms	remaining: 25.4s
# 4:	learn: 0.5327410	total: 114ms	remaining: 22.8s
# 5:	learn: 0.5209298	total: 127ms	remaining: 21s
# 6:	learn: 0.5114107	total: 140ms	remaining: 19.9s
# 7:	learn: 0.5045976	total: 153ms	remaining: 19s
# 8:	learn: 0.4981951	total: 167ms	remaining: 18.4s
# 9:	learn: 0.4932068	total: 180ms	remaining: 17.8s
# 10:	learn: 0.4897269	total: 193ms	remaining: 17.4s
# 11:	learn: 0.4868153	total: 205ms	remaining: 16.9s
# 12:	learn: 0.4843017	total: 218ms	remaining: 16.6s
# 13:	learn: 0.4818677	total: 231ms	remaining: 16.2s
# 14:	learn: 0.4763066	total: 242ms	remaining: 15.9s
# 15:	learn: 0.4749499	total: 255ms	remaining: 15.7s
# 16:	learn: 0.4730370	total: 267ms	remaining: 15.5s
# 17:	learn: 0.4699819	total: 280ms	remaining: 15.3s
# 18:	learn: 0.4671852	total: 292ms	remaining: 15.1s
# 19:	learn: 0.4660104	total: 305ms	remaining: 14.9s
# 20:	learn: 0.4645018	total: 317ms	remaining: 14.8s
# 21:	learn: 0.4637573	total: 330ms	remaining: 14.7s
# 22:	learn: 0.4628724	total: 342ms	remaining: 14.5s
# 23:	learn: 0.4617955	total: 354ms	remaining: 14.4s
# 24:	learn: 0.4607435	total: 367ms	remaining: 14.3s
# 25:	learn: 0.4598005	total: 379ms	remaining: 14.2s
# 26:	learn: 0.4588542	total: 392ms	remaining: 14.1s
# 27:	learn: 0.4572599	total: 404ms	remaining: 14s
# 28:	learn: 0.4567499	total: 416ms	remaining: 13.9s
# 29:	learn: 0.4550347	total: 429ms	remaining: 13.9s
# 30:	learn: 0.4546103	total: 442ms	remaining: 13.8s
# 31:	learn: 0.4540394	total: 454ms	remaining: 13.7s
# 32:	learn: 0.4530368	total: 466ms	remaining: 13.7s
# 33:	learn: 0.4520755	total: 479ms	remaining: 13.6s
# 34:	learn: 0.4515305	total: 491ms	remaining: 13.5s
# 35:	learn: 0.4510800	total: 504ms	remaining: 13.5s
# 36:	learn: 0.4503802	total: 516ms	remaining: 13.4s
# 37:	learn: 0.4491407	total: 527ms	remaining: 13.3s
# 38:	learn: 0.4484903	total: 539ms	remaining: 13.3s
# 39:	learn: 0.4473880	total: 550ms	remaining: 13.2s
# 40:	learn: 0.4469413	total: 562ms	remaining: 13.1s
# 41:	learn: 0.4464718	total: 575ms	remaining: 13.1s
# 42:	learn: 0.4460003	total: 587ms	remaining: 13.1s
# 43:	learn: 0.4453780	total: 598ms	remaining: 13s
# 44:	learn: 0.4445050	total: 610ms	remaining: 12.9s
# 45:	learn: 0.4439301	total: 622ms	remaining: 12.9s
# 46:	learn: 0.4435025	total: 633ms	remaining: 12.8s
# 47:	learn: 0.4429707	total: 645ms	remaining: 12.8s
# 48:	learn: 0.4426710	total: 656ms	remaining: 12.7s
# 49:	learn: 0.4422941	total: 668ms	remaining: 12.7s
# 50:	learn: 0.4403281	total: 679ms	remaining: 12.6s
# 51:	learn: 0.4397033	total: 691ms	remaining: 12.6s
# 52:	learn: 0.4389070	total: 704ms	remaining: 12.6s
# 53:	learn: 0.4375330	total: 716ms	remaining: 12.5s
# 54:	learn: 0.4368310	total: 728ms	remaining: 12.5s
# 55:	learn: 0.4362924	total: 740ms	remaining: 12.5s
# 56:	learn: 0.4357776	total: 752ms	remaining: 12.4s
# 57:	learn: 0.4354543	total: 765ms	remaining: 12.4s
# 58:	learn: 0.4346458	total: 776ms	remaining: 12.4s
# 59:	learn: 0.4343441	total: 788ms	remaining: 12.3s
# 60:	learn: 0.4334630	total: 799ms	remaining: 12.3s
# 61:	learn: 0.4330622	total: 811ms	remaining: 12.3s
# 62:	learn: 0.4325148	total: 823ms	remaining: 12.2s
# 63:	learn: 0.4322450	total: 834ms	remaining: 12.2s
# 64:	learn: 0.4315691	total: 846ms	remaining: 12.2s
# 65:	learn: 0.4312188	total: 857ms	remaining: 12.1s
# 66:	learn: 0.4298460	total: 880ms	remaining: 12.3s
# 67:	learn: 0.4293005	total: 892ms	remaining: 12.2s
# 68:	learn: 0.4289802	total: 904ms	remaining: 12.2s
# 69:	learn: 0.4287782	total: 914ms	remaining: 12.1s
# 70:	learn: 0.4283466	total: 926ms	remaining: 12.1s
# 71:	learn: 0.4281521	total: 937ms	remaining: 12.1s
# 72:	learn: 0.4274019	total: 950ms	remaining: 12.1s
# 73:	learn: 0.4268256	total: 962ms	remaining: 12s
# 74:	learn: 0.4265448	total: 975ms	remaining: 12s
# 75:	learn: 0.4262501	total: 986ms	remaining: 12s
# 76:	learn: 0.4259673	total: 997ms	remaining: 12s
# 77:	learn: 0.4257154	total: 1.01s	remaining: 11.9s
# 78:	learn: 0.4250097	total: 1.02s	remaining: 11.9s
# 79:	learn: 0.4247230	total: 1.03s	remaining: 11.9s
# 80:	learn: 0.4244086	total: 1.05s	remaining: 11.9s
# 81:	learn: 0.4241294	total: 1.06s	remaining: 11.9s
# 82:	learn: 0.4237982	total: 1.07s	remaining: 11.8s
# 83:	learn: 0.4235710	total: 1.08s	remaining: 11.8s
# 84:	learn: 0.4231068	total: 1.1s	remaining: 11.8s
# 85:	learn: 0.4228683	total: 1.11s	remaining: 11.8s
# 86:	learn: 0.4226597	total: 1.12s	remaining: 11.8s
# 87:	learn: 0.4221702	total: 1.13s	remaining: 11.7s
# 88:	learn: 0.4218652	total: 1.14s	remaining: 11.7s
# 89:	learn: 0.4215947	total: 1.16s	remaining: 11.7s
# 90:	learn: 0.4212631	total: 1.17s	remaining: 11.7s
# 91:	learn: 0.4205495	total: 1.18s	remaining: 11.6s
# 92:	learn: 0.4203542	total: 1.19s	remaining: 11.6s
# 93:	learn: 0.4200117	total: 1.2s	remaining: 11.6s
# 94:	learn: 0.4197684	total: 1.21s	remaining: 11.6s
# 95:	learn: 0.4194312	total: 1.22s	remaining: 11.5s
# 96:	learn: 0.4190973	total: 1.24s	remaining: 11.5s
# 97:	learn: 0.4181320	total: 1.25s	remaining: 11.5s
# 98:	learn: 0.4176586	total: 1.26s	remaining: 11.5s
# 99:	learn: 0.4173948	total: 1.27s	remaining: 11.4s
# 100:	learn: 0.4171291	total: 1.28s	remaining: 11.4s
# 101:	learn: 0.4168041	total: 1.29s	remaining: 11.4s
# 102:	learn: 0.4159635	total: 1.31s	remaining: 11.4s
# 103:	learn: 0.4156807	total: 1.32s	remaining: 11.4s
# 104:	learn: 0.4152928	total: 1.33s	remaining: 11.4s
# 105:	learn: 0.4147285	total: 1.34s	remaining: 11.3s
# 106:	learn: 0.4144768	total: 1.36s	remaining: 11.3s
# 107:	learn: 0.4140958	total: 1.37s	remaining: 11.3s
# 108:	learn: 0.4138033	total: 1.38s	remaining: 11.3s
# 109:	learn: 0.4134984	total: 1.39s	remaining: 11.3s
# 110:	learn: 0.4132728	total: 1.4s	remaining: 11.2s
# 111:	learn: 0.4129697	total: 1.41s	remaining: 11.2s
# 112:	learn: 0.4123116	total: 1.43s	remaining: 11.2s
# 113:	learn: 0.4116545	total: 1.44s	remaining: 11.2s
# 114:	learn: 0.4112766	total: 1.45s	remaining: 11.2s
# 115:	learn: 0.4110469	total: 1.46s	remaining: 11.1s
# 116:	learn: 0.4105604	total: 1.47s	remaining: 11.1s
# 117:	learn: 0.4103780	total: 1.48s	remaining: 11.1s
# 118:	learn: 0.4100448	total: 1.49s	remaining: 11.1s
# 119:	learn: 0.4097086	total: 1.5s	remaining: 11s
# 120:	learn: 0.4094809	total: 1.52s	remaining: 11s
# 121:	learn: 0.4093278	total: 1.53s	remaining: 11s
# 122:	learn: 0.4089565	total: 1.54s	remaining: 11s
# 123:	learn: 0.4087347	total: 1.55s	remaining: 11s
# 124:	learn: 0.4084810	total: 1.56s	remaining: 11s
# 125:	learn: 0.4079258	total: 1.58s	remaining: 10.9s
# 126:	learn: 0.4075738	total: 1.59s	remaining: 10.9s
# 127:	learn: 0.4073661	total: 1.6s	remaining: 10.9s
# 128:	learn: 0.4071454	total: 1.61s	remaining: 10.9s
# 129:	learn: 0.4068693	total: 1.62s	remaining: 10.9s
# 130:	learn: 0.4065675	total: 1.63s	remaining: 10.8s
# 131:	learn: 0.4063240	total: 1.64s	remaining: 10.8s
# 132:	learn: 0.4060001	total: 1.66s	remaining: 10.8s
# 133:	learn: 0.4057413	total: 1.67s	remaining: 10.8s
# 134:	learn: 0.4055110	total: 1.68s	remaining: 10.8s
# 135:	learn: 0.4051774	total: 1.69s	remaining: 10.7s
# 136:	learn: 0.4048109	total: 1.7s	remaining: 10.7s
# 137:	learn: 0.4044274	total: 1.72s	remaining: 10.7s
# 138:	learn: 0.4041495	total: 1.73s	remaining: 10.7s
# 139:	learn: 0.4038843	total: 1.74s	remaining: 10.7s
# 140:	learn: 0.4036789	total: 1.75s	remaining: 10.7s
# 141:	learn: 0.4033165	total: 1.76s	remaining: 10.7s
# 142:	learn: 0.4030225	total: 1.78s	remaining: 10.6s
# 143:	learn: 0.4025966	total: 1.79s	remaining: 10.6s
# 144:	learn: 0.4023808	total: 1.8s	remaining: 10.6s
# 145:	learn: 0.4021920	total: 1.81s	remaining: 10.6s
# 146:	learn: 0.4019663	total: 1.82s	remaining: 10.6s
# 147:	learn: 0.4016763	total: 1.83s	remaining: 10.6s
# 148:	learn: 0.4014641	total: 1.85s	remaining: 10.5s
# 149:	learn: 0.4012395	total: 1.86s	remaining: 10.5s
# 150:	learn: 0.4010326	total: 1.87s	remaining: 10.5s
# 151:	learn: 0.4007767	total: 1.88s	remaining: 10.5s
# 152:	learn: 0.4003490	total: 1.9s	remaining: 10.5s
# 153:	learn: 0.4001525	total: 1.91s	remaining: 10.5s
# 154:	learn: 0.3999135	total: 1.92s	remaining: 10.5s
# 155:	learn: 0.3996759	total: 1.93s	remaining: 10.4s
# 156:	learn: 0.3993344	total: 1.94s	remaining: 10.4s
# 157:	learn: 0.3991289	total: 1.95s	remaining: 10.4s
# 158:	learn: 0.3988398	total: 1.96s	remaining: 10.4s
# 159:	learn: 0.3985563	total: 1.98s	remaining: 10.4s
# 160:	learn: 0.3982454	total: 1.99s	remaining: 10.4s
# 161:	learn: 0.3977524	total: 2s	remaining: 10.3s
# 162:	learn: 0.3974035	total: 2.01s	remaining: 10.3s
# 163:	learn: 0.3970415	total: 2.02s	remaining: 10.3s
# 164:	learn: 0.3968308	total: 2.03s	remaining: 10.3s
# 165:	learn: 0.3965531	total: 2.04s	remaining: 10.3s
# 166:	learn: 0.3962616	total: 2.06s	remaining: 10.3s
# 167:	learn: 0.3960970	total: 2.07s	remaining: 10.2s
# 168:	learn: 0.3958958	total: 2.08s	remaining: 10.2s
# 169:	learn: 0.3957060	total: 2.09s	remaining: 10.2s
# 170:	learn: 0.3954658	total: 2.1s	remaining: 10.2s
# 171:	learn: 0.3953258	total: 2.11s	remaining: 10.2s
# 172:	learn: 0.3950843	total: 2.12s	remaining: 10.2s
# 173:	learn: 0.3948036	total: 2.13s	remaining: 10.1s
# 174:	learn: 0.3945470	total: 2.15s	remaining: 10.1s
# 175:	learn: 0.3943569	total: 2.16s	remaining: 10.1s
# 176:	learn: 0.3941594	total: 2.17s	remaining: 10.1s
# 177:	learn: 0.3939068	total: 2.18s	remaining: 10.1s
# 178:	learn: 0.3936713	total: 2.19s	remaining: 10.1s
# 179:	learn: 0.3933078	total: 2.2s	remaining: 10s
# 180:	learn: 0.3930048	total: 2.21s	remaining: 10s
# 181:	learn: 0.3927380	total: 2.23s	remaining: 10s
# 182:	learn: 0.3924325	total: 2.24s	remaining: 9.99s
# 183:	learn: 0.3922286	total: 2.25s	remaining: 9.98s
# 184:	learn: 0.3920688	total: 2.26s	remaining: 9.96s
# 185:	learn: 0.3917466	total: 2.27s	remaining: 9.95s
# 186:	learn: 0.3915620	total: 2.29s	remaining: 9.94s
# 187:	learn: 0.3913617	total: 2.3s	remaining: 9.92s
# 188:	learn: 0.3911326	total: 2.31s	remaining: 9.91s
# 189:	learn: 0.3909239	total: 2.32s	remaining: 9.9s
# 190:	learn: 0.3906874	total: 2.33s	remaining: 9.89s
# 191:	learn: 0.3904191	total: 2.35s	remaining: 9.88s
# 192:	learn: 0.3902322	total: 2.36s	remaining: 9.86s
# 193:	learn: 0.3900818	total: 2.37s	remaining: 9.84s
# 194:	learn: 0.3898675	total: 2.38s	remaining: 9.82s
# 195:	learn: 0.3896939	total: 2.39s	remaining: 9.81s
# 196:	learn: 0.3894965	total: 2.4s	remaining: 9.79s
# 197:	learn: 0.3893237	total: 2.41s	remaining: 9.77s
# 198:	learn: 0.3891353	total: 2.42s	remaining: 9.76s
# 199:	learn: 0.3889119	total: 2.44s	remaining: 9.74s
# 200:	learn: 0.3887227	total: 2.45s	remaining: 9.73s
# 201:	learn: 0.3884964	total: 2.46s	remaining: 9.71s
# 202:	learn: 0.3882683	total: 2.47s	remaining: 9.7s
# 203:	learn: 0.3880513	total: 2.48s	remaining: 9.69s
# 204:	learn: 0.3878528	total: 2.49s	remaining: 9.67s
# 205:	learn: 0.3875901	total: 2.5s	remaining: 9.66s
# 206:	learn: 0.3873638	total: 2.52s	remaining: 9.64s
# 207:	learn: 0.3871502	total: 2.53s	remaining: 9.63s
# 208:	learn: 0.3869213	total: 2.54s	remaining: 9.61s
# 209:	learn: 0.3867398	total: 2.55s	remaining: 9.6s
# 210:	learn: 0.3864086	total: 2.56s	remaining: 9.58s
# 211:	learn: 0.3861777	total: 2.57s	remaining: 9.57s
# 212:	learn: 0.3859776	total: 2.58s	remaining: 9.55s
# 213:	learn: 0.3857194	total: 2.6s	remaining: 9.54s
# 214:	learn: 0.3855570	total: 2.61s	remaining: 9.53s
# 215:	learn: 0.3853469	total: 2.62s	remaining: 9.51s
# 216:	learn: 0.3851652	total: 2.63s	remaining: 9.5s
# 217:	learn: 0.3849911	total: 2.64s	remaining: 9.49s
# 218:	learn: 0.3847462	total: 2.66s	remaining: 9.47s
# 219:	learn: 0.3845502	total: 2.67s	remaining: 9.46s
# 220:	learn: 0.3844130	total: 2.68s	remaining: 9.44s
# 221:	learn: 0.3842267	total: 2.69s	remaining: 9.43s
# 222:	learn: 0.3839768	total: 2.7s	remaining: 9.41s
# 223:	learn: 0.3837762	total: 2.71s	remaining: 9.4s
# 224:	learn: 0.3835168	total: 2.73s	remaining: 9.39s
# 225:	learn: 0.3833019	total: 2.74s	remaining: 9.37s
# 226:	learn: 0.3830960	total: 2.75s	remaining: 9.36s
# 227:	learn: 0.3829634	total: 2.76s	remaining: 9.34s
# 228:	learn: 0.3827956	total: 2.77s	remaining: 9.33s
# 229:	learn: 0.3825807	total: 2.78s	remaining: 9.31s
# 230:	learn: 0.3823727	total: 2.79s	remaining: 9.3s
# 231:	learn: 0.3822388	total: 2.8s	remaining: 9.28s
# 232:	learn: 0.3820096	total: 2.81s	remaining: 9.27s
# 233:	learn: 0.3818220	total: 2.83s	remaining: 9.25s
# 234:	learn: 0.3816065	total: 2.84s	remaining: 9.24s
# 235:	learn: 0.3814340	total: 2.85s	remaining: 9.22s
# 236:	learn: 0.3812454	total: 2.86s	remaining: 9.21s
# 237:	learn: 0.3810633	total: 2.87s	remaining: 9.2s
# 238:	learn: 0.3809091	total: 2.88s	remaining: 9.18s
# 239:	learn: 0.3807199	total: 2.89s	remaining: 9.16s
# 240:	learn: 0.3805446	total: 2.9s	remaining: 9.15s
# 241:	learn: 0.3802705	total: 2.92s	remaining: 9.14s
# 242:	learn: 0.3801522	total: 2.93s	remaining: 9.13s
# 243:	learn: 0.3799174	total: 2.94s	remaining: 9.12s
# 244:	learn: 0.3796939	total: 2.96s	remaining: 9.11s
# 245:	learn: 0.3794662	total: 2.97s	remaining: 9.1s
# 246:	learn: 0.3792960	total: 2.98s	remaining: 9.08s
# 247:	learn: 0.3791007	total: 2.99s	remaining: 9.07s
# 248:	learn: 0.3789104	total: 3s	remaining: 9.05s
# 249:	learn: 0.3787013	total: 3.01s	remaining: 9.04s
# 250:	learn: 0.3785776	total: 3.02s	remaining: 9.03s
# 251:	learn: 0.3784192	total: 3.04s	remaining: 9.01s
# 252:	learn: 0.3781946	total: 3.05s	remaining: 9s
# 253:	learn: 0.3779898	total: 3.06s	remaining: 8.98s
# 254:	learn: 0.3778383	total: 3.07s	remaining: 8.97s
# 255:	learn: 0.3776151	total: 3.08s	remaining: 8.96s
# 256:	learn: 0.3774465	total: 3.09s	remaining: 8.95s
# 257:	learn: 0.3772473	total: 3.11s	remaining: 8.93s
# 258:	learn: 0.3770541	total: 3.12s	remaining: 8.92s
# 259:	learn: 0.3768008	total: 3.13s	remaining: 8.91s
# 260:	learn: 0.3765830	total: 3.14s	remaining: 8.89s
# 261:	learn: 0.3763566	total: 3.15s	remaining: 8.88s
# 262:	learn: 0.3761409	total: 3.16s	remaining: 8.87s
# 263:	learn: 0.3759570	total: 3.17s	remaining: 8.85s
# 264:	learn: 0.3757687	total: 3.19s	remaining: 8.84s
# 265:	learn: 0.3756129	total: 3.2s	remaining: 8.82s
# 266:	learn: 0.3754790	total: 3.21s	remaining: 8.81s
# 267:	learn: 0.3753170	total: 3.22s	remaining: 8.8s
# 268:	learn: 0.3751484	total: 3.23s	remaining: 8.79s
# 269:	learn: 0.3748609	total: 3.25s	remaining: 8.77s
# 270:	learn: 0.3746768	total: 3.26s	remaining: 8.76s
# 271:	learn: 0.3744367	total: 3.27s	remaining: 8.75s
# 272:	learn: 0.3742266	total: 3.28s	remaining: 8.73s
# 273:	learn: 0.3741081	total: 3.29s	remaining: 8.72s
# 274:	learn: 0.3739313	total: 3.3s	remaining: 8.71s
# 275:	learn: 0.3737702	total: 3.31s	remaining: 8.69s
# 276:	learn: 0.3736150	total: 3.32s	remaining: 8.68s
# 277:	learn: 0.3734113	total: 3.33s	remaining: 8.66s
# 278:	learn: 0.3732433	total: 3.35s	remaining: 8.65s
# 279:	learn: 0.3730835	total: 3.36s	remaining: 8.64s
# 280:	learn: 0.3729023	total: 3.37s	remaining: 8.62s
# 281:	learn: 0.3727043	total: 3.38s	remaining: 8.61s
# 282:	learn: 0.3724678	total: 3.39s	remaining: 8.6s
# 283:	learn: 0.3723063	total: 3.4s	remaining: 8.58s
# 284:	learn: 0.3720336	total: 3.42s	remaining: 8.57s
# 285:	learn: 0.3718722	total: 3.43s	remaining: 8.56s
# 286:	learn: 0.3716897	total: 3.44s	remaining: 8.54s
# 287:	learn: 0.3714910	total: 3.45s	remaining: 8.53s
# 288:	learn: 0.3713051	total: 3.46s	remaining: 8.51s
# 289:	learn: 0.3711201	total: 3.47s	remaining: 8.5s
# 290:	learn: 0.3709331	total: 3.48s	remaining: 8.49s
# 291:	learn: 0.3707576	total: 3.5s	remaining: 8.48s
# 292:	learn: 0.3706071	total: 3.51s	remaining: 8.46s
# 293:	learn: 0.3704475	total: 3.52s	remaining: 8.45s
# 294:	learn: 0.3702999	total: 3.53s	remaining: 8.44s
# 295:	learn: 0.3701629	total: 3.54s	remaining: 8.43s
# 296:	learn: 0.3700417	total: 3.55s	remaining: 8.41s
# 297:	learn: 0.3699046	total: 3.56s	remaining: 8.4s
# 298:	learn: 0.3697415	total: 3.58s	remaining: 8.39s
# 299:	learn: 0.3696215	total: 3.59s	remaining: 8.37s
# 300:	learn: 0.3694949	total: 3.6s	remaining: 8.36s
# 301:	learn: 0.3693273	total: 3.61s	remaining: 8.35s
# 302:	learn: 0.3691575	total: 3.62s	remaining: 8.33s
# 303:	learn: 0.3690181	total: 3.63s	remaining: 8.32s
# 304:	learn: 0.3689011	total: 3.64s	remaining: 8.3s
# 305:	learn: 0.3687998	total: 3.65s	remaining: 8.29s
# 306:	learn: 0.3685843	total: 3.67s	remaining: 8.28s
# 307:	learn: 0.3683735	total: 3.68s	remaining: 8.27s
# 308:	learn: 0.3682578	total: 3.69s	remaining: 8.25s
# 309:	learn: 0.3680223	total: 3.7s	remaining: 8.24s
# 310:	learn: 0.3678118	total: 3.71s	remaining: 8.22s
# 311:	learn: 0.3676307	total: 3.72s	remaining: 8.21s
# 312:	learn: 0.3674188	total: 3.73s	remaining: 8.2s
# 313:	learn: 0.3672644	total: 3.75s	remaining: 8.18s
# 314:	learn: 0.3670605	total: 3.76s	remaining: 8.17s
# 315:	learn: 0.3668891	total: 3.77s	remaining: 8.16s
# 316:	learn: 0.3666757	total: 3.78s	remaining: 8.14s
# 317:	learn: 0.3664798	total: 3.79s	remaining: 8.13s
# 318:	learn: 0.3662986	total: 3.8s	remaining: 8.12s
# 319:	learn: 0.3661063	total: 3.81s	remaining: 8.11s
# 320:	learn: 0.3659257	total: 3.83s	remaining: 8.1s
# 321:	learn: 0.3657379	total: 3.84s	remaining: 8.08s
# 322:	learn: 0.3655315	total: 3.85s	remaining: 8.07s
# 323:	learn: 0.3653240	total: 3.86s	remaining: 8.06s
# 324:	learn: 0.3651902	total: 3.87s	remaining: 8.04s
# 325:	learn: 0.3650130	total: 3.88s	remaining: 8.03s
# 326:	learn: 0.3648682	total: 3.9s	remaining: 8.02s
# 327:	learn: 0.3646970	total: 3.91s	remaining: 8.01s
# 328:	learn: 0.3645587	total: 3.92s	remaining: 8s
# 329:	learn: 0.3643687	total: 3.93s	remaining: 7.98s
# 330:	learn: 0.3641836	total: 3.94s	remaining: 7.97s
# 331:	learn: 0.3640817	total: 3.96s	remaining: 7.96s
# 332:	learn: 0.3639014	total: 3.97s	remaining: 7.95s
# 333:	learn: 0.3637592	total: 3.98s	remaining: 7.94s
# 334:	learn: 0.3635855	total: 3.99s	remaining: 7.92s
# 335:	learn: 0.3634383	total: 4s	remaining: 7.91s
# 336:	learn: 0.3633064	total: 4.01s	remaining: 7.9s
# 337:	learn: 0.3630965	total: 4.03s	remaining: 7.89s
# 338:	learn: 0.3629003	total: 4.04s	remaining: 7.88s
# 339:	learn: 0.3627051	total: 4.05s	remaining: 7.86s
# 340:	learn: 0.3625103	total: 4.06s	remaining: 7.85s
# 341:	learn: 0.3623727	total: 4.08s	remaining: 7.84s
# 342:	learn: 0.3622016	total: 4.09s	remaining: 7.83s
# 343:	learn: 0.3619814	total: 4.1s	remaining: 7.82s
# 344:	learn: 0.3618034	total: 4.11s	remaining: 7.81s
# 345:	learn: 0.3616696	total: 4.12s	remaining: 7.79s
# 346:	learn: 0.3615504	total: 4.13s	remaining: 7.78s
# 347:	learn: 0.3613611	total: 4.14s	remaining: 7.77s
# 348:	learn: 0.3611720	total: 4.16s	remaining: 7.75s
# 349:	learn: 0.3609633	total: 4.17s	remaining: 7.74s
# 350:	learn: 0.3608111	total: 4.18s	remaining: 7.73s
# 351:	learn: 0.3606775	total: 4.19s	remaining: 7.72s
# 352:	learn: 0.3605383	total: 4.2s	remaining: 7.71s
# 353:	learn: 0.3604160	total: 4.22s	remaining: 7.7s
# 354:	learn: 0.3602497	total: 4.23s	remaining: 7.68s
# 355:	learn: 0.3601031	total: 4.24s	remaining: 7.67s
# 356:	learn: 0.3599572	total: 4.25s	remaining: 7.66s
# 357:	learn: 0.3598270	total: 4.26s	remaining: 7.65s
# 358:	learn: 0.3596416	total: 4.28s	remaining: 7.63s
# 359:	learn: 0.3594656	total: 4.29s	remaining: 7.62s
# 360:	learn: 0.3593290	total: 4.3s	remaining: 7.61s
# 361:	learn: 0.3591918	total: 4.31s	remaining: 7.6s
# 362:	learn: 0.3589769	total: 4.32s	remaining: 7.58s
# 363:	learn: 0.3588535	total: 4.33s	remaining: 7.57s
# 364:	learn: 0.3586824	total: 4.34s	remaining: 7.56s
# 365:	learn: 0.3585398	total: 4.36s	remaining: 7.55s
# 366:	learn: 0.3583510	total: 4.37s	remaining: 7.54s
# 367:	learn: 0.3582067	total: 4.38s	remaining: 7.52s
# 368:	learn: 0.3579941	total: 4.39s	remaining: 7.51s
# 369:	learn: 0.3577875	total: 4.4s	remaining: 7.5s
# 370:	learn: 0.3576293	total: 4.42s	remaining: 7.49s
# 371:	learn: 0.3574498	total: 4.43s	remaining: 7.47s
# 372:	learn: 0.3573391	total: 4.44s	remaining: 7.46s
# 373:	learn: 0.3571737	total: 4.45s	remaining: 7.45s
# 374:	learn: 0.3570576	total: 4.46s	remaining: 7.44s
# 375:	learn: 0.3568965	total: 4.47s	remaining: 7.42s
# 376:	learn: 0.3567710	total: 4.49s	remaining: 7.41s
# 377:	learn: 0.3566156	total: 4.5s	remaining: 7.4s
# 378:	learn: 0.3564790	total: 4.51s	remaining: 7.39s
# 379:	learn: 0.3563166	total: 4.52s	remaining: 7.38s
# 380:	learn: 0.3561619	total: 4.53s	remaining: 7.37s
# 381:	learn: 0.3560193	total: 4.54s	remaining: 7.35s
# 382:	learn: 0.3558659	total: 4.56s	remaining: 7.34s
# 383:	learn: 0.3557574	total: 4.57s	remaining: 7.33s
# 384:	learn: 0.3556465	total: 4.58s	remaining: 7.32s
# 385:	learn: 0.3554862	total: 4.59s	remaining: 7.3s
# 386:	learn: 0.3553179	total: 4.61s	remaining: 7.29s
# 387:	learn: 0.3552125	total: 4.62s	remaining: 7.28s
# 388:	learn: 0.3550897	total: 4.63s	remaining: 7.27s
# 389:	learn: 0.3549180	total: 4.64s	remaining: 7.26s
# 390:	learn: 0.3547211	total: 4.66s	remaining: 7.25s
# 391:	learn: 0.3546167	total: 4.67s	remaining: 7.24s
# 392:	learn: 0.3544954	total: 4.68s	remaining: 7.23s
# 393:	learn: 0.3543772	total: 4.69s	remaining: 7.22s
# 394:	learn: 0.3542420	total: 4.7s	remaining: 7.2s
# 395:	learn: 0.3540771	total: 4.72s	remaining: 7.19s
# 396:	learn: 0.3539697	total: 4.73s	remaining: 7.18s
# 397:	learn: 0.3538265	total: 4.74s	remaining: 7.17s
# 398:	learn: 0.3536646	total: 4.75s	remaining: 7.16s
# 399:	learn: 0.3535255	total: 4.76s	remaining: 7.15s
# 400:	learn: 0.3533712	total: 4.78s	remaining: 7.13s
# 401:	learn: 0.3532492	total: 4.79s	remaining: 7.12s
# 402:	learn: 0.3530930	total: 4.8s	remaining: 7.11s
# 403:	learn: 0.3529344	total: 4.81s	remaining: 7.1s
# 404:	learn: 0.3528268	total: 4.82s	remaining: 7.09s
# 405:	learn: 0.3526883	total: 4.84s	remaining: 7.08s
# 406:	learn: 0.3525669	total: 4.85s	remaining: 7.06s
# 407:	learn: 0.3524136	total: 4.86s	remaining: 7.05s
# 408:	learn: 0.3523176	total: 4.87s	remaining: 7.04s
# 409:	learn: 0.3521622	total: 4.88s	remaining: 7.03s
# 410:	learn: 0.3520290	total: 4.89s	remaining: 7.01s
# 411:	learn: 0.3518931	total: 4.91s	remaining: 7s
# 412:	learn: 0.3517590	total: 4.92s	remaining: 6.99s
# 413:	learn: 0.3516231	total: 4.93s	remaining: 6.98s
# 414:	learn: 0.3514762	total: 4.94s	remaining: 6.97s
# 415:	learn: 0.3513214	total: 4.95s	remaining: 6.95s
# 416:	learn: 0.3511334	total: 4.96s	remaining: 6.94s
# 417:	learn: 0.3509863	total: 4.98s	remaining: 6.93s
# 418:	learn: 0.3508417	total: 4.99s	remaining: 6.92s
# 419:	learn: 0.3506580	total: 5s	remaining: 6.9s
# 420:	learn: 0.3505629	total: 5.01s	remaining: 6.89s
# 421:	learn: 0.3504268	total: 5.02s	remaining: 6.88s
# 422:	learn: 0.3502625	total: 5.03s	remaining: 6.87s
# 423:	learn: 0.3500634	total: 5.05s	remaining: 6.86s
# 424:	learn: 0.3498675	total: 5.06s	remaining: 6.84s
# 425:	learn: 0.3497019	total: 5.07s	remaining: 6.83s
# 426:	learn: 0.3495453	total: 5.08s	remaining: 6.82s
# 427:	learn: 0.3494406	total: 5.09s	remaining: 6.81s
# 428:	learn: 0.3492907	total: 5.11s	remaining: 6.79s
# 429:	learn: 0.3491366	total: 5.12s	remaining: 6.78s
# 430:	learn: 0.3490161	total: 5.13s	remaining: 6.77s
# 431:	learn: 0.3488741	total: 5.14s	remaining: 6.76s
# 432:	learn: 0.3487883	total: 5.15s	remaining: 6.75s
# 433:	learn: 0.3486175	total: 5.16s	remaining: 6.73s
# 434:	learn: 0.3484720	total: 5.17s	remaining: 6.72s
# 435:	learn: 0.3482981	total: 5.18s	remaining: 6.71s
# 436:	learn: 0.3481571	total: 5.2s	remaining: 6.7s
# 437:	learn: 0.3479324	total: 5.21s	remaining: 6.68s
# 438:	learn: 0.3478077	total: 5.22s	remaining: 6.67s
# 439:	learn: 0.3476189	total: 5.23s	remaining: 6.66s
# 440:	learn: 0.3474833	total: 5.24s	remaining: 6.65s
# 441:	learn: 0.3473604	total: 5.25s	remaining: 6.63s
# 442:	learn: 0.3471548	total: 5.27s	remaining: 6.62s
# 443:	learn: 0.3470176	total: 5.28s	remaining: 6.61s
# 444:	learn: 0.3467794	total: 5.29s	remaining: 6.6s
# 445:	learn: 0.3466684	total: 5.3s	remaining: 6.58s
# 446:	learn: 0.3465536	total: 5.31s	remaining: 6.57s
# 447:	learn: 0.3464300	total: 5.32s	remaining: 6.56s
# 448:	learn: 0.3463153	total: 5.33s	remaining: 6.55s
# 449:	learn: 0.3461872	total: 5.35s	remaining: 6.53s
# 450:	learn: 0.3460549	total: 5.36s	remaining: 6.52s
# 451:	learn: 0.3459202	total: 5.37s	remaining: 6.51s
# 452:	learn: 0.3458005	total: 5.38s	remaining: 6.5s
# 453:	learn: 0.3456276	total: 5.39s	remaining: 6.48s
# 454:	learn: 0.3455208	total: 5.4s	remaining: 6.47s
# 455:	learn: 0.3454044	total: 5.41s	remaining: 6.46s
# 456:	learn: 0.3452836	total: 5.42s	remaining: 6.45s
# 457:	learn: 0.3450945	total: 5.44s	remaining: 6.43s
# 458:	learn: 0.3448975	total: 5.45s	remaining: 6.42s
# 459:	learn: 0.3447392	total: 5.46s	remaining: 6.41s
# 460:	learn: 0.3446292	total: 5.47s	remaining: 6.4s
# 461:	learn: 0.3444435	total: 5.48s	remaining: 6.39s
# 462:	learn: 0.3442905	total: 5.5s	remaining: 6.37s
# 463:	learn: 0.3441749	total: 5.51s	remaining: 6.36s
# 464:	learn: 0.3441014	total: 5.52s	remaining: 6.35s
# 465:	learn: 0.3439671	total: 5.53s	remaining: 6.34s
# 466:	learn: 0.3438610	total: 5.54s	remaining: 6.32s
# 467:	learn: 0.3437208	total: 5.55s	remaining: 6.31s
# 468:	learn: 0.3436135	total: 5.56s	remaining: 6.3s
# 469:	learn: 0.3435164	total: 5.57s	remaining: 6.29s
# 470:	learn: 0.3433769	total: 5.58s	remaining: 6.27s
# 471:	learn: 0.3432477	total: 5.6s	remaining: 6.26s
# 472:	learn: 0.3430673	total: 5.61s	remaining: 6.25s
# 473:	learn: 0.3429132	total: 5.62s	remaining: 6.24s
# 474:	learn: 0.3427644	total: 5.63s	remaining: 6.22s
# 475:	learn: 0.3426679	total: 5.64s	remaining: 6.21s
# 476:	learn: 0.3425747	total: 5.65s	remaining: 6.2s
# 477:	learn: 0.3424561	total: 5.66s	remaining: 6.18s
# 478:	learn: 0.3422910	total: 5.68s	remaining: 6.17s
# 479:	learn: 0.3421379	total: 5.69s	remaining: 6.16s
# 480:	learn: 0.3419929	total: 5.7s	remaining: 6.15s
# 481:	learn: 0.3418449	total: 5.71s	remaining: 6.14s
# 482:	learn: 0.3416789	total: 5.72s	remaining: 6.13s
# 483:	learn: 0.3415666	total: 5.73s	remaining: 6.11s
# 484:	learn: 0.3414515	total: 5.75s	remaining: 6.1s
# 485:	learn: 0.3413348	total: 5.76s	remaining: 6.09s
# 486:	learn: 0.3412240	total: 5.77s	remaining: 6.08s
# 487:	learn: 0.3410861	total: 5.78s	remaining: 6.07s
# 488:	learn: 0.3409745	total: 5.79s	remaining: 6.05s
# 489:	learn: 0.3408715	total: 5.8s	remaining: 6.04s
# 490:	learn: 0.3407572	total: 5.81s	remaining: 6.03s
# 491:	learn: 0.3406293	total: 5.83s	remaining: 6.01s
# 492:	learn: 0.3405173	total: 5.84s	remaining: 6s
# 493:	learn: 0.3403484	total: 5.85s	remaining: 5.99s
# 494:	learn: 0.3402199	total: 5.86s	remaining: 5.98s
# 495:	learn: 0.3399270	total: 5.88s	remaining: 5.97s
# 496:	learn: 0.3398033	total: 5.89s	remaining: 5.96s
# 497:	learn: 0.3396765	total: 5.9s	remaining: 5.95s
# 498:	learn: 0.3394973	total: 5.91s	remaining: 5.93s
# 499:	learn: 0.3394184	total: 5.92s	remaining: 5.92s
# 500:	learn: 0.3392898	total: 5.93s	remaining: 5.91s
# 501:	learn: 0.3391619	total: 5.95s	remaining: 5.9s
# 502:	learn: 0.3390233	total: 5.96s	remaining: 5.88s
# 503:	learn: 0.3388850	total: 5.97s	remaining: 5.87s
# 504:	learn: 0.3387666	total: 5.98s	remaining: 5.86s
# 505:	learn: 0.3386118	total: 5.99s	remaining: 5.85s
# 506:	learn: 0.3385048	total: 6s	remaining: 5.84s
# 507:	learn: 0.3383767	total: 6.01s	remaining: 5.83s
# 508:	learn: 0.3382368	total: 6.03s	remaining: 5.81s
# 509:	learn: 0.3381062	total: 6.04s	remaining: 5.8s
# 510:	learn: 0.3379222	total: 6.05s	remaining: 5.79s
# 511:	learn: 0.3377589	total: 6.06s	remaining: 5.78s
# 512:	learn: 0.3376451	total: 6.07s	remaining: 5.76s
# 513:	learn: 0.3374878	total: 6.08s	remaining: 5.75s
# 514:	learn: 0.3373475	total: 6.09s	remaining: 5.74s
# 515:	learn: 0.3372242	total: 6.11s	remaining: 5.73s
# 516:	learn: 0.3370769	total: 6.12s	remaining: 5.72s
# 517:	learn: 0.3369424	total: 6.13s	remaining: 5.7s
# 518:	learn: 0.3367660	total: 6.14s	remaining: 5.69s
# 519:	learn: 0.3366471	total: 6.15s	remaining: 5.68s
# 520:	learn: 0.3365048	total: 6.17s	remaining: 5.67s
# 521:	learn: 0.3363563	total: 6.18s	remaining: 5.66s
# 522:	learn: 0.3362567	total: 6.19s	remaining: 5.64s
# 523:	learn: 0.3361693	total: 6.2s	remaining: 5.63s
# 524:	learn: 0.3360232	total: 6.21s	remaining: 5.62s
# 525:	learn: 0.3358962	total: 6.22s	remaining: 5.61s
# 526:	learn: 0.3357891	total: 6.24s	remaining: 5.6s
# 527:	learn: 0.3356726	total: 6.25s	remaining: 5.59s
# 528:	learn: 0.3355875	total: 6.26s	remaining: 5.57s
# 529:	learn: 0.3354613	total: 6.27s	remaining: 5.56s
# 530:	learn: 0.3353700	total: 6.28s	remaining: 5.55s
# 531:	learn: 0.3352490	total: 6.3s	remaining: 5.54s
# 532:	learn: 0.3350847	total: 6.31s	remaining: 5.53s
# 533:	learn: 0.3349522	total: 6.32s	remaining: 5.51s
# 534:	learn: 0.3348674	total: 6.33s	remaining: 5.5s
# 535:	learn: 0.3347418	total: 6.34s	remaining: 5.49s
# 536:	learn: 0.3346058	total: 6.36s	remaining: 5.48s
# 537:	learn: 0.3344835	total: 6.37s	remaining: 5.47s
# 538:	learn: 0.3343876	total: 6.38s	remaining: 5.46s
# 539:	learn: 0.3342780	total: 6.39s	remaining: 5.45s
# 540:	learn: 0.3341600	total: 6.4s	remaining: 5.43s
# 541:	learn: 0.3340113	total: 6.42s	remaining: 5.42s
# 542:	learn: 0.3339202	total: 6.43s	remaining: 5.41s
# 543:	learn: 0.3338169	total: 6.44s	remaining: 5.4s
# 544:	learn: 0.3336932	total: 6.45s	remaining: 5.38s
# 545:	learn: 0.3335677	total: 6.46s	remaining: 5.37s
# 546:	learn: 0.3334546	total: 6.47s	remaining: 5.36s
# 547:	learn: 0.3333195	total: 6.49s	remaining: 5.35s
# 548:	learn: 0.3331618	total: 6.5s	remaining: 5.34s
# 549:	learn: 0.3330801	total: 6.51s	remaining: 5.33s
# 550:	learn: 0.3329985	total: 6.52s	remaining: 5.31s
# 551:	learn: 0.3328860	total: 6.53s	remaining: 5.3s
# 552:	learn: 0.3327781	total: 6.54s	remaining: 5.29s
# 553:	learn: 0.3326881	total: 6.55s	remaining: 5.28s
# 554:	learn: 0.3325453	total: 6.57s	remaining: 5.26s
# 555:	learn: 0.3324286	total: 6.58s	remaining: 5.25s
# 556:	learn: 0.3322834	total: 6.59s	remaining: 5.24s
# 557:	learn: 0.3321706	total: 6.6s	remaining: 5.23s
# 558:	learn: 0.3320736	total: 6.61s	remaining: 5.22s
# 559:	learn: 0.3320000	total: 6.63s	remaining: 5.21s
# 560:	learn: 0.3318983	total: 6.64s	remaining: 5.19s
# 561:	learn: 0.3317459	total: 6.65s	remaining: 5.18s
# 562:	learn: 0.3315907	total: 6.66s	remaining: 5.17s
# 563:	learn: 0.3314737	total: 6.67s	remaining: 5.16s
# 564:	learn: 0.3313403	total: 6.68s	remaining: 5.14s
# 565:	learn: 0.3311759	total: 6.69s	remaining: 5.13s
# 566:	learn: 0.3311088	total: 6.7s	remaining: 5.12s
# 567:	learn: 0.3310249	total: 6.71s	remaining: 5.11s
# 568:	learn: 0.3308809	total: 6.73s	remaining: 5.1s
# 569:	learn: 0.3307562	total: 6.74s	remaining: 5.08s
# 570:	learn: 0.3306140	total: 6.75s	remaining: 5.07s
# 571:	learn: 0.3304567	total: 6.76s	remaining: 5.06s
# 572:	learn: 0.3303494	total: 6.78s	remaining: 5.05s
# 573:	learn: 0.3302632	total: 6.79s	remaining: 5.04s
# 574:	learn: 0.3301367	total: 6.8s	remaining: 5.02s
# 575:	learn: 0.3300137	total: 6.81s	remaining: 5.01s
# 576:	learn: 0.3299248	total: 6.82s	remaining: 5s
# 577:	learn: 0.3298406	total: 6.83s	remaining: 4.99s
# 578:	learn: 0.3297167	total: 6.85s	remaining: 4.98s
# 579:	learn: 0.3295831	total: 6.86s	remaining: 4.97s
# 580:	learn: 0.3294584	total: 6.87s	remaining: 4.96s
# 581:	learn: 0.3293446	total: 6.88s	remaining: 4.94s
# 582:	learn: 0.3292373	total: 6.89s	remaining: 4.93s
# 583:	learn: 0.3291500	total: 6.91s	remaining: 4.92s
# 584:	learn: 0.3290697	total: 6.92s	remaining: 4.91s
# 585:	learn: 0.3289482	total: 6.93s	remaining: 4.89s
# 586:	learn: 0.3288733	total: 6.94s	remaining: 4.88s
# 587:	learn: 0.3287655	total: 6.95s	remaining: 4.87s
# 588:	learn: 0.3286504	total: 6.96s	remaining: 4.86s
# 589:	learn: 0.3285673	total: 6.97s	remaining: 4.85s
# 590:	learn: 0.3284181	total: 6.99s	remaining: 4.83s
# 591:	learn: 0.3283058	total: 7s	remaining: 4.82s
# 592:	learn: 0.3281845	total: 7.01s	remaining: 4.81s
# 593:	learn: 0.3280546	total: 7.02s	remaining: 4.8s
# 594:	learn: 0.3279460	total: 7.03s	remaining: 4.79s
# 595:	learn: 0.3278013	total: 7.04s	remaining: 4.78s
# 596:	learn: 0.3276782	total: 7.05s	remaining: 4.76s
# 597:	learn: 0.3275832	total: 7.07s	remaining: 4.75s
# 598:	learn: 0.3274799	total: 7.08s	remaining: 4.74s
# 599:	learn: 0.3273451	total: 7.09s	remaining: 4.72s
# 600:	learn: 0.3272193	total: 7.1s	remaining: 4.71s
# 601:	learn: 0.3271374	total: 7.11s	remaining: 4.7s
# 602:	learn: 0.3269963	total: 7.12s	remaining: 4.69s
# 603:	learn: 0.3268976	total: 7.13s	remaining: 4.68s
# 604:	learn: 0.3267796	total: 7.15s	remaining: 4.67s
# 605:	learn: 0.3266588	total: 7.16s	remaining: 4.65s
# 606:	learn: 0.3265039	total: 7.17s	remaining: 4.64s
# 607:	learn: 0.3264255	total: 7.18s	remaining: 4.63s
# 608:	learn: 0.3263046	total: 7.19s	remaining: 4.62s
# 609:	learn: 0.3261813	total: 7.21s	remaining: 4.61s
# 610:	learn: 0.3260525	total: 7.22s	remaining: 4.59s
# 611:	learn: 0.3259298	total: 7.23s	remaining: 4.58s
# 612:	learn: 0.3258010	total: 7.24s	remaining: 4.57s
# 613:	learn: 0.3257019	total: 7.25s	remaining: 4.56s
# 614:	learn: 0.3255998	total: 7.26s	remaining: 4.55s
# 615:	learn: 0.3254827	total: 7.28s	remaining: 4.54s
# 616:	learn: 0.3253457	total: 7.29s	remaining: 4.52s
# 617:	learn: 0.3252182	total: 7.3s	remaining: 4.51s
# 618:	learn: 0.3251547	total: 7.31s	remaining: 4.5s
# 619:	learn: 0.3250534	total: 7.32s	remaining: 4.49s
# 620:	learn: 0.3249418	total: 7.33s	remaining: 4.47s
# 621:	learn: 0.3248440	total: 7.34s	remaining: 4.46s
# 622:	learn: 0.3247229	total: 7.36s	remaining: 4.45s
# 623:	learn: 0.3246016	total: 7.37s	remaining: 4.44s
# 624:	learn: 0.3245535	total: 7.38s	remaining: 4.43s
# 625:	learn: 0.3244605	total: 7.39s	remaining: 4.41s
# 626:	learn: 0.3242922	total: 7.4s	remaining: 4.4s
# 627:	learn: 0.3241746	total: 7.41s	remaining: 4.39s
# 628:	learn: 0.3240756	total: 7.42s	remaining: 4.38s
# 629:	learn: 0.3239471	total: 7.43s	remaining: 4.37s
# 630:	learn: 0.3238599	total: 7.45s	remaining: 4.35s
# 631:	learn: 0.3237938	total: 7.46s	remaining: 4.34s
# 632:	learn: 0.3236992	total: 7.47s	remaining: 4.33s
# 633:	learn: 0.3235464	total: 7.48s	remaining: 4.32s
# 634:	learn: 0.3234044	total: 7.49s	remaining: 4.31s
# 635:	learn: 0.3233125	total: 7.5s	remaining: 4.29s
# 636:	learn: 0.3232313	total: 7.51s	remaining: 4.28s
# 637:	learn: 0.3231021	total: 7.53s	remaining: 4.27s
# 638:	learn: 0.3229747	total: 7.54s	remaining: 4.26s
# 639:	learn: 0.3228571	total: 7.55s	remaining: 4.25s
# 640:	learn: 0.3227673	total: 7.56s	remaining: 4.24s
# 641:	learn: 0.3226741	total: 7.57s	remaining: 4.22s
# 642:	learn: 0.3225365	total: 7.59s	remaining: 4.21s
# 643:	learn: 0.3224239	total: 7.6s	remaining: 4.2s
# 644:	learn: 0.3223028	total: 7.61s	remaining: 4.19s
# 645:	learn: 0.3221755	total: 7.62s	remaining: 4.18s
# 646:	learn: 0.3220741	total: 7.63s	remaining: 4.17s
# 647:	learn: 0.3219549	total: 7.65s	remaining: 4.15s
# 648:	learn: 0.3218545	total: 7.66s	remaining: 4.14s
# 649:	learn: 0.3217396	total: 7.67s	remaining: 4.13s
# 650:	learn: 0.3216292	total: 7.68s	remaining: 4.12s
# 651:	learn: 0.3215405	total: 7.69s	remaining: 4.11s
# 652:	learn: 0.3214462	total: 7.7s	remaining: 4.09s
# 653:	learn: 0.3213602	total: 7.71s	remaining: 4.08s
# 654:	learn: 0.3212567	total: 7.73s	remaining: 4.07s
# 655:	learn: 0.3211652	total: 7.74s	remaining: 4.06s
# 656:	learn: 0.3210805	total: 7.75s	remaining: 4.04s
# 657:	learn: 0.3210052	total: 7.76s	remaining: 4.03s
# 658:	learn: 0.3209360	total: 7.77s	remaining: 4.02s
# 659:	learn: 0.3208196	total: 7.78s	remaining: 4.01s
# 660:	learn: 0.3206893	total: 7.79s	remaining: 4s
# 661:	learn: 0.3205855	total: 7.81s	remaining: 3.98s
# 662:	learn: 0.3204700	total: 7.82s	remaining: 3.97s
# 663:	learn: 0.3203514	total: 7.83s	remaining: 3.96s
# 664:	learn: 0.3202730	total: 7.84s	remaining: 3.95s
# 665:	learn: 0.3201375	total: 7.85s	remaining: 3.94s
# 666:	learn: 0.3200468	total: 7.86s	remaining: 3.93s
# 667:	learn: 0.3199576	total: 7.88s	remaining: 3.91s
# 668:	learn: 0.3198451	total: 7.89s	remaining: 3.9s
# 669:	learn: 0.3197380	total: 7.9s	remaining: 3.89s
# 670:	learn: 0.3196231	total: 7.91s	remaining: 3.88s
# 671:	learn: 0.3195044	total: 7.92s	remaining: 3.87s
# 672:	learn: 0.3194034	total: 7.93s	remaining: 3.85s
# 673:	learn: 0.3192982	total: 7.94s	remaining: 3.84s
# 674:	learn: 0.3191803	total: 7.95s	remaining: 3.83s
# 675:	learn: 0.3190791	total: 7.97s	remaining: 3.82s
# 676:	learn: 0.3190202	total: 7.98s	remaining: 3.81s
# 677:	learn: 0.3189268	total: 7.99s	remaining: 3.79s
# 678:	learn: 0.3187903	total: 8s	remaining: 3.78s
# 679:	learn: 0.3187063	total: 8.01s	remaining: 3.77s
# 680:	learn: 0.3185959	total: 8.02s	remaining: 3.76s
# 681:	learn: 0.3185184	total: 8.04s	remaining: 3.75s
# 682:	learn: 0.3184123	total: 8.05s	remaining: 3.73s
# 683:	learn: 0.3183267	total: 8.06s	remaining: 3.72s
# 684:	learn: 0.3182438	total: 8.07s	remaining: 3.71s
# 685:	learn: 0.3181247	total: 8.08s	remaining: 3.7s
# 686:	learn: 0.3180097	total: 8.09s	remaining: 3.69s
# 687:	learn: 0.3179541	total: 8.1s	remaining: 3.67s
# 688:	learn: 0.3178502	total: 8.12s	remaining: 3.66s
# 689:	learn: 0.3177451	total: 8.13s	remaining: 3.65s
# 690:	learn: 0.3176448	total: 8.14s	remaining: 3.64s
# 691:	learn: 0.3175713	total: 8.15s	remaining: 3.63s
# 692:	learn: 0.3174771	total: 8.16s	remaining: 3.62s
# 693:	learn: 0.3173892	total: 8.17s	remaining: 3.6s
# 694:	learn: 0.3172830	total: 8.18s	remaining: 3.59s
# 695:	learn: 0.3172077	total: 8.19s	remaining: 3.58s
# 696:	learn: 0.3171199	total: 8.2s	remaining: 3.57s
# 697:	learn: 0.3170140	total: 8.22s	remaining: 3.55s
# 698:	learn: 0.3169308	total: 8.23s	remaining: 3.54s
# 699:	learn: 0.3168193	total: 8.24s	remaining: 3.53s
# 700:	learn: 0.3166776	total: 8.25s	remaining: 3.52s
# 701:	learn: 0.3165690	total: 8.26s	remaining: 3.51s
# 702:	learn: 0.3164148	total: 8.27s	remaining: 3.5s
# 703:	learn: 0.3163443	total: 8.28s	remaining: 3.48s
# 704:	learn: 0.3162584	total: 8.29s	remaining: 3.47s
# 705:	learn: 0.3161478	total: 8.31s	remaining: 3.46s
# 706:	learn: 0.3160148	total: 8.32s	remaining: 3.45s
# 707:	learn: 0.3158908	total: 8.33s	remaining: 3.44s
# 708:	learn: 0.3158040	total: 8.35s	remaining: 3.42s
# 709:	learn: 0.3157132	total: 8.36s	remaining: 3.41s
# 710:	learn: 0.3156295	total: 8.37s	remaining: 3.4s
# 711:	learn: 0.3154867	total: 8.38s	remaining: 3.39s
# 712:	learn: 0.3154132	total: 8.39s	remaining: 3.38s
# 713:	learn: 0.3153411	total: 8.4s	remaining: 3.37s
# 714:	learn: 0.3152353	total: 8.42s	remaining: 3.35s
# 715:	learn: 0.3151510	total: 8.43s	remaining: 3.34s
# 716:	learn: 0.3150262	total: 8.44s	remaining: 3.33s
# 717:	learn: 0.3149117	total: 8.45s	remaining: 3.32s
# 718:	learn: 0.3147924	total: 8.46s	remaining: 3.31s
# 719:	learn: 0.3146715	total: 8.48s	remaining: 3.3s
# 720:	learn: 0.3145443	total: 8.49s	remaining: 3.29s
# 721:	learn: 0.3144511	total: 8.5s	remaining: 3.27s
# 722:	learn: 0.3143392	total: 8.51s	remaining: 3.26s
# 723:	learn: 0.3142381	total: 8.52s	remaining: 3.25s
# 724:	learn: 0.3141308	total: 8.54s	remaining: 3.24s
# 725:	learn: 0.3139923	total: 8.55s	remaining: 3.23s
# 726:	learn: 0.3138938	total: 8.56s	remaining: 3.21s
# 727:	learn: 0.3138019	total: 8.57s	remaining: 3.2s
# 728:	learn: 0.3136813	total: 8.59s	remaining: 3.19s
# 729:	learn: 0.3135340	total: 8.6s	remaining: 3.18s
# 730:	learn: 0.3134125	total: 8.61s	remaining: 3.17s
# 731:	learn: 0.3133643	total: 8.63s	remaining: 3.16s
# 732:	learn: 0.3132778	total: 8.64s	remaining: 3.15s
# 733:	learn: 0.3132232	total: 8.65s	remaining: 3.13s
# 734:	learn: 0.3131287	total: 8.66s	remaining: 3.12s
# 735:	learn: 0.3130414	total: 8.67s	remaining: 3.11s
# 736:	learn: 0.3129064	total: 8.68s	remaining: 3.1s
# 737:	learn: 0.3128060	total: 8.69s	remaining: 3.09s
# 738:	learn: 0.3127176	total: 8.71s	remaining: 3.07s
# 739:	learn: 0.3126482	total: 8.72s	remaining: 3.06s
# 740:	learn: 0.3125628	total: 8.73s	remaining: 3.05s
# 741:	learn: 0.3124831	total: 8.74s	remaining: 3.04s
# 742:	learn: 0.3123573	total: 8.75s	remaining: 3.03s
# 743:	learn: 0.3122623	total: 8.77s	remaining: 3.02s
# 744:	learn: 0.3121646	total: 8.78s	remaining: 3s
# 745:	learn: 0.3120707	total: 8.79s	remaining: 2.99s
# 746:	learn: 0.3119699	total: 8.8s	remaining: 2.98s
# 747:	learn: 0.3118982	total: 8.81s	remaining: 2.97s
# 748:	learn: 0.3118150	total: 8.82s	remaining: 2.96s
# 749:	learn: 0.3117066	total: 8.84s	remaining: 2.94s
# 750:	learn: 0.3116163	total: 8.85s	remaining: 2.93s
# 751:	learn: 0.3115190	total: 8.86s	remaining: 2.92s
# 752:	learn: 0.3114240	total: 8.87s	remaining: 2.91s
# 753:	learn: 0.3113071	total: 8.88s	remaining: 2.9s
# 754:	learn: 0.3111615	total: 8.89s	remaining: 2.89s
# 755:	learn: 0.3110148	total: 8.91s	remaining: 2.87s
# 756:	learn: 0.3109595	total: 8.92s	remaining: 2.86s
# 757:	learn: 0.3108654	total: 8.93s	remaining: 2.85s
# 758:	learn: 0.3107956	total: 8.94s	remaining: 2.84s
# 759:	learn: 0.3106781	total: 8.95s	remaining: 2.83s
# 760:	learn: 0.3105886	total: 8.96s	remaining: 2.81s
# 761:	learn: 0.3104938	total: 8.98s	remaining: 2.8s
# 762:	learn: 0.3103991	total: 8.99s	remaining: 2.79s
# 763:	learn: 0.3102809	total: 9s	remaining: 2.78s
# 764:	learn: 0.3101472	total: 9.01s	remaining: 2.77s
# 765:	learn: 0.3100073	total: 9.02s	remaining: 2.76s
# 766:	learn: 0.3098757	total: 9.03s	remaining: 2.74s
# 767:	learn: 0.3097632	total: 9.05s	remaining: 2.73s
# 768:	learn: 0.3096821	total: 9.06s	remaining: 2.72s
# 769:	learn: 0.3096205	total: 9.07s	remaining: 2.71s
# 770:	learn: 0.3095505	total: 9.08s	remaining: 2.7s
# 771:	learn: 0.3094243	total: 9.09s	remaining: 2.69s
# 772:	learn: 0.3093342	total: 9.11s	remaining: 2.67s
# 773:	learn: 0.3092052	total: 9.12s	remaining: 2.66s
# 774:	learn: 0.3090806	total: 9.13s	remaining: 2.65s
# 775:	learn: 0.3090184	total: 9.14s	remaining: 2.64s
# 776:	learn: 0.3089527	total: 9.15s	remaining: 2.63s
# 777:	learn: 0.3088358	total: 9.16s	remaining: 2.62s
# 778:	learn: 0.3087758	total: 9.18s	remaining: 2.6s
# 779:	learn: 0.3086921	total: 9.19s	remaining: 2.59s
# 780:	learn: 0.3085451	total: 9.2s	remaining: 2.58s
# 781:	learn: 0.3084375	total: 9.21s	remaining: 2.57s
# 782:	learn: 0.3083675	total: 9.22s	remaining: 2.56s
# 783:	learn: 0.3082405	total: 9.24s	remaining: 2.54s
# 784:	learn: 0.3080855	total: 9.25s	remaining: 2.53s
# 785:	learn: 0.3079399	total: 9.26s	remaining: 2.52s
# 786:	learn: 0.3078332	total: 9.27s	remaining: 2.51s
# 787:	learn: 0.3076715	total: 9.28s	remaining: 2.5s
# 788:	learn: 0.3075987	total: 9.3s	remaining: 2.49s
# 789:	learn: 0.3074974	total: 9.31s	remaining: 2.47s
# 790:	learn: 0.3074135	total: 9.32s	remaining: 2.46s
# 791:	learn: 0.3073102	total: 9.33s	remaining: 2.45s
# 792:	learn: 0.3072251	total: 9.34s	remaining: 2.44s
# 793:	learn: 0.3070901	total: 9.36s	remaining: 2.43s
# 794:	learn: 0.3069704	total: 9.37s	remaining: 2.42s
# 795:	learn: 0.3068864	total: 9.38s	remaining: 2.4s
# 796:	learn: 0.3067982	total: 9.39s	remaining: 2.39s
# 797:	learn: 0.3066961	total: 9.4s	remaining: 2.38s
# 798:	learn: 0.3065909	total: 9.41s	remaining: 2.37s
# 799:	learn: 0.3064956	total: 9.43s	remaining: 2.36s
# 800:	learn: 0.3063699	total: 9.44s	remaining: 2.34s
# 801:	learn: 0.3062467	total: 9.45s	remaining: 2.33s
# 802:	learn: 0.3061677	total: 9.46s	remaining: 2.32s
# 803:	learn: 0.3060588	total: 9.47s	remaining: 2.31s
# 804:	learn: 0.3059973	total: 9.48s	remaining: 2.3s
# 805:	learn: 0.3058777	total: 9.49s	remaining: 2.29s
# 806:	learn: 0.3058051	total: 9.51s	remaining: 2.27s
# 807:	learn: 0.3057103	total: 9.52s	remaining: 2.26s
# 808:	learn: 0.3056041	total: 9.53s	remaining: 2.25s
# 809:	learn: 0.3055268	total: 9.54s	remaining: 2.24s
# 810:	learn: 0.3054047	total: 9.55s	remaining: 2.23s
# 811:	learn: 0.3053084	total: 9.56s	remaining: 2.21s
# 812:	learn: 0.3052065	total: 9.58s	remaining: 2.2s
# 813:	learn: 0.3051226	total: 9.59s	remaining: 2.19s
# 814:	learn: 0.3049905	total: 9.6s	remaining: 2.18s
# 815:	learn: 0.3048960	total: 9.61s	remaining: 2.17s
# 816:	learn: 0.3047814	total: 9.62s	remaining: 2.15s
# 817:	learn: 0.3046450	total: 9.64s	remaining: 2.14s
# 818:	learn: 0.3045662	total: 9.65s	remaining: 2.13s
# 819:	learn: 0.3044594	total: 9.66s	remaining: 2.12s
# 820:	learn: 0.3043513	total: 9.67s	remaining: 2.11s
# 821:	learn: 0.3042200	total: 9.68s	remaining: 2.1s
# 822:	learn: 0.3041073	total: 9.69s	remaining: 2.08s
# 823:	learn: 0.3040126	total: 9.71s	remaining: 2.07s
# 824:	learn: 0.3039217	total: 9.72s	remaining: 2.06s
# 825:	learn: 0.3038202	total: 9.73s	remaining: 2.05s
# 826:	learn: 0.3037177	total: 9.74s	remaining: 2.04s
# 827:	learn: 0.3036159	total: 9.76s	remaining: 2.03s
# 828:	learn: 0.3034832	total: 9.77s	remaining: 2.02s
# 829:	learn: 0.3033723	total: 9.78s	remaining: 2s
# 830:	learn: 0.3032789	total: 9.79s	remaining: 1.99s
# 831:	learn: 0.3031782	total: 9.8s	remaining: 1.98s
# 832:	learn: 0.3031174	total: 9.82s	remaining: 1.97s
# 833:	learn: 0.3030348	total: 9.83s	remaining: 1.96s
# 834:	learn: 0.3029465	total: 9.84s	remaining: 1.94s
# 835:	learn: 0.3028321	total: 9.85s	remaining: 1.93s
# 836:	learn: 0.3027100	total: 9.86s	remaining: 1.92s
# 837:	learn: 0.3025726	total: 9.88s	remaining: 1.91s
# 838:	learn: 0.3024587	total: 9.89s	remaining: 1.9s
# 839:	learn: 0.3023539	total: 9.9s	remaining: 1.89s
# 840:	learn: 0.3022555	total: 9.91s	remaining: 1.87s
# 841:	learn: 0.3021699	total: 9.92s	remaining: 1.86s
# 842:	learn: 0.3020894	total: 9.94s	remaining: 1.85s
# 843:	learn: 0.3020451	total: 9.95s	remaining: 1.84s
# 844:	learn: 0.3019681	total: 9.96s	remaining: 1.83s
# 845:	learn: 0.3018757	total: 9.97s	remaining: 1.81s
# 846:	learn: 0.3017950	total: 9.98s	remaining: 1.8s
# 847:	learn: 0.3017345	total: 9.99s	remaining: 1.79s
# 848:	learn: 0.3016576	total: 10s	remaining: 1.78s
# 849:	learn: 0.3015687	total: 10s	remaining: 1.77s
# 850:	learn: 0.3014438	total: 10s	remaining: 1.76s
# 851:	learn: 0.3013538	total: 10s	remaining: 1.74s
# 852:	learn: 0.3012428	total: 10.1s	remaining: 1.73s
# 853:	learn: 0.3011670	total: 10.1s	remaining: 1.72s
# 854:	learn: 0.3011008	total: 10.1s	remaining: 1.71s
# 855:	learn: 0.3010370	total: 10.1s	remaining: 1.7s
# 856:	learn: 0.3009605	total: 10.1s	remaining: 1.69s
# 857:	learn: 0.3008317	total: 10.1s	remaining: 1.67s
# 858:	learn: 0.3007482	total: 10.1s	remaining: 1.66s
# 859:	learn: 0.3006124	total: 10.1s	remaining: 1.65s
# 860:	learn: 0.3005003	total: 10.1s	remaining: 1.64s
# 861:	learn: 0.3004036	total: 10.2s	remaining: 1.63s
# 862:	learn: 0.3003320	total: 10.2s	remaining: 1.61s
# 863:	learn: 0.3002260	total: 10.2s	remaining: 1.6s
# 864:	learn: 0.3001435	total: 10.2s	remaining: 1.59s
# 865:	learn: 0.3000534	total: 10.2s	remaining: 1.58s
# 866:	learn: 0.2999908	total: 10.2s	remaining: 1.57s
# 867:	learn: 0.2999098	total: 10.2s	remaining: 1.56s
# 868:	learn: 0.2998589	total: 10.2s	remaining: 1.54s
# 869:	learn: 0.2997158	total: 10.3s	remaining: 1.53s
# 870:	learn: 0.2996138	total: 10.3s	remaining: 1.52s
# 871:	learn: 0.2995140	total: 10.3s	remaining: 1.51s
# 872:	learn: 0.2994213	total: 10.3s	remaining: 1.5s
# 873:	learn: 0.2993624	total: 10.3s	remaining: 1.49s
# 874:	learn: 0.2992696	total: 10.3s	remaining: 1.47s
# 875:	learn: 0.2991990	total: 10.3s	remaining: 1.46s
# 876:	learn: 0.2990457	total: 10.3s	remaining: 1.45s
# 877:	learn: 0.2989283	total: 10.3s	remaining: 1.44s
# 878:	learn: 0.2988231	total: 10.4s	remaining: 1.43s
# 879:	learn: 0.2987411	total: 10.4s	remaining: 1.41s
# 880:	learn: 0.2986806	total: 10.4s	remaining: 1.4s
# 881:	learn: 0.2985898	total: 10.4s	remaining: 1.39s
# 882:	learn: 0.2984959	total: 10.4s	remaining: 1.38s
# 883:	learn: 0.2983963	total: 10.4s	remaining: 1.37s
# 884:	learn: 0.2982638	total: 10.4s	remaining: 1.35s
# 885:	learn: 0.2981564	total: 10.4s	remaining: 1.34s
# 886:	learn: 0.2980628	total: 10.5s	remaining: 1.33s
# 887:	learn: 0.2979891	total: 10.5s	remaining: 1.32s
# 888:	learn: 0.2979160	total: 10.5s	remaining: 1.31s
# 889:	learn: 0.2977979	total: 10.5s	remaining: 1.3s
# 890:	learn: 0.2977130	total: 10.5s	remaining: 1.28s
# 891:	learn: 0.2976360	total: 10.5s	remaining: 1.27s
# 892:	learn: 0.2975636	total: 10.5s	remaining: 1.26s
# 893:	learn: 0.2974849	total: 10.5s	remaining: 1.25s
# 894:	learn: 0.2973949	total: 10.6s	remaining: 1.24s
# 895:	learn: 0.2972985	total: 10.6s	remaining: 1.23s
# 896:	learn: 0.2972187	total: 10.6s	remaining: 1.21s
# 897:	learn: 0.2971555	total: 10.6s	remaining: 1.2s
# 898:	learn: 0.2970686	total: 10.6s	remaining: 1.19s
# 899:	learn: 0.2969871	total: 10.6s	remaining: 1.18s
# 900:	learn: 0.2969048	total: 10.6s	remaining: 1.17s
# 901:	learn: 0.2968189	total: 10.6s	remaining: 1.16s
# 902:	learn: 0.2967202	total: 10.6s	remaining: 1.14s
# 903:	learn: 0.2966328	total: 10.7s	remaining: 1.13s
# 904:	learn: 0.2965145	total: 10.7s	remaining: 1.12s
# 905:	learn: 0.2964357	total: 10.7s	remaining: 1.11s
# 906:	learn: 0.2963459	total: 10.7s	remaining: 1.1s
# 907:	learn: 0.2962729	total: 10.7s	remaining: 1.08s
# 908:	learn: 0.2961827	total: 10.7s	remaining: 1.07s
# 909:	learn: 0.2961004	total: 10.7s	remaining: 1.06s
# 910:	learn: 0.2959851	total: 10.7s	remaining: 1.05s
# 911:	learn: 0.2958688	total: 10.8s	remaining: 1.04s
# 912:	learn: 0.2958259	total: 10.8s	remaining: 1.02s
# 913:	learn: 0.2957388	total: 10.8s	remaining: 1.01s
# 914:	learn: 0.2956390	total: 10.8s	remaining: 1s
# 915:	learn: 0.2955316	total: 10.8s	remaining: 990ms
# 916:	learn: 0.2954638	total: 10.8s	remaining: 979ms
# 917:	learn: 0.2953584	total: 10.8s	remaining: 967ms
# 918:	learn: 0.2952636	total: 10.8s	remaining: 955ms
# 919:	learn: 0.2951599	total: 10.8s	remaining: 943ms
# 920:	learn: 0.2950231	total: 10.9s	remaining: 931ms
# 921:	learn: 0.2949616	total: 10.9s	remaining: 920ms
# 922:	learn: 0.2949053	total: 10.9s	remaining: 908ms
# 923:	learn: 0.2948294	total: 10.9s	remaining: 896ms
# 924:	learn: 0.2947043	total: 10.9s	remaining: 884ms
# 925:	learn: 0.2945964	total: 10.9s	remaining: 873ms
# 926:	learn: 0.2945008	total: 10.9s	remaining: 861ms
# 927:	learn: 0.2943998	total: 10.9s	remaining: 849ms
# 928:	learn: 0.2943508	total: 11s	remaining: 837ms
# 929:	learn: 0.2942527	total: 11s	remaining: 825ms
# 930:	learn: 0.2941365	total: 11s	remaining: 813ms
# 931:	learn: 0.2940378	total: 11s	remaining: 802ms
# 932:	learn: 0.2939213	total: 11s	remaining: 790ms
# 933:	learn: 0.2938370	total: 11s	remaining: 778ms
# 934:	learn: 0.2937427	total: 11s	remaining: 766ms
# 935:	learn: 0.2936710	total: 11s	remaining: 755ms
# 936:	learn: 0.2935720	total: 11s	remaining: 743ms
# 937:	learn: 0.2935281	total: 11.1s	remaining: 731ms
# 938:	learn: 0.2934497	total: 11.1s	remaining: 719ms
# 939:	learn: 0.2933367	total: 11.1s	remaining: 707ms
# 940:	learn: 0.2932249	total: 11.1s	remaining: 696ms
# 941:	learn: 0.2931141	total: 11.1s	remaining: 684ms
# 942:	learn: 0.2930398	total: 11.1s	remaining: 672ms
# 943:	learn: 0.2929287	total: 11.1s	remaining: 660ms
# 944:	learn: 0.2928366	total: 11.1s	remaining: 648ms
# 945:	learn: 0.2927470	total: 11.2s	remaining: 637ms
# 946:	learn: 0.2926333	total: 11.2s	remaining: 625ms
# 947:	learn: 0.2925775	total: 11.2s	remaining: 613ms
# 948:	learn: 0.2924689	total: 11.2s	remaining: 601ms
# 949:	learn: 0.2923706	total: 11.2s	remaining: 590ms
# 950:	learn: 0.2922861	total: 11.2s	remaining: 578ms
# 951:	learn: 0.2922341	total: 11.2s	remaining: 566ms
# 952:	learn: 0.2921126	total: 11.2s	remaining: 555ms
# 953:	learn: 0.2919990	total: 11.3s	remaining: 543ms
# 954:	learn: 0.2919475	total: 11.3s	remaining: 531ms
# 955:	learn: 0.2918984	total: 11.3s	remaining: 519ms
# 956:	learn: 0.2918119	total: 11.3s	remaining: 508ms
# 957:	learn: 0.2917796	total: 11.3s	remaining: 496ms
# 958:	learn: 0.2917143	total: 11.3s	remaining: 484ms
# 959:	learn: 0.2916521	total: 11.3s	remaining: 472ms
# 960:	learn: 0.2915817	total: 11.3s	remaining: 460ms
# 961:	learn: 0.2914392	total: 11.4s	remaining: 448ms
# 962:	learn: 0.2913660	total: 11.4s	remaining: 437ms
# 963:	learn: 0.2912933	total: 11.4s	remaining: 425ms
# 964:	learn: 0.2911761	total: 11.4s	remaining: 413ms
# 965:	learn: 0.2911055	total: 11.4s	remaining: 401ms
# 966:	learn: 0.2910323	total: 11.4s	remaining: 389ms
# 967:	learn: 0.2909260	total: 11.4s	remaining: 378ms
# 968:	learn: 0.2908502	total: 11.4s	remaining: 366ms
# 969:	learn: 0.2907680	total: 11.4s	remaining: 354ms
# 970:	learn: 0.2907132	total: 11.5s	remaining: 342ms
# 971:	learn: 0.2906634	total: 11.5s	remaining: 330ms
# 972:	learn: 0.2906051	total: 11.5s	remaining: 319ms
# 973:	learn: 0.2904808	total: 11.5s	remaining: 307ms
# 974:	learn: 0.2903841	total: 11.5s	remaining: 295ms
# 975:	learn: 0.2903089	total: 11.5s	remaining: 283ms
# 976:	learn: 0.2901907	total: 11.5s	remaining: 271ms
# 977:	learn: 0.2901297	total: 11.5s	remaining: 260ms
# 978:	learn: 0.2900567	total: 11.6s	remaining: 248ms
# 979:	learn: 0.2900055	total: 11.6s	remaining: 236ms
# 980:	learn: 0.2899346	total: 11.6s	remaining: 224ms
# 981:	learn: 0.2898207	total: 11.6s	remaining: 212ms
# 982:	learn: 0.2897246	total: 11.6s	remaining: 201ms
# 983:	learn: 0.2896363	total: 11.6s	remaining: 189ms
# 984:	learn: 0.2895218	total: 11.6s	remaining: 177ms
# 985:	learn: 0.2893999	total: 11.6s	remaining: 165ms
# 986:	learn: 0.2893169	total: 11.7s	remaining: 153ms
# 987:	learn: 0.2892609	total: 11.7s	remaining: 142ms
# 988:	learn: 0.2891964	total: 11.7s	remaining: 130ms
# 989:	learn: 0.2891197	total: 11.7s	remaining: 118ms
# 990:	learn: 0.2890318	total: 11.7s	remaining: 106ms
# 991:	learn: 0.2889403	total: 11.7s	remaining: 94.5ms
# 992:	learn: 0.2888690	total: 11.7s	remaining: 82.6ms
# 993:	learn: 0.2887971	total: 11.7s	remaining: 70.9ms
# 994:	learn: 0.2887066	total: 11.8s	remaining: 59ms
# 995:	learn: 0.2885966	total: 11.8s	remaining: 47.2ms
# 996:	learn: 0.2885373	total: 11.8s	remaining: 35.4ms
# 997:	learn: 0.2884392	total: 11.8s	remaining: 23.6ms
# 998:	learn: 0.2883515	total: 11.8s	remaining: 11.8ms
# 999:	learn: 0.2882612	total: 11.8s	remaining: 0us

# %% [markdown]
# # Report

# %%
test_report = pd.DataFrame(test_model_scores, index =  ['Accuracy', 'Precision', 'Recall', 'F1', 'AUROC']).T
test_report
# Out:
#                      Accuracy  Precision    Recall        F1     AUROC
# Logistic Regression  0.783863   0.627645  0.785811  0.642382  0.785811
# Decision Tree        0.887941   0.688466  0.702249  0.694989  0.702249
# Random Forest        0.928284   0.835484  0.705275  0.750345  0.705275
# XGBoost              0.843305   0.664959  0.806789  0.697947  0.806789
# CatBoost             0.852441   0.671777  0.805865  0.706226  0.805865

# %%
train_report = pd.DataFrame(train_model_scores, index =  ['Accuracy', 'Precision', 'Recall', 'F1', 'AUROC']).T
train_report
# Out:
#                      Accuracy  Precision    Recall        F1     AUROC
# Logistic Regression  0.784049   0.626642  0.782991  0.641382  0.782991
# Decision Tree        0.999821   0.999090  0.999901  0.999495  0.999901
# Random Forest        0.999821   0.999090  0.999901  0.999495  0.999901
# XGBoost              0.858395   0.688556  0.853156  0.728032  0.853156
# CatBoost             0.874935   0.709272  0.879302  0.753823  0.879302

# %%
train_o_report = pd.DataFrame(train_o_model_scores, index =  ['Accuracy', 'Precision', 'Recall', 'F1', 'AUROC']).T
train_o_report
# Out:
#                      Accuracy  Precision    Recall        F1     AUROC
# Logistic Regression  0.782526   0.782530  0.782526  0.782526  0.782526
# Decision Tree        0.999901   0.999901  0.999901  0.999901  0.999901
# Random Forest        0.999901   0.999901  0.999901  0.999901  0.999901
# XGBoost              0.857068   0.857078  0.857068  0.857067  0.857068
# CatBoost             0.884034   0.884192  0.884034  0.884022  0.884034
